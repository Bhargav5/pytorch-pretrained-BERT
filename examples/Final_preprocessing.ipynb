# %%
import argparse
import os
import csv
import random
import logging
from tqdm import tqdm, trange

import numpy as np
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from pytorch_pretrained_bert import OpenAIGPTLMHeadModel, OpenAIGPTTokenizer, OpenAIAdam
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
spl_tokens = {'pos': '<POS>',
              'neg': '<NEG>',
              'Con_start':'<CON_START>',
              'start': '<START>',
              'end': '<END>'}
spl_tokens
# Out:
# {'pos': '<POS>',
#  'neg': '<NEG>',
#  'Con_start': '<CON_START>',
#  'start': '<START>',
#  'end': '<END>'}

# %%
VOCAB_PATH = os.path.join(os.getcwd(), 'amazon_attribute_vocab.txt')
POS_FILE_PATH = os.path.join(os.getcwd(), 'sentiment_train_1.txt')
NEG_FILE_PATH = os.path.join(os.getcwd(),'sentiment_train_0.txt')
POS_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_train_1.txt')
NEG_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_train_0.txt')

# %%
attribute_vocab = []
with open(VOCAB_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        attribute_vocab.append(line)

# %%
def extract_attribure(attribute_vocab, line):
    content = []
    attribute = []
    for token in line:
        if token in attribute_vocab:
            attribute.append(token)
        else:
            content.append(token)
    return content, attribute

# %%
def prepare_data_file(reference_file_path, output_file_path, type_token='pos'):
    count = 0
    out_file = open(output_file_path, 'w', encoding='utf-8')
    with open(reference_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            count += 1
            line = line.strip()
            tokens = line.split(' ')
            cont, att = extract_attribure(attribute_vocab, tokens)
            ipstr = spl_tokens[type_token] + ' '+ spl_tokens['Con_start'] + ' ' + ' '.join(cont)  + ' ' + spl_tokens[
                'start'] + ' ' + line + ' '+ spl_tokens['end'] + "\n"
            out_file.write(ipstr)
            if (count % 10000 == 0):
                print(count)
    out_file.close()

# %%
lt = []

# %%
lt == []
# Out:
# True

# %%
def prepare_test_data_file(reference_file_path, output_file_path, type_token='pos'):
    count = 0
    out_file = open(output_file_path, 'w', encoding='utf-8')
    with open(reference_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            count += 1
            line = line.strip()
            tokens = line.split(' ')
            cont, att = extract_attribure(attribute_vocab, tokens)
            if att != []:
                ipstr = spl_tokens[type_token] + ' '+ spl_tokens['Con_start'] + ' ' + ' '.join(cont)  + ' ' + spl_tokens[
                'start'] + "\n"
                out_file.write(ipstr)
            if (count % 10000 == 0):
                print(count)
    out_file.close()

# %%
def prepare_test_data_file_v1(reference_file_path, output_file_path, output_ref_file, type_token='pos'):
    count = 0
    out_file = open(output_file_path, 'w', encoding='utf-8')
    out_ref_file = open(output_ref_file, 'w', encoding='utf-8')
    with open(reference_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            count += 1
            line = line.strip()
            tokens = line.split(' ')
            cont, att = extract_attribure(attribute_vocab, tokens)
            if att != []:
                ipstr = spl_tokens[type_token] + ' '+ spl_tokens['Con_start'] + ' ' + ' '.join(cont)  + ' ' + spl_tokens[
                'start'] + "\n"
                out_file.write(ipstr)
                out_ref_file.write(line + "\n")
            if (count % 10000 == 0):
                print(count)
    out_file.close()

# %%
prepare_data_file(POS_FILE_PATH, POS_OUT_FILE_PATH, type_token='pos')

# %%
prepare_data_file(NEG_FILE_PATH, NEG_OUT_FILE_PATH, type_token='neg')

# %%
POS_VAL_FILE_PATH = os.path.join(os.getcwd(), 'sentiment_dev_1.txt')
NEG_VAL_FILE_PATH = os.path.join(os.getcwd(),'sentiment_dev_0.txt')
POS_VAL_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_dev_1.txt')
NEG_VAL_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_dev_0.txt')
POS_TEST_FILE_PATH = os.path.join(os.getcwd(), 'sentiment_test_1.txt')
NEG_TEST_FILE_PATH = os.path.join(os.getcwd(),'sentiment_test_0.txt')
POS_TEST_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_test_1.txt')
NEG_TEST_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_test_0.txt')
POS_TEST_OUT_FILE_PATH1 = os.path.join(os.getcwd(), 'processed_sentiment_test_1_1.txt')
NEG_TEST_OUT_FILE_PATH1 = os.path.join(os.getcwd(), 'processed_sentiment_test_0_1.txt')
POS_TEST_FILE_PATH_FILTER = os.path.join(os.getcwd(), 'sentiment_test_filtered_1.txt')
NEG_TEST_FILE_PATH_FILTER = os.path.join(os.getcwd(),'sentiment_test_filtered_0.txt')

# %%
prepare_data_file(POS_VAL_FILE_PATH, POS_VAL_OUT_FILE_PATH, type_token='pos')

# %%
prepare_data_file(NEG_VAL_FILE_PATH, NEG_VAL_OUT_FILE_PATH, type_token='neg')

# %%
prepare_test_data_file(POS_TEST_FILE_PATH, POS_TEST_OUT_FILE_PATH1)

# %%
prepare_test_data_file(NEG_TEST_FILE_PATH, NEG_TEST_OUT_FILE_PATH1, type_token='neg')

# %%
prepare_test_data_file_v1(POS_TEST_FILE_PATH, POS_TEST_OUT_FILE_PATH1, POS_TEST_FILE_PATH_FILTER)

# %%
prepare_test_data_file_v1(NEG_TEST_FILE_PATH, NEG_TEST_OUT_FILE_PATH1, NEG_TEST_FILE_PATH_FILTER, type_token='neg')

# %%
TRAIN_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_train.txt')
TEST_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_test_v1.txt')
TEST_REF_FILE_PATH = os.path.join(os.getcwd(), 'sentiment_test_filtered.txt')
VAL_OUT_FILE_PATH = os.path.join(os.getcwd(), 'processed_sentiment_dev.txt')

# %%
def concate_files(output_file_path, input_files):
    with open(output_file_path, 'w', encoding='utf-8') as out_f:
        for file in input_files:
            with open(file, 'r') as f1:
                for line in f1:
                    out_f.write(line)

# %%
concate_files(output_file_path=TRAIN_OUT_FILE_PATH, input_files=[POS_OUT_FILE_PATH, NEG_OUT_FILE_PATH])

# %%
concate_files(output_file_path=TEST_OUT_FILE_PATH, input_files=[POS_TEST_OUT_FILE_PATH1, NEG_TEST_OUT_FILE_PATH1])

# %%
concate_files(output_file_path=TEST_REF_FILE_PATH, input_files=[POS_TEST_FILE_PATH_FILTER, NEG_TEST_FILE_PATH_FILTER])

# %%
concate_files(output_file_path=VAL_OUT_FILE_PATH, input_files=[POS_VAL_OUT_FILE_PATH, NEG_VAL_OUT_FILE_PATH])

# %%
np.zeros()

# %%
# !cat processed_sentiment_test_v1.txt
# Out:
# <POS> <CON_START> very price but this one harder to use than my cusinart . <START>
# <POS> <CON_START> replaced my pampered press with this one . <START>
# <POS> <CON_START> and seems similar to apple products . <START>
# <POS> <CON_START> i have many products ,  and i ve been pleased . <START>
# <POS> <CON_START> it turned out just to replace what i had lost . <START>
# <POS> <CON_START> the way these roll instead of sliding on the rod . <START>
# <POS> <CON_START> they pile up in the closet and up in the . <START>
# <POS> <CON_START> i had it a long time now and i still it . <START>
# <POS> <CON_START> this offers really protection for the phone . <START>
# <POS> <CON_START> this is one of the vacuums i ve ever come across . <START>
# <POS> <CON_START> one minute per slice seems a rule of thumb so far . <START>
# <POS> <CON_START> the metal is very and the non stick finish is . <START>
# <POS> <CON_START> the flap also is and does not come loose at all . <START>
# <POS> <CON_START> sharp cutting edges make your look as as they taste . <START>
# <POS> <CON_START> recently in the trash as the line wore out . <START>
# <POS> <CON_START> i have several of these ,  well it . <START>
# <POS> <CON_START> charger ,  though there may be cheaper options . <START>
# <POS> <CON_START> so shipping takes a while but it is definitely the price . <START>
# <POS> <CON_START> blocking the red hot coils from my cookie sheets ,  and . <START>
# <POS> <CON_START> for about anything you want to shred ,  cut or mix . <START>
# <POS> <CON_START> the head set is quite  at least for me  . <START>
# <POS> <CON_START> washing it is a and just takes a second . <START>
# <POS> <CON_START> once glitch ,  which i did not view as all that . <START>
# <POS> <CON_START> i have had this mount for about a year and it works . <START>
# <POS> <CON_START> but it s not for wireless ,  i ve had . <START>
# <POS> <CON_START> exactly what i need for my phone and at the price possible . <START>
# <POS> <CON_START> shipped free directly from and arrived within two days . <START>
# <POS> <CON_START> to put on and i have no problems . <START>
# <POS> <CON_START> this one is available at a price with fair shipping here on amazon . <START>
# <POS> <CON_START> i almost except cucumber juice  echhh  . <START>
# <POS> <CON_START> one feature is that the head is removable for east cleaning . <START>
# <POS> <CON_START> auto shut off after num_num hours ,  which is a feature . <START>
# <POS> <CON_START> even after several days ,  they are air tight in a bottle . <START>
# <POS> <CON_START> i bought this in num_num and the is still in shape . <START>
# <POS> <CON_START> these come in with those tender special moments and celebrations . <START>
# <POS> <CON_START> both english and metric measurements are embossed onto each . <START>
# <POS> <CON_START> and it ll keep rice and hot for up to num_num hours . <START>
# <POS> <CON_START> it keeps the air and smelling . <START>
# <POS> <CON_START> belt works and installed in just a few minutes . <START>
# <POS> <CON_START> they were and they work i them a lot thank you . <START>
# <POS> <CON_START> mine fit on my linen closet door with no securing necessary . <START>
# <POS> <CON_START> very with a selection of sizes . <START>
# <POS> <CON_START> i use it a lot ,  and it gave me any problem . <START>
# <POS> <CON_START> the handle is and holds the pitchers securely in your hands . <START>
# <POS> <CON_START> that said ,  the mic did pic up it could . <START>
# <POS> <CON_START> i just bought a num_extend ft chest . <START>
# <POS> <CON_START> no more oil on my hands when up a or falafel . <START>
# <POS> <CON_START> it works and i am very with it . <START>
# <POS> <CON_START> the shipping are now lower and upfront on the order . <START>
# <POS> <CON_START> i can t believe how and substantial this ice cream maker is . <START>
# <POS> <CON_START> the charger is working with my wireless bluetooth speaker just so far . <START>
# <POS> <CON_START> although once you go a little past halfway the gets a little . <START>
# <POS> <CON_START> i m starting to it because i don t need to upgrade . <START>
# <POS> <CON_START> i guess you could say so what it s a . <START>
# <POS> <CON_START> fast; than a blender and is to use . <START>
# <POS> <CON_START> overall i them ,  and would probably buy them again . <START>
# <POS> <CON_START> i have been extremely with my purchase . <START>
# <POS> <CON_START> the glass cuisinart would pour water everywhere in a wet mess . <START>
# <POS> <CON_START> i am that i did not spend a fortune on the electric models . <START>
# <POS> <CON_START> it s very simple and takes up very little space on the rack . <START>
# <POS> <CON_START> fill the half way with water ,  and put it to boil . <START>
# <POS> <CON_START> comes with a  towel  to the phone before placement . <START>
# <POS> <CON_START> i said ,  it works ,  these are ok . <START>
# <POS> <CON_START> seems to working in my mother s humidifier . <START>
# <POS> <CON_START> mediocre results until hitting upon a . <START>
# <POS> <CON_START> on the other hand for power you ve got something here . <START>
# <POS> <CON_START> headset ,  solid build and blocks out the wind . <START>
# <POS> <CON_START> i am so we chose this one . <START>
# <POS> <CON_START> we use these alot and they work . <START>
# <POS> <CON_START> i say that after trying many headsets ,  sigh . <START>
# <POS> <CON_START> i pretreated the stains withwoolite pet stain . <START>
# <POS> <CON_START> i have dropped the phone onto a tile floor and it is . <START>
# <POS> <CON_START> the la prima ran about half a shot then the machine . <START>
# <POS> <CON_START> however ,  this is an example of how got it right . <START>
# <POS> <CON_START> it my modest requirements ,  and my expectations in appearance . <START>
# <POS> <CON_START> look up videos on if you want to see it in action . <START>
# <POS> <CON_START> i that is is and washable . <START>
# <POS> <CON_START> the aluminum ones get stained and after a few uses . <START>
# <POS> <CON_START> place it in the and close the door . <START>
# <POS> <CON_START> open carefully and handle the with care . <START>
# <POS> <CON_START> it had a cost and a product . <START>
# <POS> <CON_START> it stays stable in your ear very nicely and is surprisingly very . <START>
# <POS> <CON_START> this headset is ,  the sound is truly amazing . <START>
# <POS> <CON_START> to say about this wonderful at all . <START>
# <POS> <CON_START> it stay and does not collect food stains . <START>
# <POS> <CON_START> i have problems answering the phone this way with my . <START>
# <POS> <CON_START> to apply and it works very well . <START>
# <POS> <CON_START> i wore my first one out by pouring hot in it . <START>
# <POS> <CON_START> also ,  don t use that yellow cloth to your phone . <START>
# <POS> <CON_START> doesn t really reduce the fat anymore than most methods . <START>
# <POS> <CON_START> the that comes with it is . <START>
# <POS> <CON_START> i have read reviews from experts that it doesn t work . <START>
# <POS> <CON_START> then along came this which i use constantly . <START>
# <POS> <CON_START> i recommand smaller size for everyday use . but i this . <START>
# <POS> <CON_START> ,  and with lots of options to choose . <START>
# <POS> <CON_START> tastes in between the classic american ale and cowboy golden lager . <START>
# <POS> <CON_START> put sauce on top then add pepperoni and mushrooms . <START>
# <POS> <CON_START> this is the old faithful water filter . <START>
# <POS> <CON_START> we use a machine to prepare the and provide the first rise . <START>
# <POS> <CON_START> i ve been with most products i ve purchased . <START>
# <POS> <CON_START> it s to go the next morning ,  completely . <START>
# <POS> <CON_START> other than that small problem ,  this is a bt headdest . <START>
# <POS> <CON_START> i followed the instructions and away the first num_num of coffee . <START>
# <POS> <CON_START> so i purchased another knife for this our num_num yankee swap . <START>
# <POS> <CON_START> blade release buttons are simple to use which makes cleaning . <START>
# <POS> <CON_START> : pi also have limited space in my . <START>
# <POS> <CON_START> i also it because the jar is plastic . <START>
# <POS> <CON_START> you ve probably seen them use it on iron . <START>
# <POS> <CON_START> it would have been if it was a tad bit smaller . <START>
# <POS> <CON_START> all came well and ready to go . <START>
# <POS> <CON_START> this cuts down on and you don t have to propellants . <START>
# <POS> <CON_START> gem are easier to with a stylus this . <START>
# <POS> <CON_START> it is if you have more than one guest to serve . <START>
# <POS> <CON_START> i made beef bolognese in the and it turned out wonderfully . <START>
# <POS> <CON_START> making seperation and cross contamination containment a very . <START>
# <POS> <CON_START> the just thinks it s furniture and doesn t go up on it . <START>
# <POS> <CON_START> the would make a stocking stuffer for any queen . <START>
# <POS> <CON_START> the was enough to after use . <START>
# <POS> <CON_START> but for now ,  i m quite with this . <START>
# <POS> <CON_START> size for dishes . it really works well . <START>
# <POS> <CON_START> this product is being used for dollar size . <START>
# <POS> <CON_START> it !  really to set by the . <START>
# <POS> <CON_START> i m a fan of symbian and find it to operate . <START>
# <POS> <CON_START> plugs the ipad into my car and works . <START>
# <POS> <CON_START> i it than any of the items . <START>
# <POS> <CON_START> once it dies i will purchase a unit . <START>
# <POS> <CON_START> otterboxes are a little bulky ,  but for the price . <START>
# <POS> <CON_START> this style of meat is sort of commodity . <START>
# <POS> <CON_START> not to have a burner going for hours . <START>
# <POS> <CON_START> this unit makes the french i ve ever made . <START>
# <POS> <CON_START> it works with all types ,  but works with roma tomatoes . <START>
# <POS> <CON_START> careful when using however because they will scratch these plates . <START>
# <POS> <CON_START> it s still going ,  i just needed more capacity . <START>
# <POS> <CON_START> also ,  the knife is to maneuver despite its length . <START>
# <POS> <CON_START> for the price ,  this is a buy . <START>
# <POS> <CON_START> and it s a knife and all that special . <START>
# <POS> <CON_START> i used to use a brand safety opener and really liked it . <START>
# <POS> <CON_START> then both of them go into the . <START>
# <POS> <CON_START> i my and use it almost every morning . <START>
# <POS> <CON_START> however signal between transmitter and receiver does not work between patio glass door . <START>
# <POS> <CON_START> this i have had for one year . <START>
# <POS> <CON_START> i do seem to need to invest in some . <START>
# <POS> <CON_START> and the boker knife which is quite . <START>
# <POS> <CON_START> i finally made he purchase and am i did . <START>
# <POS> <CON_START> coming from an asian background it s not something we normally with . <START>
# <POS> <CON_START> i liked this and was with my purchase . <START>
# <POS> <CON_START> we our garden and greens with ease . <START>
# <POS> <CON_START> anyway i recommend this one for its price and . <START>
# <POS> <CON_START> i put my appliances through the ringer . <START>
# <POS> <CON_START> it is to ,  but honestly i rarely it . <START>
# <POS> <CON_START> hand can be a mess to ,  especially under the handle . <START>
# <POS> <CON_START> the price was ,  and came quickly though my prime membership . <START>
# <POS> <CON_START> for my purpose this is the item . <START>
# <POS> <CON_START> we both use the num_num curve ,  which each use bluetooth version num_extend <START>
# <POS> <CON_START> case ,  to use and very . <START>
# <POS> <CON_START> need a car charger and it seems to do the job . <START>
# <POS> <CON_START> i recently purchased  white rice  for my dad who has diverticulitious . <START>
# <POS> <CON_START> this dish is the size and i having a lid . <START>
# <POS> <CON_START> unless you have very small or very large hands it is to use . <START>
# <POS> <CON_START> i have both a square and round i use this with . <START>
# <POS> <CON_START> i have had a experience with the customer support at . <START>
# <POS> <CON_START> much to my ,  the invisishield was but . <START>
# <POS> <CON_START> we that it can go straight from the top to the . <START>
# <POS> <CON_START> i thought about making cheese until ree drummond made some on her show . <START>
# <POS> <CON_START> it seems to be of very in its build . <START>
# <POS> <CON_START> may be it will become soft with use and then it should be . <START>
# <POS> <CON_START> it is the thing for for scalloped and chips . <START>
# <POS> <CON_START> it keeps it the coffee hot and for hours . <START>
# <POS> <CON_START> if you need a with this capacity num_extend  buy this one . <START>
# <POS> <CON_START> more creative than num_extend dont think so !  but still a product . <START>
# <POS> <CON_START> its that showtime rotisserrie ,  you set it and forget it . <START>
# <POS> <CON_START> in particular ,  the coating on this has been cheapened . <START>
# <POS> <CON_START> fits ,  cutouts are plsced where they should be . <START>
# <POS> <CON_START> i also the adjustable heat option for the warming plate . <START>
# <POS> <CON_START> it it pretty hardy ,  i haven t it yet . <START>
# <POS> <CON_START> i purchased two to mount horizontally under the shelves of my island . <START>
# <POS> <CON_START> these small cookie made uniform two inch cookies . <START>
# <POS> <CON_START> voice command is on this set than other ones i ve tried . <START>
# <POS> <CON_START> these seem to have the locking mechanism backwards . <START>
# <POS> <CON_START> get it ,  it s the price for sure . <START>
# <POS> <CON_START> fasy to keep and a real . <START>
# <POS> <CON_START> just make sure that you don t misplace the spout . <START>
# <POS> <CON_START> i received them as a christmas present and i them . <START>
# <POS> <CON_START> put num_num of water into the machine . <START>
# <POS> <CON_START> i use is for more than deep . <START>
# <POS> <CON_START> i sprinkle a little flour on the rolls before to prevent sticking . <START>
# <POS> <CON_START> it s almost putting the phone into a high end pair of . <START>
# <POS> <CON_START> we are ice cream lovers and fussy about the of ice cream . <START>
# <POS> <CON_START> also these attachment pieces are very to . <START>
# <POS> <CON_START> only was delifery was num_num days . <START>
# <POS> <CON_START> oh ,  and the battery life is pretty . <START>
# <POS> <CON_START> i dropped phone once and the case held up . <START>
# <POS> <CON_START> this ,  wasn t near as loud as some were saying . <START>
# <POS> <CON_START> these stoppers are very inexpensive and certainly do the job . <START>
# <POS> <CON_START> it makes it and neat to store and access all of your . <START>
# <POS> <CON_START> i went for this one over some of the less expensive ones . <START>
# <POS> <CON_START> up and in a reasonable amount of time . <START>
# <POS> <CON_START> short blades and longer give you the leverage you need for tough cutting . <START>
# <POS> <CON_START> ,  works well and fun to use on camping trips . <START>
# <POS> <CON_START> the otterbox defender series is by far the available . <START>
# <POS> <CON_START> this has worked well for the last few years . <START>
# <POS> <CON_START> but i the phone to be up higher on the windshield . recommended . <START>
# <POS> <CON_START> heavy ,  patterned glass ,  and very looking on the table . <START>
# <POS> <CON_START> however ,  up tons of can be quite time consuming . <START>
# <POS> <CON_START> i was to see it was still available . <START>
# <POS> <CON_START> very to put on ,  no bubbles whatsoever . <START>
# <POS> <CON_START> i was concerned for the price that these cups would be flimsy . <START>
# <POS> <CON_START> the complication is the of the phone . <START>
# <POS> <CON_START> i used this set with a toaster and with a camping . <START>
# <POS> <CON_START> you place all the ingredients into the maker . <START>
# <POS> <CON_START> i don t know how i ever managed without this devise . <START>
# <POS> <CON_START> but these are well their price . <START>
# <POS> <CON_START> i bought this to grind and sweeteners into a powder for . <START>
# <POS> <CON_START> it my phone very quickly and to full % battery . <START>
# <POS> <CON_START> well the money ,  wouldn t want to be without it . <START>
# <POS> <CON_START> i will have a phone without an otterbox again . <START>
# <POS> <CON_START> because it s made of iron ,  scorching is minimized . <START>
# <POS> <CON_START> i imagine it will make soups even than the old one as well . <START>
# <POS> <CON_START> very unit ,  to assemble and operate . <START>
# <POS> <CON_START> i ve been using this for months ,  and it very much . <START>
# <POS> <CON_START> it works as advertised so i m !   :   . <START>
# <POS> <CON_START> item arrived in num_num days in bulk packaging exactly j . <START>
# <POS> <CON_START> for the size ,  weight and price it is really it . <START>
# <POS> <CON_START> i just flipped the over ,  and there they were . <START>
# <POS> <CON_START> it holds the charge when my phone was brand new . <START>
# <POS> <CON_START> the same panel buttons are there but in a placement . <START>
# <POS> <CON_START> all in all ,  though ,  with the product . <START>
# <POS> <CON_START> finish is ,  and it makes french toast . <START>
# <POS> <CON_START> with grandchildren ,  this is the combination of colorful and functional . <START>
# <POS> <CON_START> it s also a size for a family of num_extend <START>
# <POS> <CON_START> i have been using this for num_num years . <START>
# <POS> <CON_START> i the oster ,  it does it claim to do . <START>
# <POS> <CON_START> either you will it ,  or you won t . <START>
# <POS> <CON_START> i really how this protector curves over the edge of the . <START>
# <POS> <CON_START> trash cans are pretty unexciting ,  but this one is . <START>
# <POS> <CON_START> much than block and tackle type hooks to store overhead . <START>
# <POS> <CON_START> it is not to or assemble . <START>
# <POS> <CON_START> this is a bit heavier and truly . <START>
# <POS> <CON_START> we have tried a few and had fun with them . <START>
# <POS> <CON_START> this is and to use . <START>
# <POS> <CON_START> i wouldn t trade them but this is a knife for the price . <START>
# <POS> <CON_START> it s very to use and very dependable . <START>
# <POS> <CON_START> i ve owned this crock for several years . <START>
# <POS> <CON_START> i think this case is a very phone case . <START>
# <POS> <CON_START> is a product though i d heard of it . <START>
# <POS> <CON_START> the unit itself rests a necklace around your neck . <START>
# <POS> <CON_START> but the back side looks as well . <START>
# <POS> <CON_START> it works and the coffee is just as !  . <START>
# <POS> <CON_START> it s a very at a reasonalbe price . <START>
# <POS> <CON_START> this knife more than met our expectations . <START>
# <POS> <CON_START> most wheels that i ve seen are much smaller . <START>
# <POS> <CON_START> fit for replacement in my num_num year old blender that still works . <START>
# <POS> <CON_START> i give it five stars for making eating so !  . <START>
# <POS> <CON_START> the daily challenge around here is keeping the fur to a minimum . <START>
# <POS> <CON_START> synching is simple ,  with no passwords or required . <START>
# <POS> <CON_START> a gas would be and a smooth probably much . <START>
# <POS> <CON_START> i the design and the colors . <START>
# <POS> <CON_START> very impressed than within a minute incorporated all ingredients to . <START>
# <POS> <CON_START> we often ,  hot and in it as well . <START>
# <POS> <CON_START> snug fit ,  with all the buttons and holes aligned . <START>
# <POS> <CON_START> yes ,  it is plastic ,  but not plastic . <START>
# <POS> <CON_START> i use this with afresh to my top . <START>
# <POS> <CON_START> doesn t get stuck on the rod some non rollers do . <START>
# <POS> <CON_START> i made flour that night for our mexican burrito dinner . <START>
# <POS> <CON_START> the surface is easier to than our other grills . <START>
# <POS> <CON_START> i feel i have a new phone . <START>
# <POS> <CON_START> plus its from amazon and amazon wouldn t put their name on . <START>
# <POS> <CON_START> another thing i really is that it does not have rivets . <START>
# <POS> <CON_START> on cleaning and the use of aluminum foil . <START>
# <POS> <CON_START> will leave a big orange smear on the surface . <START>
# <POS> <CON_START> once the lid closes ,  the goes away . <START>
# <POS> <CON_START> still it is a fun learning experience and so far so . <START>
# <POS> <CON_START> i did not have what i felt were expectations of this device . <START>
# <POS> <CON_START> i purchased the to replace a glass bodum press that broke . <START>
# <POS> <CON_START> white in the a couple of days longer . <START>
# <POS> <CON_START> i and you need sharp when . <START>
# <POS> <CON_START> it comes at a price and appears to be well made . <START>
# <POS> <CON_START> of course the german s call this sort of idea engineering . <START>
# <POS> <CON_START> i also that this as an indoor . <START>
# <POS> <CON_START> i may even give some as this holiday season . <START>
# <POS> <CON_START> its actually a little than the filter that came with the unit . <START>
# <POS> <CON_START> this is the i ve ever owned . <START>
# <NEG> <CON_START> if your had a kickstand on the plate it won t lock down . <START>
# <NEG> <CON_START> either than or the decided to do their own . <START>
# <NEG> <CON_START> the pair made in mexico is much . <START>
# <NEG> <CON_START> it looks i ve splashed glitter all over my . <START>
# <NEG> <CON_START> it was not as as our much cheaper model . <START>
# <NEG> <CON_START> so not that for leaving on at night . <START>
# <NEG> <CON_START> and ,  there were many things we liked about this . <START>
# <NEG> <CON_START> !  i had trouble getting it on with zero bubbles . <START>
# <NEG> <CON_START> did nt have time to it before christmas so bought another necklass . <START>
# <NEG> <CON_START> another num_num calories from the other num_num grams of . <START>
# <NEG> <CON_START> these are supposedly cotton ,  but they don t feel it . <START>
# <NEG> <CON_START> no comment on the since i have not used it yet . <START>
# <NEG> <CON_START> i will buy hamilton beach products again . <START>
# <NEG> <CON_START> the description on the website did not state that the were elastic . <START>
# <NEG> <CON_START> we re too to put together normal sounding sentences . <START>
# <NEG> <CON_START> this is not the money and the brand name is misleading . <START>
# <NEG> <CON_START> used to be fun ,  but that tradition ends here . <START>
# <NEG> <CON_START> the computer recognized the usb connection ,  but the moved . <START>
# <NEG> <CON_START> we have been treating our for months and finally got this . <START>
# <NEG> <CON_START> i bought this set for our toaster . <START>
# <NEG> <CON_START> my just isn t at all interested in these springs . <START>
# <NEG> <CON_START> since that time i have replaced the . <START>
# <NEG> <CON_START> surely not what was paid for it by half . <START>
# <NEG> <CON_START> once you one match ,  you ve them all . <START>
# <NEG> <CON_START> i products as a rule ,  so this was a . <START>
# <NEG> <CON_START> the original is the very definition of fun . <START>
# <NEG> <CON_START> the bar   which does not occur naturally . <START>
# <NEG> <CON_START> i couldn t stand the of in my apartment . <START>
# <NEG> <CON_START> first ,  i put them both under my simultaneously . <START>
# <NEG> <CON_START> not a product for conditioning even though it says it has butter . <START>
# <NEG> <CON_START> i would recommend this of money case . <START>
# <NEG> <CON_START> can t imagine how it acts when you heat style your . <START>
# <NEG> <CON_START> amazon was to give me a right away . <START>
# <NEG> <CON_START> it for no reason ,  got . <START>
# <NEG> <CON_START> i bought this for my boys a few years back . <START>
# <NEG> <CON_START> if you are sensitive to ,  this isn t for you . <START>
# <NEG> <CON_START> we ve tried num_num of these makers since jan num_extend <START>
# <NEG> <CON_START> i ll stick to my for now ,  thanks . <START>
# <NEG> <CON_START> i myself for falling for the james bond license and wasting $ <START>
# <NEG> <CON_START> don t buy this unless you replacing toasters . <START>
# <NEG> <CON_START> this cream will give you if you have sensitive . <START>
# <NEG> <CON_START> the is so i had to brush my . <START>
# <NEG> <CON_START> i am actually afraid to open the remaining . <START>
# <NEG> <CON_START> the product is not but it might just be the one i received . <START>
# <NEG> <CON_START> in that short time ,  he one wing off the . <START>
# <NEG> <CON_START> these definitely open up your and functionally work as advertised . <START>
# <NEG> <CON_START> i thought the was good; scuffy thinks otherwise . <START>
# <NEG> <CON_START> every product i own from them has failed or been a . <START>
# <NEG> <CON_START> then i put the cream on my feet especially around my and . <START>
# <NEG> <CON_START> you can go to any chain store and do . <START>
# <NEG> <CON_START> also the  free will  option is an absolute . <START>
# <NEG> <CON_START> if you are stir your ingredients  i . e . <START>
# <NEG> <CON_START> of course in most ,  shouldn t matter . <START>
# <NEG> <CON_START> i had it professionally installed at a local shop . <START>
# <NEG> <CON_START> this ring looked on out of the box . <START>
# <NEG> <CON_START> i figured this would be a alternative to use during the six weeks . <START>
# <NEG> <CON_START> i bought this for my num_num month old from for christmas . <START>
# <NEG> <CON_START> we purchased this so our daughter could have fun to with . <START>
# <NEG> <CON_START> i woke up with basically an oil slick on my . <START>
# <NEG> <CON_START> i felt i must have missed something if the reviews were so . <START>
# <NEG> <CON_START> i have purchased fairly holders from motorola and they lasted a while . <START>
# <NEG> <CON_START> i was surprised as the box seemed to be in shape . <START>
# <NEG> <CON_START> i was looking forward to this for a couple of num_extend <START>
# <NEG> <CON_START> i think i will and stick with wool gloves . <START>
# <NEG> <CON_START> showdown : of , it has too many glitches to count . <START>
# <NEG> <CON_START> if you have soft fair then by all means use these razors . <START>
# <NEG> <CON_START> she handed it back to me and picked up her knife . <START>
# <NEG> <CON_START> got all excited ,  but this taste nohthing honey at all . <START>
# <NEG> <CON_START> it way too easily and way too smoothly . <START>
# <NEG> <CON_START> there was at all to indicate that belkin manufactured this item . <START>
# <NEG> <CON_START> i do not this belt because of lack of material . <START>
# <NEG> <CON_START> too small and not the i expected . <START>
# <NEG> <CON_START> it just it around until the water evaporates into the air . <START>
# <NEG> <CON_START> with sliced cheese in lieu of french on a fruit and cheese plate . <START>
# <NEG> <CON_START> it didn t have the a lot complained of though . <START>
# <NEG> <CON_START> i put in a password but won t recoginize it . <START>
# <NEG> <CON_START> ,  the controls are so confusing that it gives me a . <START>
# <NEG> <CON_START> now i have a that i don t ever want to . <START>
# <NEG> <CON_START> nokia knows how to design a very interface . <START>
# <NEG> <CON_START> basically ,  this product is a on consumers . <START>
# <NEG> <CON_START> this is honestly the only case i ve thrown away in the . <START>
# <NEG> <CON_START> i ve had many lighters and this one might be the . <START>
# <NEG> <CON_START> its that its made in rather than china . <START>
# <NEG> <CON_START> this machine is no match for the new . <START>
# <NEG> <CON_START> it s the that drives multiplay into the ground . <START>
# <NEG> <CON_START> for one day only . and test this product on . <START>
# <NEG> <CON_START> product but from what i ve heard it does the job . <START>
# <NEG> <CON_START> drinking the coffee was slightly less unpleasent than the suggested it would be . <START>
# <NEG> <CON_START> it is then no lube because it gets soooo sticky . <START>
# <NEG> <CON_START> birds or . tried num_num different kinds of bird food . <START>
# <NEG> <CON_START> however ,  definitely does not work a new battery . <START>
# <NEG> <CON_START> what a !  learn from my mistake ,  do not buy . <START>
# <NEG> <CON_START> and still the focus was extremely soft or just plain . <START>
# <NEG> <CON_START> yes ,  they are light ,  and are not at all . <START>
# <NEG> <CON_START> there are companies that make biscuits with the activated charcoal in it . <START>
# <NEG> <CON_START> i ve learned that companies make varying degrees of . <START>
# <NEG> <CON_START> the real thing is nong noodle ramyun . <START>
# <NEG> <CON_START> this just doesn t have enough power to my and neck . <START>
# <NEG> <CON_START> with a couple of bucks you could make something a lot yourself . <START>
# <NEG> <CON_START> i had much luck with the other three pairs mentioned . <START>
# <NEG> <CON_START> it s i got an extension cord and male outlets on both ends . <START>
# <NEG> <CON_START> that is not to say that these are by any means . <START>
# <NEG> <CON_START> generally if a makes noise ,  i don t mind so much . <START>
# <NEG> <CON_START> there was almost i liked about this product . <START>
# <NEG> <CON_START> first of all ,  this will void whatever warranty you have with . <START>
# <NEG> <CON_START> and it is very possible that these are cables . <START>
# <NEG> <CON_START> but it didn t do anything for my . <START>
# <NEG> <CON_START> they in it about once a week ,  if that . <START>
# <NEG> <CON_START> to ataris credit ,  this was a bit fun . <START>
# <NEG> <CON_START> it not or exciting and it s annoying . <START>
# <NEG> <CON_START> i spent $ for the num_extend and overall it was not the cost . <START>
# <NEG> <CON_START> i can use a creamy on it . <START>
# <NEG> <CON_START> on what otherwise has been a reliable company with several other respectful products . <START>
# <NEG> <CON_START> my husband said it was obvious so i had to it . <START>
# <NEG> <CON_START> is very hard to use especially with an extended magazine . <START>
# <NEG> <CON_START> mind you the oem charger is not that at all . <START>
# <NEG> <CON_START> for the price tag ,  its to rave about . <START>
# <NEG> <CON_START> i won t give this to the new i m getting . <START>
# <NEG> <CON_START> i bought this for and fried  , and fried eggs . <START>
# <NEG> <CON_START> note that i got mine from an amazon store called  small  . <START>
# <NEG> <CON_START> i practically felt i away my money on this one . <START>
# <NEG> <CON_START> maybe it just needs in and some fitting . <START>
# <NEG> <CON_START> in num_num came out with this . <START>
# <NEG> <CON_START> i didn t have enough of them to . <START>
# <NEG> <CON_START> for me this was a most product . <START>
# <NEG> <CON_START> this is just a little too low . <START>
# <NEG> <CON_START> the lid is the part of the ensemble . <START>
# <NEG> <CON_START> this is due to the short lived cheaper they put in them . <START>
# <NEG> <CON_START> whatever the case ,  i couldn t be more with this purchase . <START>
# <NEG> <CON_START> these make little night lights for the kids . <START>
# <NEG> <CON_START> i ve not had this happen with my . <START>
# <NEG> <CON_START> first ,  there is about this to really write home about . <START>
# <NEG> <CON_START> the item was considerably different than pictured . <START>
# <NEG> <CON_START> i must find a way to them . <START>
# <NEG> <CON_START> does increase volume but does not feel to the touch . <START>
# <NEG> <CON_START> me too is a brand and make very . <START>
# <NEG> <CON_START> this offers unique and the are not raving about . <START>
# <NEG> <CON_START> very well designed and to figure out . <START>
# <NEG> <CON_START> this gives you no incentive to keep . <START>
# <NEG> <CON_START> would suggest using one of the bubblers amazon sells . <START>
# <NEG> <CON_START> this cord seemed a deal and got reviews . <START>
# <NEG> <CON_START> i had high for this product since i bruise easily . <START>
# <NEG> <CON_START> this is called cheating !  i expected canister with at least . <START>
# <NEG> <CON_START> it opens cans ok ,  but no than the old fashioned openers . <START>
# <NEG> <CON_START> i d rather be a little less healthy and a little more . <START>
# <NEG> <CON_START> try explaining to a two year old why her keeps  breaking  . <START>
# <NEG> <CON_START> the kids thought it was ,  but it got old pretty . <START>
# <NEG> <CON_START> does a very job with their led systems . <START>
# <NEG> <CON_START> they glued it together and shipped it out it seemed . <START>
# <NEG> <CON_START> they are cheerios ,  afterall ,  and we the original kind . <START>
# <NEG> <CON_START> it makes a farce out of a num_num num_extend <START>
# <NEG> <CON_START> both rub my raw and cause . <START>
# <NEG> <CON_START> while the is soft ,  it is not full . <START>
# <NEG> <CON_START> overall it is inconvenient to keep the and the unit . <START>
# <NEG> <CON_START> because these will greatly appreciate on the collector s market . <START>
# <NEG> <CON_START> gave it to someone named on her birthday . <START>
# <NEG> <CON_START> it took three years three and over twelve hundred dollars spent before success . <START>
# <NEG> <CON_START> the was and it worked very well when it worked . <START>
# <NEG> <CON_START> i have no padding of my own to offset hard . <START>
# <NEG> <CON_START> and i wanted them all to be to access . <START>
# <NEG> <CON_START> this is a and well made . <START>
# <NEG> <CON_START> ,  low chicom with even cheaper ring mounts . <START>
# <NEG> <CON_START> first of all i m not some . <START>
# <NEG> <CON_START> i started using xlear spray a few years ago . <START>
# <NEG> <CON_START> first ,  and surprising was that they have removeable inserts . <START>
# <NEG> <CON_START> however ,  i feel iv is most definitely not an improvement overall . <START>
# <NEG> <CON_START> avoid the heartache and titme of discs . <START>
# <NEG> <CON_START> lasted for two ,  during which i was the operator . <START>
# <NEG> <CON_START> very hard plastic and not that fun to with at all . <START>
# <NEG> <CON_START> i and any or naturally enhanced cheese snack . <START>
# <NEG> <CON_START> i have num_num bird hanging from poles in my front and back yard . <START>
# <NEG> <CON_START> don t your time or money on these jeans . <START>
# <NEG> <CON_START> not the fastest but than my other hot air brush . <START>
# <NEG> <CON_START> i it out because i can t take alcohol . <START>
# <NEG> <CON_START> after that you have to pay a . <START>
# <NEG> <CON_START> i will still continue to use products ,  just not this one . <START>
# <NEG> <CON_START> just reinstall the previous ghost and raven shield . <START>
# <NEG> <CON_START> all of them are ,  not even . <START>
# <NEG> <CON_START> i d suggest anyone looking to purchase products look into instead . <START>
# <NEG> <CON_START> thing filters for num_num gallon tanks are . <START>
# <NEG> <CON_START> i might it ,  but i need a can opener . <START>
# <NEG> <CON_START> instead i would recommend gentle and you will be . <START>
# <NEG> <CON_START> sugar is extremely and does absolutely for your body . <START>
# <NEG> <CON_START> the constriction on my caused him to sit . <START>
# <NEG> <CON_START> they would flip off or get hung up due to rolling wheels . <START>
# <NEG> <CON_START> one thing is the amazingly unit a . i . <START>
# <NEG> <CON_START> is just as ,  though thankfully not . <START>
# <NEG> <CON_START> i was after the first num_num minutes . <START>
# <NEG> <CON_START> i loved the food for my as you can read below . <START>
# <NEG> <CON_START> th product features and editorial review germany as the origin of manufacture . <START>
# <NEG> <CON_START> it didn t work for me hopefully other people will have luck . <START>
# <NEG> <CON_START> flavor :  it has some tangy notes ,  and overall not . <START>
# <NEG> <CON_START> mine is a piece of ,  as far as i am concerned . <START>
# <NEG> <CON_START> it is to invest in a set of brushes . <START>
# <NEG> <CON_START> i will have slight pain ,  no matter what . <START>
# <NEG> <CON_START> the material that it is made of is a dirt magnet . <START>
# <NEG> <CON_START> the directions were to follow but the of the easel was . <START>
# <NEG> <CON_START> of money ,  of time ,  of . <START>
# <NEG> <CON_START> too bulky and there are products out there in single units . <START>
# <NEG> <CON_START> does not give me any confidence in buying any of the discovery kids . <START>
# <NEG> <CON_START> decided to push it to live a whole num_num weeks sooner than that . <START>
# <NEG> <CON_START> it s not ,  it is not . <START>
# <NEG> <CON_START> num_extend has much ,  sound ,  slightly control . <START>
# <NEG> <CON_START> also the headphones do not feel on your head . <START>
# <NEG> <CON_START> claritin used to be the thing around . <START>
# <NEG> <CON_START> it really is they didn t take anything at all . <START>
# <NEG> <CON_START> i tried short of breaking the thing open . <START>
# <NEG> <CON_START> other reviews seemed more ,  but i just gave mine away . <START>
# <NEG> <CON_START> makes the ,  don t get me wrong . <START>
# <NEG> <CON_START> perhaps it won t rust ,  but upclose it looks a little . <START>
# <NEG> <CON_START> so i just thought maybe it ll help keep my away . <START>
# <NEG> <CON_START> its tollable but thats not the thing to say about headphones . <START>
# <NEG> <CON_START> my has started to become anxious at bedtime . <START>
# <NEG> <CON_START> i don t know why it has all the reviews . <START>
# <NEG> <CON_START> there were other included ,  but you really couldn t taste them . <START>
# <NEG> <CON_START> the of materials and workmanship is noticeably less . <START>
# <NEG> <CON_START> if you want a cheaper deal with companies that specialize in that category . <START>
# <NEG> <CON_START> is by and . <START>
# <NEG> <CON_START> it reminds me more of silly putty than of a . <START>
# <NEG> <CON_START> this is not at all expected from a respected brand sony . <START>
# <NEG> <CON_START> i found these very hard to put on . <START>
# <NEG> <CON_START> i tried hiding them in her food and in her . <START>
# <NEG> <CON_START> she didn t the handle of this one at all . <START>
# <NEG> <CON_START> well it made it a rubber band texture . <START>
# <NEG> <CON_START> i ll just stick with a mayo and skip the . <START>
# <NEG> <CON_START> i thought i was over charged once it was . <START>
# <NEG> <CON_START> after all the reviews i thought i d give this a try . <START>
# <NEG> <CON_START> as i expected to received candy that would last a long time . <START>
# <NEG> <CON_START> the cords are over a foot long after being taken in . <START>
# <NEG> <CON_START> so ,  this car looks cool and all but its not that . <START>
# <NEG> <CON_START> just hurry up and the darn song and move on for goodness sake . <START>
# <NEG> <CON_START> try it once and you won t think it s . <START>
# <NEG> <CON_START> it was supposed to be a complete . <START>
# <NEG> <CON_START> nevertheless ,  the lasts for num_num or num_num minutes tops . <START>
# <NEG> <CON_START> that they are from usa and not china !  . <START>
# <NEG> <CON_START> so far i am not at all . <START>
# <NEG> <CON_START> quite and they make you order so many . <START>
# <NEG> <CON_START> i will again purchase another where this is a requirement . <START>
# <NEG> <CON_START> really ,  it all does look wise . <START>
# <NEG> <CON_START> might have been ,  but just went over my . <START>
# <NEG> <CON_START> they have a medium pile lining that has more of a stiffer feel . <START>
# <NEG> <CON_START> it s too because they look they would keep my ears warm . <START>
# <NEG> <CON_START> when you place the eye attachment on you can get a mixed cut . <START>
# <NEG> <CON_START> i hated the color that was sent to me ,  pale beige . <START>
# <NEG> <CON_START> that s not what it felt with the original gel adhesive . <START>
# <NEG> <CON_START> because it is definitely not full price . <START>
# <NEG> <CON_START> i would not recommend this item for who . <START>
# <NEG> <CON_START> this is the i have come across in a long time . <START>
# <NEG> <CON_START> it is too because the ingredients looked to be . <START>
# <NEG> <CON_START> the feel of the wheel is and i the side scrolling feature . <START>
# <NEG> <CON_START> am very that i still can t wear my !  . <START>
# <NEG> <CON_START> this case looks but that s about it . <START>
# <NEG> <CON_START> it takes several passes through some types of to cut it . <START>
# <NEG> <CON_START> i hope it will be a choice . <START>
# <NEG> <CON_START> i that it uses ingredients but it was ineffective on my . <START>
# <NEG> <CON_START> most products are for caused by dry . <START>
# <NEG> <CON_START> this is a item that makes no sense at all . <START>
# <NEG> <CON_START> worked on older new england house with narrow staircase . <START>
# <NEG> <CON_START> i thought that all of the possibilities would be . <START>
# <NEG> <CON_START> it was all and had very little clam flavor . <START>
# <NEG> <CON_START> i was hoping for a bit than this from amazon . <START>
# <NEG> <CON_START> this case is cute however the is the only thing about it . <START>
# <NEG> <CON_START> i ve come to the conclusion that i ve my money . <START>
# <NEG> <CON_START> the pieces that i manages to salvage the birds refuse to touch . <START>
# <NEG> <CON_START> he enjoys this ,  but can get the out fairly quickly . <START>
# <NEG> <CON_START> how many times you the nazgul and how easily they are beaten . <START>
# <NEG> <CON_START> the entire thing fits in the palm of my s hand . <START>
# <NEG> <CON_START> the is more a vaseline stick . <START>
# <NEG> <CON_START> i guess it fails in the truth department on its . <START>
# <NEG> <CON_START> in this case ,  it s a big for num_extend <START>
# <NEG> <CON_START> i bought this product for feeding my num_num persian while on vacation . <START>
# <NEG> <CON_START> it is a performer when it comes to odor retention and . <START>
# <NEG> <CON_START> do not buy this product ! the photos are ,  misleading . <START>
# <NEG> <CON_START> armada lacks the epic of similar or even . <START>
# <NEG> <CON_START> it worked for the first couple of weeks then it just stopped completely . <START>
# <NEG> <CON_START> spend the extra bucks and get the chopat bands . <START>
# <NEG> <CON_START> unfortunately ,  not my nor my cell phone . <START>
# <NEG> <CON_START> i contacted the seller and was given a . <START>
# <NEG> <CON_START> the are most definitely improved over the previous version . <START>
# <NEG> <CON_START> it was almost yellow in the system . <START>
# <NEG> <CON_START> it does this to a very significant degree and is extremely to wear . <START>
# <NEG> <CON_START> there must be an engineering issue with the motor of the . <START>
# <NEG> <CON_START> the is declined quickly by heat exposure . <START>
# <NEG> <CON_START> the main flavor to come through is cinnamon and the slight of . <START>
# <NEG> <CON_START> i was also very at how quickly it drains the batteries . <START>
# <NEG> <CON_START> as the clock clicked by num_extend i still felt . <START>
# <NEG> <CON_START> ekobrew ,  the coffee stays in that bottom wedge section . <START>

# %%
# !cat amazon_test_result_v1.txt
# Out:
# very good price but this one harder to use than my cusinart . <END>
# replaced my pampered chef press with this one . <END>
# quality and seems similar to apple products . <END>
# i have many oxo products , and i ve been pleased . <END>
# it turned out just to replace what i had lost . <END>
# love the way these roll instead of sliding on the rod . <END>
# they pile up in the closet and clean up in the dishwasher . <END>
# i had it a long time now and i still love it . <END>
# this offers really good protection for the phone . <END>
# this is one of the best vacuums i ve ever come across . <END>
# one minute per slice seems like a rule of thumb so far . <END>
# the metal is very sturdy and the non stick finish is great . <END>
# the flap also is sturdy and does not come loose at all . <END>
# sharp cutting edges make your knives look as good as they taste . <END>
# recently in the trash as the line wore out . <END>
# i have several of these , well worth it . <END>
# good charger , though there may be cheaper options . <END>
# so shipping takes a while but it is definitely worth the price . <END>
# blocking the red hot coils from my cookie sheets , and . <END>
# for about anything you want to shred , cut or mix . <END>
# the head set is quite good at least for me . <END>
# washing it is a breeze and just takes a second . <END>
# once glitch , which i did not view as all that . <END>
# i have had this mount for about a year and it works great . <END>
# but it s not for wireless , i ve had . <END>
# exactly what i need for my phone and at the price possible . <END>
# shipped free directly from presto and arrived within two days . <END>
# easy to put on and i have no problems . <END>
# this one is available at a great price with fair shipping here on amazon . <END>
# i almost except cucumber juice echhh . <END>
# one feature is that the head is removable for east cleaning . <END>
# auto shut off after num _ num hours , which is a great feature . <END>
# even after several days , they are air tight in a bottle . <END>
# i bought this in num _ num and the quality is still in good shape . <END>
# these come in with those tender special moments and thick ports welcome . <END>
# both english and metric measurements are embossed onto each . <END>
# and it ll keep rice and hot for up to num _ num hours . <END>
# it keeps the air fresh and smelling . <END>
# belt works great and installed in just a few minutes . <END>
# they were cheap and they work great i like them a lot thank you . <END>
# mine fit perfectly on my linen closet door with no securing necessary . <END>
# very happy with a selection of sizes . <END>
# i ve come to the conclusion that i ve wasted my money . <END>
# the pieces that i manages to salvage the birds refuse to touch . <END>
# he enjoys this toy , but can get the toy out fairly quickly . <END>
# how many times you play the music switch wrote blend and how easily they are beaten . <END>
# the entire thing fits in the palm of my mouse s hand . <END>
# the smell is more like a vaseline stick . <END>
# i guess it fails in the truth department on its face . <END>
# in this case , it s a big disappointment for num _ extend <END>
# i bought this product for feeding my num _ num persian cat while on vacation . <END>
# it is a great performer when it comes to odor retention and smells . <END>
# do not buy this product ! the photos are cheap , misleading . <END>
# staple lacks the epic of similar or even . <END>
# it worked for the first couple of weeks then it just stopped completely . <END>
# spend the extra bucks and get the chopat bands . <END>
# unfortunately , not my nor my cell phone . <END>
# i contacted the seller and was given a refund . <END>
# the graphics are most definitely improved over the previous version . <END>
# it was almost yellow in the system . <END>
# it does this to a very significant degree and is extremely uncomfortable to wear . <END>
# there must be an engineering issue with the motor of the pan . <END>
# the quality is declined quickly by heat exposure . <END>
# the main flavor to come through is cinnamon and the slight of protein . <END>
# i was also very disappointed at how quickly it drains the batteries . <END>
# as the clock clicked by num _ extend i still felt . <END>
# ekobrew , the coffee stays in that bottom wedge section . <END>

# %%
from torchnlp.metrics import get_moses_multi_bleu

# %%
hypotheses = []
reference = []

# %%
with open(os.path.join(os.getcwd(), './amazon_test_result_v1.txt')) as fp1:
    hypotheses = fp1.readlines()
with open(TEST_REF_FILE_PATH) as fp1:
    reference = fp1.readlines()

# %%
reference = list(map(lambda x: x.strip(), reference))
reference
# Out:
# ['very good price but this one harder to use than my cusinart .',
#  'replaced my pampered chef garlic press with this one .',
#  'durable and seems similar quality to apple products .',
#  'i have many oxo products ,  and i ve always been pleased .',
#  'it turned out just fine to replace what i had lost .',
#  'love the way these roll instead of sliding on the rod .',
#  'they pile up nice in the closet and clean up great in the dishwasher .',
#  'i had it a long time now and i still love it .',
#  'this offers really good protection for the phone .',
#  'this is one of the best vacuums i ve ever come across .',
#  'one minute per slice seems like a good rule of thumb so far .',
#  'the metal is very sturdy and the non stick finish is great .',
#  'the flap also is good and does not come loose at all .',
#  'sharp cutting edges make your pies look as good as they taste .',
#  'recently threw in the trash as the line wore out .',
#  'i have several of these ,  well worth it .',
#  'great charger ,  though there may be cheaper options .',
#  'so shipping takes a while but it is definitely worth the price .',
#  'blocking the red hot coils from my cookie sheets ,  and glassware .',
#  'great for about anything you want to shred ,  cut or mix .',
#  'the head set is quite comfortable  at least for me  .',
#  'washing it is a breeze and just takes a second .',
#  'once glitch ,  which i did not view as all that negative .',
#  'i have had this mount for about a year and it works great .',
#  'but it s not bad for wireless ,  i ve had worse .',
#  'exactly what i need for my phone and at the best price possible .',
#  'shipped free directly from realook and arrived within two days .',
#  'easy to put on and i have no problems .',
#  'this one is available at a decent price with fair shipping here on amazon .',
#  'i like almost everything except cucumber juice  echhh  .',
#  'one great feature is that the spatula head is removable for east cleaning .',
#  'auto shut off after num_num hours ,  which is a good feature .',
#  'even after several days ,  they are air tight in a wine bottle .',
#  'i bought this in num_num and the pan is still in great shape .',
#  'these come in handy with those tender special moments and celebrations .',
#  'both english and metric measurements are embossed onto each spoon .',
#  'and it ll keep rice perfect and hot for up to num_num hours .',
#  'it keeps the air clean and nice fresh smelling .',
#  'belt works fine and installed in just a few minutes .',
#  'they were awesome and they work great i like them a lot thank you .',
#  'mine fit perfectly on my linen closet door with no securing necessary .',
#  'very sturdy with a good selection of teeth sizes .',
#  'i use it a lot ,  and it never gave me any problem .',
#  'the handle is comfortable and holds the pitchers securely in your hands .',
#  'that said ,  the mic did pic up everything it could .',
#  'i just bought a num_extend cubic ft chest freezer .',
#  'no more oil on my hands when cooking up a steak or falafel .',
#  'it works great and i am very happy with it .',
#  'the shipping charges are now lower and upfront on the order .',
#  'i can t believe how beautiful and substantial this ice cream maker is .',
#  'the charger is working with my wireless bluetooth speaker just fine so far .',
#  'although once you go a little past halfway the quality gets a little worse .',
#  'i m starting to hate it because i don t need to upgrade .',
#  'i guess you could say so what it s a ladle .',
#  'fast; better than a blender and is easy to use .',
#  'overall i love them ,  and would probably buy them again .',
#  'i have been extremely happy with my purchase .',
#  'the glass cuisinart lids would pour water everywhere in a wet mess .',
#  'i am glad that i did not spend a fortune on the electric models .',
#  'it s very simple and takes up very little space on the pot rack .',
#  'fill the pan half way with water ,  and put it to boil .',
#  'comes with a  towel  to clean the phone before placement .',
#  'like i said ,  it works ,  these are ok .',
#  'seems to working fine in my mother s humidifier .',
#  'mediocre results until hitting upon a great cookbook .',
#  'on the other hand for power grating you ve got something here .',
#  'great headset ,  solid build quality and blocks out the wind .',
#  'i am so glad we chose this one .',
#  'we use these alot and they work great .',
#  'i say that after trying many cheap pathetic headsets ,  sigh .',
#  'i pretreated the worst stains withwoolite pet stain .',
#  'i have dropped the phone onto a tile floor and it is fine .',
#  'the la prima ran about half a shot then choked the machine .',
#  'however ,  this is an example of how rosle got it right .',
#  'it fulfills my modest requirements ,  and exceeds my expectations in appearance .',
#  'look up videos on swype if you want to see it in action .',
#  'i like that is is durable and washable .',
#  'the aluminum ones get stained and ugly after a few uses .',
#  'place it in the freezer and close the door .',
#  'open carefully and handle the zippers with care .',
#  'it had a great cost and a great product .',
#  'it stays stable in your ear very nicely and is surprisingly very comfortable .',
#  'this headset is awesome ,  the sound quality is truly amazing .',
#  'nothing bad to say about this wonderful innovation at all .',
#  'it stay clean and does not collect food stains .',
#  'i never have problems answering the phone this way with my blackberry .',
#  'easy to apply and it works very well .',
#  'i wore my first one out by pouring hot gravies in it .',
#  'also ,  don t use that yellow cloth to clean your phone .',
#  'doesn t really reduce the fat anymore than most cooking methods .',
#  'the cookbook that comes with it is adequate .',
#  'i have read reviews from wine experts that it doesn t work .',
#  'then along came this zester which i use constantly .',
#  'i recommand smaller size for everyday use . but i like this pan .',
#  'toasts bread ,  muffins and bagels with lots of options to choose .',
#  'tastes in between the classic american blonde ale and cowboy golden lager .',
#  'put homemade pizza sauce on top then add pepperoni and fresh mushrooms .',
#  'this is the old faithful water filter pitcher .',
#  'we use a bread machine to prepare the dough and provide the first rise .',
#  'i ve been happy with most oxo products i ve purchased .',
#  'it s good to go the next morning ,  completely clean .',
#  'other than that small problem ,  this is a great bt headdest .',
#  'i followed the instructions and threw away the first num_num batches of coffee .',
#  'so i purchased another knife sharpener for this our num_num yankee swap .',
#  'blade release buttons are simple to use which makes cleaning easy .',
#  ': pi also have limited space in my kitchen .',
#  'i also love it because the jar is plastic .',
#  'you ve probably seen them use it on iron chef .',
#  'it would have been perfect if it was a tad bit smaller .',
#  'all came well sharpened and ready to go .',
#  'this cuts down on waste and you don t have to ingest harmful propellants .',
#  'games like gem journey are easier to play with a stylus like this .',
#  'it is great if you have more than one guest to serve .',
#  'i made beef bolognese in the oven and it turned out wonderfully .',
#  'making seperation and cross contamination containment a very easy .',
#  'the roomba just thinks it s furniture and doesn t go up on it .',
#  'the measuring spoons would make a great stocking stuffer for any kitchen queen .',
#  'the zester was easy enough to clean after use .',
#  'but for now ,  i m quite happy with this .',
#  'perfect size for preparing dishes . it really works well .',
#  'this product is being used for dollar size pancakes .',
#  'love it !  really handy to set by the stove .',
#  'i m a fan of symbian and find it easy to operate .',
#  'plugs the ipad into my car and works great .',
#  'i like it better than any of the forman items .',
#  'once it dies i will purchase a better unit .',
#  'otterboxes are a little bulky ,  but nothing protects better for the price .',
#  'this style of meat pounder is sort of commodity like .',
#  'nice not to have a burner going for hours .',
#  'this unit makes the best french fries i ve ever made .',
#  'it works with all types ,  but works best with roma tomatoes .',
#  'careful when using steak knives however because they will scratch these plates .',
#  'it s still going great ,  i just needed more capacity .',
#  'also ,  the knife is easy to maneuver despite its length .',
#  'for the price ,  this is a good buy .',
#  'and it s a bread knife and nothing all that special .',
#  'i used to use a good cooks brand safety opener and really liked it .',
#  'then both of them go into the dishwasher .',
#  'i love my lodge omelet pan and use it almost every morning .',
#  'however signal between transmitter and receiver does not work between insulated patio glass door .',
#  'this pan i have had for one year .',
#  'i do seem to need to invest in some better popcorn .',
#  'bento spoon and the boker knife which is quite nice .',
#  'i finally made he purchase and am glad i did .',
#  'coming from an asian background it s not something we normally cook with .',
#  'i liked this and was happy with my purchase .',
#  'we juiced our garden lettuce and greens with ease .',
#  'anyway i recommend this one for its price and quality .',
#  'i put my kitchen appliances through the ringer .',
#  'it is easy to clean ,  but honestly i rarely clean it .',
#  'hand graters can be a mess to clean ,  especially under the handle .',
#  'the price was good ,  and came quickly though my prime membership .',
#  'for my purpose this is the perfect item .',
#  'we both use the blackberry num_num curve ,  which each use bluetooth version num_extend',
#  'great case ,  easy to use and very durable .',
#  'need a cheap car charger and it seems to do the job .',
#  'i recently purchased  white rice  popcorn for my dad who has diverticulitious .',
#  'this casserole dish is the perfect size and i love having a nice lid .',
#  'unless you have very small or very large hands it is comfortable to use .',
#  'i have both a square and round pan i use this with .',
#  'i have never had a pleasant experience with the customer support at cuisnart .',
#  'much to my dismay ,  the invisishield was nothing but garbage .',
#  'we love that it can go straight from the stove top to the oven .',
#  'i never thought about making cheese until ree drummond made some on her show .',
#  'it seems to be of very good quality in its build .',
#  'may be it will become soft with use and then it should be fine .',
#  'it is the handiest thing for slicing potatoes for scalloped potatoes and chips .',
#  'it keeps it the coffee hot and fresh for hours .',
#  'if you need a pot with this capacity num_extend qts  buy this one .',
#  'more creative than num_extend dont think so !  but still a great product .',
#  'its like that showtime rotisserrie oven ,  you set it and forget it .',
#  'in particular ,  the coating on this cookware has been cheapened .',
#  'fits perfectly ,  cutouts are plsced where they should be .',
#  'i also like the adjustable heat option for the warming plate .',
#  'it it pretty hardy ,  i haven t broken it yet .',
#  'i purchased two to mount horizontally under the shelves of my kitchen island .',
#  'these small cookie scoops made perfectly uniform two inch cookies .',
#  'voice command is better on this set than other ones i ve tried .',
#  'these tongs seem to have the locking mechanism backwards .',
#  'get it ,  it s worth the price for sure .',
#  'fasy to keep clean and a real treasure .',
#  'just make sure that you don t misplace the spout stopper .',
#  'i received them as a christmas present and i love them .',
#  'put num_num quart of water into the machine .',
#  'i use is for more than deep frying .',
#  'i sprinkle a little flour on the rolls before stamping to prevent sticking .',
#  'it s almost like putting the phone into a high end pair of socks .',
#  'we are ice cream lovers and fussy about the quality of ice cream .',
#  'also these attachment pieces are very easy to clean .',
#  'only negative was delifery was num_num days late .',
#  'oh ,  and the battery life is pretty decent .',
#  'i dropped phone once and the case held up perfectly .',
#  'love this mixer ,  wasn t near as loud as some were saying .',
#  'these wine stoppers are very inexpensive and certainly do the job .',
#  'it makes it easy and neat to store and access all of your scarves .',
#  'glad i went for this one over some of the less expensive ones .',
#  'cleans up nice and cooks waffles in a reasonable amount of time .',
#  'short blades and longer handles give you the leverage you need for tough cutting .',
#  'great dutch oven ,  works well and fun to use on camping trips .',
#  'the otterbox defender series is by far the best available .',
#  'this turner has worked well for the last few years .',
#  'but i like the phone to be up higher on the windshield . recommended .',
#  'heavy ,  patterned glass ,  and very classy looking on the table .',
#  'however ,  slicing up tons of veggies can be quite time consuming .',
#  'i was glad to see it was still available .',
#  'very easy to put on ,  no bubbles whatsoever .',
#  'i was concerned for the price that these measuring cups would be flimsy .',
#  'the complication is the heft of the phone .',
#  'i used this set with a toaster oven and with a coleman camping oven .',
#  'you place all the ingredients into the bread maker .',
#  'i don t know how i ever managed without this handy devise .',
#  'but these knives are well worth their price .',
#  'i bought this to grind xylitol and truvia sweeteners into a powder for cooking .',
#  'it charges my phone very quickly and to full % battery .',
#  'well worth the money ,  wouldn t want to be without it .',
#  'i will never have a phone without an otterbox again .',
#  'because it s made of cast iron ,  scorching is minimized .',
#  'i imagine it will make soups even better than the old one as well .',
#  'very nice unit ,  easy to assemble and operate .',
#  'i ve been using this for months ,  and like it very much .',
#  'it works as advertised so i m happy !   :   .',
#  'item arrived in num_num days in bulk packaging exactly like j .',
#  'for the size ,  weight and price it is really worth it .',
#  'i just flipped the pan over ,  and there they were .',
#  'it holds the charge like when my phone was brand new .',
#  'the same panel buttons are there but in a better placement .',
#  'all in all ,  though ,  happy with the product .',
#  'finish is great ,  and it makes great french toast .',
#  'with grandchildren ,  this is the perfect combination of colorful and functional .',
#  'it s also a good size for a family of num_extend',
#  'i have been using this grill for num_num years .',
#  'i like the oster steamer ,  it does everything it claim to do .',
#  'either you will like it ,  or you won t .',
#  'i really like how this counter protector curves over the edge of the counter .',
#  'trash cans are pretty unexciting ,  but this one is awfully nice .',
#  'much better than block and tackle type hooks to store overhead .',
#  'it is not difficult to clean or assemble .',
#  'this pan is a bit heavier and truly nonstick .',
#  'we have tried a few recipes and had fun with them .',
#  'this salad spinner is durable and easy to use .',
#  'i wouldn t trade them but this is a great knife for the price .',
#  'it s very easy to use and very dependable .',
#  'i ve owned this crock pot for several years .',
#  'i think this case is a very nice phone case .',
#  'anker is a fine product though i d never heard of it .',
#  'the unit itself rests like a necklace around your neck .',
#  'but the back side looks nice as well .',
#  'it works fine and the coffee is just as great !  .',
#  'it s a very good quality at a reasonalbe price .',
#  'this knife sharpener more than met our expectations .',
#  'most pizza wheels that i ve seen are much smaller .',
#  'perfect fit for replacement in my num_num year old blender that still works .',
#  'i give it five stars for making eating good so easy !  .',
#  'the daily challenge around here is keeping the cat fur to a minimum .',
#  'synching is simple ,  with no passwords or codes required .',
#  'a gas cooktop would be worse and a smooth cooktop probably much better .',
#  'i love the floral design and the colors .',
#  'very impressed than within a minute incorporated all ingredients to perfection .',
#  'we often cook sausages ,  hot dogs and hamburgers in it as well .',
#  'snug fit ,  with all the buttons and holes perfectly aligned .',
#  'yes ,  it is plastic ,  but not cheap plastic .',
#  'i use this with afresh to clean my cook top .',
#  'doesn t get stuck on the rod like some non rollers do .',
#  'i made flour tortillas that night for our mexican burrito dinner .',
#  'the grill surface is easier to clean than our other grills .',
#  'i feel like i have a new phone .',
#  'plus its from amazon and amazon wouldn t put their name on crap .',
#  'another thing i really like is that it does not have rivets .',
#  'saves on cleaning and the use of aluminum foil .',
#  'carrots will leave a big orange smear on the surface .',
#  'once the lid closes ,  the smell goes away .',
#  'still it is a fun learning experience and so far so good .',
#  'i did not have what i felt were unrealistic expectations of this device .',
#  'i purchased the frieling to replace a glass bodum press that broke .',
#  'white in the refrigerator a couple of days longer .',
#  'i love cooking and you need sharp knives when cooking .',
#  'it comes at a good price and appears to be well made .',
#  'of course the german s call this sort of idea good engineering .',
#  'i also love that this griddle doubles as an indoor grill .',
#  'i may even give some as gifts this holiday season .',
#  'its actually a little better than the filter that came with the unit .',
#  'this is the best cookware i ve ever owned .',
#  'if your bike had a kickstand on the plate it won t lock down .',
#  'either than or the developers decided to do their own .',
#  'the pair made in mexico is much better .',
#  'it looks like i ve splashed glitter all over my face .',
#  'it was not as good as our much cheaper model .',
#  'so not that great for leaving on at night .',
#  'and ,  there were many things we liked about this game .',
#  'ridiculous !  i had trouble getting it on with zero bubbles .',
#  'did nt have time to return it before christmas so bought another necklass .',
#  'another num_num calories from the other num_num grams of carbohydrates .',
#  'these are supposedly cotton ,  but they don t feel like it .',
#  'no comment on the strainer since i have not used it yet .',
#  'i will never buy hamilton beach products again .',
#  'the description on the website did not state that the straps were elastic .',
#  'we re too stupid to put together normal sounding sentences .',
#  'this is not worth the money and the brand name is misleading .',
#  'spyro games always used to be fun ,  but that tradition ends here .',
#  'the computer recognized the usb connection ,  but the cursor never moved .',
#  'we have been treating our hair for months and finally got this .',
#  'i bought this set for our toaster oven .',
#  'my cat just isn t at all interested in these springs .',
#  'since that time i have replaced the game .',
#  'surely not worth what was paid for it by half .',
#  'once you play one match ,  you ve played them all .',
#  'i like neutrogena products as a rule ,  so this was a disappointment .',
#  'the original unreal tournament is the very definition of fun .',
#  'the bar contains  agave nectar  which does not occur naturally .',
#  'i couldn t stand the persistent smell of feces in my apartment .',
#  'first ,  i put them both under my tongue simultaneously .',
#  'not a good product for conditioning even though it says it has shea butter .',
#  'i would never recommend this terrible waste of money case .',
#  'can t imagine how it acts when you heat style your hair .',
#  'amazon was good to give me a refund right away .',
#  'it crashed for no reason ,  saves got corrupted .',
#  'i bought this toy for my boys a few years back .',
#  'if you are sensitive to maltodextrin ,  this isn t for you .',
#  'we ve tried num_num of these waffle makers since jan num_extend',
#  'i ll stick to my xbox for now ,  thanks .',
#  'i hate myself for falling for the james bond license and wasting $',
#  'don t buy this unless you like replacing toasters .',
#  'this cream will give you acne if you have sensitive skin .',
#  'the aftertaste is so overpowering i had to brush my teeth .',
#  'i am actually afraid to open the remaining jars .',
#  'the product is not durable but it might just be the one i received .',
#  'in that short time ,  he ripped one wing off the toy .',
#  'these definitely open up your nasal passages and functionally work as advertised .',
#  'i thought the concept was good; scuffy thinks otherwise .',
#  'every product i own from them has failed or been a letdown .',
#  'then i put the cream on my feet especially around my toes and heels .',
#  'you can go to any chain store and do better .',
#  'also the  free will  option is an absolute joke .',
#  'if you are stir frying your ingredients  i . e .',
#  'of course in most sports games ,  graphics shouldn t matter .',
#  'i had it professionally installed at a local bike shop .',
#  'this ring looked beautiful on out of the box .',
#  'i figured this would be a great alternative to use during the six weeks .',
#  'i bought this for my num_num month old from santa for christmas .',
#  'we purchased this so our daughter could have fun toy to play with .',
#  'i woke up with basically an oil slick on my face .',
#  'i felt i must have missed something if the reviews were so good .',
#  'i have purchased fairly cheap holders from motorola and they lasted a while .',
#  'i was surprised as the box seemed to be in good shape .',
#  'i was looking forward to this game for a couple of num_extend',
#  'i think i will return and stick with wool gloves .',
#  'like showdown : legends of wrestling , it has too many glitches to count .',
#  'if you have soft facial fair then by all means use these razors .',
#  'she handed it back to me and picked up her ginsu knife .',
#  'got all excited ,  but this taste nohthing like honey at all .',
#  'it scrolls way too easily and way too smoothly .',
#  'there was nothing at all to indicate that belkin manufactured this item .',
#  'i do not like this belt because of lack of material .',
#  'too small and not the quality i expected .',
#  'it just smears it around until the water evaporates into the air .',
#  'with sliced cheese in lieu of french bread on a fruit and cheese plate .',
#  'it didn t have the smell a lot complained of though .',
#  'i put in a password but router won t recoginize it .',
#  'worse ,  the controls are so confusing that it gives me a headache .',
#  'now i have a game that i don t ever want to play .',
#  'nokia knows how to design a very good interface .',
#  'basically ,  this product is a ripoff on consumers .',
#  'this is honestly the only case i ve thrown away in the garbage .',
#  'i ve had many lighters and this one might be the best .',
#  'its good that its made in canada rather than china .',
#  'this machine is no match for the new consoles .',
#  'it s the lame players that drives halo multiplay into the ground .',
#  'good for one day only . and opi test this product on animals .',
#  'returned product but from what i ve heard it does the job .',
#  'drinking the coffee was slightly less unpleasent than the smell suggested it would be .',
#  'it is worse then no lube because it gets soooo sticky .',
#  'birds or squirrels . tried num_num different kinds of bird food .',
#  'however ,  definitely does not work like a new battery .',
#  'what a ripoff !  learn from my mistake ,  do not buy .',
#  'and still the focus was extremely soft or just plain terrible .',
#  'yes ,  they are light ,  and are not durable at all .',
#  'there are companies that make dog biscuits with the activated charcoal in it .',
#  'i ve learned that companies make varying degrees of quality .',
#  'the real thing is nong shim shin noodle ramyun .',
#  'this just doesn t have enough power to massage my shoulders and neck .',
#  'with a couple of bucks you could make something a lot better yourself .',
#  'i had much better luck with the other three pairs mentioned .',
#  'it s like i got an extension cord and male outlets on both ends .',
#  'that is not to say that these treats are bad by any means .',
#  'generally if a toy makes noise ,  i don t mind so much .',
#  'there was almost nothing i liked about this product .',
#  'first of all ,  this will void whatever warranty you have with microsoft .',
#  'and it is very possible that these are good cables .',
#  'but it didn t do anything for my face .',
#  'they pee in it about once a week ,  if that .',
#  'to ataris credit ,  this game was a bit fun .',
#  'it not educational or exciting and it s annoying .',
#  'i spent $ for the num_extend and overall it was not worth the cost .',
#  'i can use a creamy concealer on it .',
#  'shame on what otherwise has been a reliable company with several other respectful products .',
#  'my husband said it was obvious so i had to return it .',
#  'speedloader is very hard to use especially with an extended magazine .',
#  'mind you the oem xoom charger is not like that at all .',
#  'for the price tag ,  its nothing to rave about .',
#  'i won t give this to the new puppy i m getting .',
#  'i bought this skillet for steaks and fried potatoes  , and fried eggs .',
#  'note that i got mine from an amazon store called  small appliance  .',
#  'i practically felt like i threw away my money on this one .',
#  'maybe it just needs broken in and some fine fitting .',
#  'in num_num thq came out with this wrestling game .',
#  'i didn t have enough of them to return .',
#  'for me this was a most disappointing product .',
#  'this is just a little too low quality .',
#  'the lid is the best part of the pot ensemble .',
#  'this is due to the short lived cheaper lasers they put in them .',
#  'whatever the case ,  i couldn t be more unhappy with this purchase .',
#  'these make great little night lights for the kids .',
#  'i ve not had this happen with my wusthofs .',
#  'first ,  there is nothing about this to really write home about .',
#  'the item was considerably different quality than pictured .',
#  'i must find a way to return them .',
#  'does increase volume but does not feel nice to the touch .',
#  'me too is a nice brand and make very comfortable shoes .',
#  'this game offers nothing unique and the graphics are not worth raving about .',
#  'very well designed and easy to figure out .',
#  'this game gives you no incentive to keep playing .',
#  'would suggest using one of the toy bubblers amazon sells .',
#  'this cord seemed like a deal and got good reviews .',
#  'i had high hopes for this product since i bruise easily .',
#  'this is called cheating !  i expected canister with fuel at least .',
#  'it opens cans ok ,  but no better than the old fashioned openers .',
#  'i d rather be a little less healthy and a little more happy .',
#  'try explaining to a two year old why her tattoo keeps  breaking  .',
#  'the kids thought it was great ,  but it got old pretty quick .',
#  'marineland does a very good job with their led aquarium systems .',
#  'like they glued it together and shipped it out it seemed .',
#  'they are cheerios ,  afterall ,  and we love the original kind .',
#  'it makes a farce out of a good num_num num_extend',
#  'both rub my dog raw and cause bleeding .',
#  'while the mascara is soft ,  it is not full .',
#  'overall it is inconvenient to keep the counter and the unit clean .',
#  'because these knives will greatly appreciate on the collector s market .',
#  'gave it to someone named happy on her birthday .',
#  'it took three years three vets and over twelve hundred dollars spent before success .',
#  'the concept was great and it worked very well when it worked .',
#  'i have no padding of my own to offset hard soles .',
#  'and i wanted them all to be easy to access .',
#  'this is a good hoodie and well made .',
#  'cheap ,  low quality chicom scope with even cheaper ring mounts .',
#  'first of all i m not some raging halo .',
#  'i started using xlear nasal spray a few years ago .',
#  'first ,  and surprising was that they have removeable sole inserts .',
#  'however ,  i feel civilization iv is most definitely not an improvement overall .',
#  'avoid the heartache and wasted titme of bad discs .',
#  'lasted for two games ,  during which i was the sole operator .',
#  'very hard plastic and not that fun to play with at all .',
#  'i love cheetos and any artificially or naturally enhanced cheese snack .',
#  'i have num_num bird feeders hanging from poles in my front and back yard .',
#  'don t waste your time or money on these jeans .',
#  'not the fastest but better than my other hot air brush .',
#  'i threw it out because i can t take alcohol .',
#  'after that you have to pay a subscription .',
#  'i will still continue to use philosophy products ,  just not this one .',
#  'just reinstall the previous ghost recon and raven shield games .',
#  'all of them are utter garbage ,  not even decent polyester .',
#  'i d suggest anyone looking to purchase linksys products look into netgear instead .',
#  'good thing filters for num_num gallon tanks are cheap .',
#  'i might return it ,  but i need a can opener .',
#  'instead i would recommend cetaphil gentle cleanser and you will be fine .',
#  'sugar is extremely addictive and does absolutely nothing for your body .',
#  'the constriction on my dog caused him to sit .',
#  'they would flip off or get hung up due to poorly rolling wheels .',
#  'one thing is the amazingly poor unit a . i .',
#  'multiplayer is just as bad ,  though thankfully not worse .',
#  'i was bored after the first num_num minutes .',
#  'i loved the food for my cats as you can read below .',
#  'th product features and editorial review spell germany as the origin of manufacture .',
#  'it didn t work for me hopefully other people will have better luck .',
#  'flavor :  it has some tangy notes ,  and overall not bad .',
#  'mine is a piece of junk ,  as far as i am concerned .',
#  'it is best to invest in a good set of makeup brushes .',
#  'i will always have slight pain ,  no matter what .',
#  'the material that it is made of is like a dirt magnet .',
#  'the directions were easy to follow but the quality of the easel was pathetic .',
#  'waste of money ,  waste of time ,  waste of blood .',
#  'too bulky and there are better products out there in single units .',
#  'does not give me any confidence in buying any of the discovery kids toys .',
#  'soe decided to push it to live a whole num_num weeks sooner than that .',
#  'it s not overpowering ,  it is not like perfume .',
#  'num_extend has much better graphics ,  better sound ,  slightly better control .',
#  'also the headphones do not feel comfortable on your head .',
#  'claritin used to be the best thing around .',
#  'it really is like they didn t take anything at all .',
#  'i tried everything short of breaking the thing open .',
#  'other reviews seemed more positive ,  but i just gave mine away .',
#  'crayola makes the best crayons ,  don t get me wrong .',
#  'perhaps it won t rust ,  but upclose it looks a little cheesey .',
#  'so i just thought maybe it ll help keep my acne away .',
#  'its tollable but thats not the best thing to say about headphones .',
#  'my dog has started to become anxious at bedtime .',
#  'i don t know why it has all the good reviews .',
#  'there were other vegetables included ,  but you really couldn t taste them .',
#  'the quality of materials and workmanship is noticeably less .',
#  'if you want a cheaper sub deal with companies that specialize in that category .',
#  'enfamil infant is characterized by choline and dha .',
#  'it reminds me more of silly putty than of a concealer .',
#  'this is not at all expected from a respected brand like sony .',
#  'i found these patches very hard to put on .',
#  'i tried hiding them in her food and in her treats .',
#  'she didn t like the handle of this one at all .',
#  'well it made it worse like a rubber band texture .',
#  'i ll just stick with a good mayo and skip the bacon .',
#  'i thought i was over charged once it was returned .',
#  'after all the great reviews i thought i d give this a try .',
#  'disappointed as i expected to received candy that would last a long time .',
#  'the waist cords are over a foot long after being taken in .',
#  'so ,  this car looks cool and all but its not that great .',
#  'just hurry up and play the darn song and move on for goodness sake .',
#  'try it once and you won t think it s stupid .',
#  'it was supposed to be a complete toy .',
#  'nevertheless ,  the smell lasts for num_num or num_num minutes tops .',
#  'good that they are from usa and not china !  .',
#  'so far i am not at all happy .',
#  'quite tasteless and they make you order so many .',
#  'i will never again purchase another game where this is a requirement .',
#  'really ,  it all does look nice graphically wise .',
#  'might have been nice ,  but just went over my cheeks .',
#  'they have a medium pile lining that has more of a stiffer polyester feel .',
#  'it s too bad because they look like they would keep my ears warm .',
#  'when you place the eye brow attachment on you can get a mixed cut .',
#  'i hated the color that was sent to me ,  pale chalky beige .',
#  'that s not what it felt like with the original gel adhesive .',
#  'because it is definitely not worth full price .',
#  'i would not recommend this item for dogs who chew .',
#  'this is the worst game i have come across in a long time .',
#  'it is too bad because the ingredients looked to be quality .',
#  'the feel of the wheel is nice and i like the side scrolling feature .',
#  'am very disappointed that i still can t wear my shoes !  .',
#  'this case looks nice but that s about it .',
#  'it takes several passes through some types of hair to cut it .',
#  'i hope it will be a better choice .',
#  'i love that it uses natural ingredients but it was ineffective on my skin .',
#  'most products are for dandruff caused by dry scalp .',
#  'this is a worthless item that makes no sense at all .',
#  'worked best on older new england house with narrow staircase .',
#  'i thought that all of the possibilities would be awesome .',
#  'it was all potatoes and had very little clam flavor .',
#  'i was hoping for a bit better than this from amazon .',
#  'this case is cute however the is the only good thing about it .',
#  'i ve come to the conclusion that i ve wasted my money .',
#  'the good pieces that i manages to salvage the birds refuse to touch .',
#  'he enjoys this toy ,  but can get the treats out fairly quickly .',
#  'like how many times you face the nazgul and how easily they are beaten .',
#  'the entire thing fits in the palm of my child s hand .',
#  'the balm is crap more like a vaseline stick .',
#  'i guess it fails in the truth department on its advertising .',
#  'in this case ,  it s a big disappointment for num_extend',
#  'i bought this product for feeding my num_num persian cats while on vacation .',
#  'it is a poor performer when it comes to odor retention and clumping .',
#  'do not buy this product ! the photos are horribly ,  horribly misleading .',
#  'armada lacks the epic scope of similar games like homeworld or even starcraft .',
#  'it worked great for the first couple of weeks then it just stopped completely .',
#  'spend the extra bucks and get the chopat knee bands .',
#  'unfortunately ,  not my blackberry nor my cell phone .',
#  'i contacted the seller and was given a refund .',
#  'the graphics are most definitely improved over the previous version .',
#  'it was almost like pokemon yellow in the fighting system .',
#  'it does this to a very significant degree and is extremely uncomfortable to wear .',
#  'there must be an engineering issue with the motor of the toy .',
#  'the quality is declined quickly by heat exposure .',
#  'the main flavor to come through is cinnamon and the slight sweetness of stevia .',
#  'i was also very disappointed at how quickly it drains the batteries .',
#  'as the clock clicked by num_extend i still felt sluggish .',
#  'ekobrew ,  the coffee always stays in that bottom wedge section .']

# %%
hypotheses=list(map(lambda x: x.strip().replace('<END>',''), hypotheses))
hypotheses
# Out:
# ['very good price but this one harder to use than my cusinart . ',
#  'replaced my pampered chef press with this one . ',
#  'quality and seems similar to apple products . ',
#  'i have many oxo products , and i ve been pleased . ',
#  'it turned out just to replace what i had lost . ',
#  'love the way these roll instead of sliding on the rod . ',
#  'they pile up in the closet and clean up in the dishwasher . ',
#  'i had it a long time now and i still love it . ',
#  'this offers really good protection for the phone . ',
#  'this is one of the best vacuums i ve ever come across . ',
#  'one minute per slice seems like a rule of thumb so far . ',
#  'the metal is very sturdy and the non stick finish is great . ',
#  'the flap also is sturdy and does not come loose at all . ',
#  'sharp cutting edges make your knives look as good as they taste . ',
#  'recently in the trash as the line wore out . ',
#  'i have several of these , well worth it . ',
#  'good charger , though there may be cheaper options . ',
#  'so shipping takes a while but it is definitely worth the price . ',
#  'blocking the red hot coils from my cookie sheets , and . ',
#  'for about anything you want to shred , cut or mix . ',
#  'the head set is quite good at least for me . ',
#  'washing it is a breeze and just takes a second . ',
#  'once glitch , which i did not view as all that . ',
#  'i have had this mount for about a year and it works great . ',
#  'but it s not for wireless , i ve had . ',
#  'exactly what i need for my phone and at the price possible . ',
#  'shipped free directly from presto and arrived within two days . ',
#  'easy to put on and i have no problems . ',
#  'this one is available at a great price with fair shipping here on amazon . ',
#  'i almost except cucumber juice echhh . ',
#  'one feature is that the head is removable for east cleaning . ',
#  'auto shut off after num _ num hours , which is a great feature . ',
#  'even after several days , they are air tight in a bottle . ',
#  'i bought this in num _ num and the quality is still in good shape . ',
#  'these come in with those tender special moments and thick ports welcome . ',
#  'both english and metric measurements are embossed onto each . ',
#  'and it ll keep rice and hot for up to num _ num hours . ',
#  'it keeps the air fresh and smelling . ',
#  'belt works great and installed in just a few minutes . ',
#  'they were cheap and they work great i like them a lot thank you . ',
#  'mine fit perfectly on my linen closet door with no securing necessary . ',
#  'very happy with a selection of sizes . ',
#  'i use it a lot , and it gave me any problem . ',
#  'the handle is comfortable and holds the pitchers securely in your hands . ',
#  'that said , the mic did pic up it could . ',
#  'i just bought a num _ extend ft chest . ',
#  'no more oil on my hands when cooking up a wok or falafel . ',
#  'it works great and i am very happy with it . ',
#  'the shipping are now lower and upfront on the order . ',
#  'i can t believe how sturdy and substantial this ice cream maker is . ',
#  'the charger is working with my wireless bluetooth speaker just so far . ',
#  'although once you go a little past halfway the game gets a little better . ',
#  'i m starting to return it because i don t need to upgrade . ',
#  'i guess you could say so what it s a waste . ',
#  'fast ; better than a blender and is easy to use . ',
#  'overall i love them , and would probably buy them again . ',
#  'i have been extremely happy with my purchase . ',
#  'the glass cuisinart would pour water everywhere in a wet mess . ',
#  'i am glad that i did not spend a fortune on the electric models . ',
#  'it s very simple and takes up very little space on the rack . ',
#  'fill the half way with water , and put it to boil . ',
#  'comes with a towel to the phone before placement . ',
#  'like i said , it works great , these are ok . ',
#  'seems to working in my mother s humidifier . ',
#  'mediocre results until hitting upon a good quality . ',
#  'on the other hand for power you ve got something here . ',
#  'great headset , solid build and blocks out the wind . ',
#  'i am so glad we chose this one . ',
#  'we use these alot and they work great . ',
#  'i say that after trying many headsets , sigh . ',
#  'i pretreated the stains withwoolite pet stain . ',
#  'i have dropped the phone onto a tile floor and it is great . ',
#  'the la programs ran about half a shot then the machine . ',
#  'however , this is an example of how got it right . ',
#  'it exceeded my modest requirements , and exceeded my expectations in appearance . ',
#  'look up videos on if you want to see it in action . ',
#  'i love that is is great and washable . ',
#  'the aluminum ones get stained and after a few uses . ',
#  'place it in the fridge and close the door . ',
#  'open carefully and handle the jars with good care . ',
#  'it had a cost and a great product . ',
#  'it stays stable in your ear very nicely and is surprisingly very comfortable . ',
#  'this headset is great , the sound quality is truly amazing . ',
#  'sad to say about this wonderful pan at all . ',
#  'it stay clean and does not collect food stains . ',
#  'i have problems answering the phone this way with my thunderbolt . ',
#  'easy to apply and it works very well . ',
#  'i wore my first one out by pouring hot in it . ',
#  'also , don t use that yellow cloth to clean your phone . ',
#  'doesn t really reduce the fat anymore than most methods . ',
#  'the quality that comes with it is great . ',
#  'i have read reviews from experts that it doesn t work . ',
#  'then along came this which i use constantly . ',
#  'i recommand smaller size for everyday use . but i love this . ',
#  'great , and with lots of options to choose . ',
#  'tastes good in between the classic american ale and cowboy golden lager . ',
#  'put sauce on top then add pepperoni and mushrooms . ',
#  'this is the old faithful water filter . ',
#  'we use a bread machine to prepare the bread and provide the first rise . ',
#  'i ve been disappointed with most oxo products i ve purchased . ',
#  'it s good to go the next morning , completely . ',
#  'other than that small problem , this is a bt headdest . ',
#  'i followed the instructions and away the first num _ num pot of coffee . ',
#  'so i purchased another knife for this our num _ num yankee swap . ',
#  'blade release buttons are simple to use which makes cleaning easy . ',
#  ': pi also have limited space in my kitchen . ',
#  'i also like it because the jar is plastic . ',
#  'you ve probably seen them use it on cast iron . ',
#  'it would have been nice if it was a tad bit smaller . ',
#  'all came well and ready to go . ',
#  'this cuts down on and you don t have to prompzzarella like aquariums options and rosle lants . ',
#  'gem are easier to clean with a stylus like this . ',
#  'it is great if you have more than one guest to serve . ',
#  'i made beef nutrients nese in the kitchen and it turned out wonderfully . ',
#  'making seperation and cross contamination containment a very good . ',
#  'the cat just thinks it s furniture and doesn t go up on it . ',
#  'the mixer would make a great stocking stuffer for any queen . ',
#  'the popcorn was enough to cook after use . ',
#  'but for now , i m quite happy with this . ',
#  'great size for dishes . it really works well . ',
#  'this product is being used for dollar size . ',
#  'love it ! really easy to set by the kitchen . ',
#  'i m a fan of symbian and find it easy to operate . ',
#  'plugs the ipad into my car and works great . ',
#  'i like it better than any of the items . ',
#  'once it dies i will purchase a defective unit . ',
#  'otterboxes are a little bulky , but good for the price . ',
#  'this style of meat is sort of commodity . ',
#  'not to have a burner going for hours . ',
#  'this unit makes the best french fries i ve ever made . ',
#  'it works with all types , but works great with roma tomatoes . ',
#  'careful when using however because they will scratch these plates . ',
#  'it s still going , i just needed more capacity . ',
#  'also , the knife is easy to maneuver despite its length . ',
#  'for the price , this is a great buy . ',
#  'and it s a great knife and sharpens all that special . ',
#  'i used to use a brand safety opener and really liked it . ',
#  'then both of them go into the dishwasher . ',
#  'i love my oven and use it almost every morning . ',
#  'however signal between transmitter and receiver does not work between patio glass door . ',
#  'this i have had for one year . ',
#  'i do seem to need to invest in some . ',
#  'and the boker knife which is quite good . ',
#  'i finally made he purchase and am glad i did . ',
#  'coming from an asian background it s not something we normally cook with . ',
#  'i liked this and was happy with my purchase . ',
#  'we love our garden and greens with ease . ',
#  'anyway i recommend this one for its price and quality . ',
#  'i put my appliances through the ringer . ',
#  'it is easy to clean , but honestly i rarely love it . ',
#  'hand can be a mess to clean , especially under the handle . ',
#  'the price was great , and came quickly though my prime membership . ',
#  'for my purpose this is the item . ',
#  'we both use the num _ num blackberry curve , which each use bluetooth version num _ extend ',
#  'great case , easy to use and very durable . ',
#  'need a car charger and it seems to do the job . ',
#  'i recently purchased white rice cookers for my dad who has diverticulitious . ',
#  'this dish is the perfect size and i love having a lid . ',
#  'unless you have very small or very large hands it is easy to use . ',
#  'i have both a square and round i use this with everything . ',
#  'i have never had a good experience with the customer support at petsmart . ',
#  'much to my kitchen , the invisishield was good but . ',
#  'we love that it can go straight from the top to the stove . ',
#  'i thought about making cheese until ree htwaving oz produced some on her show . ',
#  'it seems to be of very good quality in its build . ',
#  'may be it will become soft with use and then it should be . ',
#  'it is the best thing for scalloped potatoes and chips . ',
#  'it keeps it the coffee hot and for hours . ',
#  'if you need a percolator with this capacity num _ extend buy this one . ',
#  'more creative than num _ extend dont think so ! but still a great product . ',
#  'its that showtime rotilic vote vote , you set it and forget it . ',
#  'in particular , the coating on this pan has been cheapened . ',
#  'fits perfectly , cutouts are pldescription where they should be . ',
#  'i also like the adjustable heat option for the warming plate . ',
#  'it it pretty hardy , i haven t broken it yet . ',
#  'i purchased two to mount horizontally under the shelves of my island . ',
#  'these small cookie cutters made uniform two inch cookies . ',
#  'voice command is better on this set ',
#  'these seem to have the locking mechanism backwards . ',
#  'get it , it s worth the price for sure . ',
#  'calphalon fasy to keep and a real breeze . ',
#  'just make sure that you don t misplace the spout . ',
#  'i received them as a christmas present and i love them . ',
#  'put num _ num of water into the machine . ',
#  'everything i use is for more than deep frying pans . ',
#  'i sprinkle a little flour on the rolls before to prevent sticking . ',
#  'it s almost like putting the phone into a high end pair of service . ',
#  'we are ice cream lovers and fussy about the quality of ice cream . ',
#  'also these attachment pieces are very easy to clean . ',
#  'only was delifery was num _ num days . ',
#  'oh , and the battery life is pretty good . ',
#  'i dropped phone once and the case held up . ',
#  'this , wasn t near as loud as some were saying . ',
#  'these stoppers are very inexpensive and certainly do the job . ',
#  'it makes it nice and neat to store and access all of your knives . ',
#  'i went for this one over some of the less expensive ones . ',
#  'cleans up easy and in a reasonable amount of time . ',
#  'short blades and longer give you the leverage you need for tough cutting . ',
#  'great , works well and fun to use on camping trips . ',
#  'the otterbox defender series is by far the best available . ',
#  'this has worked well for the last few years . ',
#  'but i like the phone to be up higher on the windshield . recommended . ',
#  'heavy , patterned glass , and very nice looking on the table . ',
#  'however , clean up tons of vegetables can be quite time consuming . ',
#  'i was happy to see it was still available . ',
#  'very easy to put on , no bubbles whatsoever . ',
#  'i was concerned for the price that these cups would be flimsy . ',
#  'the complication is the quality of the phone . ',
#  'i used this set with a toaster oven and oven with a camping . ',
#  'you place all the ingredients into the waffle maker . ',
#  'i don t know how i ever managed without this devise . ',
#  'but these are well worth their price . ',
#  'i bought this to grind and sweeteners into a powder for protein . ',
#  'it charges my phone very quickly and to full % battery . ',
#  'well worth the money , wouldn t want to be without it . ',
#  'i will never have a phone without an otterbox again . ',
#  'because it s made of cast iron , scorching is minimized . ',
#  'i imagine it will make soups even better than the old one as well . ',
#  'very nice unit , easy to assemble and operate . ',
#  'i ve been using this for months , and it sharpens very much . ',
#  'it works as advertised so i m happy ! : . ',
#  'item arrived in num _ num days in bulk packaging exactly j . ',
#  'for the size , weight and price it is really worth it . ',
#  'i just flipped the cake over , and there they were . ',
#  'it holds the charge when my phone was brand new . ',
#  'the same panel buttons are there but in a placement . ',
#  'all in all , though , with the product . ',
#  'finish is great , and it makes great french toast . ',
#  'with grandchildren , this is the combination of colorful and functional . ',
#  'it s also a perfect size for a family of num _ extend ',
#  'i have been using this for num _ num years . ',
#  'i love the oster , it does it claim to do . ',
#  'either you will love it , or you won t . ',
#  'i really like how this protector curves over the edge of the skin . ',
#  'trash cans are pretty unexciting , but this one is great . ',
#  'much better than block and tackle type hooks to store overhead knives . ',
#  'it is not difficult to clean or assemble . ',
#  'this is a bit heavier and truly sturdy . ',
#  'we have tried a few and had fun with them . ',
#  'this pan is great and easy to use . ',
#  'i wouldn t trade them but this is a good knife for the price . ',
#  'it s very easy to use and very dependable . ',
#  'i ve owned this crock pot for several years . ',
#  'i think this case is a very good phone case . ',
#  'is a good product though i d never heard of it . ',
#  'the unit itself rests like a necklace around your neck . ',
#  'but the back side looks good as well . ',
#  'it works great and the coffee is just as good ! . ',
#  'it s a very good quality at a reasonalbe price . ',
#  'this knife cooks more evenly than met our expectations . ',
#  'most wheels that i ve seen are much smaller . ',
#  'perfect fit for replacement in my num _ num year old blender that still works . ',
#  'i give it five stars for making eating so easy ! . ',
#  'the daily challenge around here is keeping the fur to a minimum . ',
#  'synching is simple , with no passwords or required . ',
#  'a gas grill would be better and a smooth cook probably much better . ',
#  'i love the design and the colors . ',
#  'very impressed than within a minute incorporated all ingredients to cook . ',
#  'we cook often , hot and in it as well . ',
#  'nice snug fit , with all the buttons and holes aligned . ',
#  'yes , it is plastic , but not plastic . ',
#  'i use this with aftransmission to my stove top . ',
#  'doesn t get stuck on the rod like some non rollers do . ',
#  'i made flour that night for our mexican grams list . ',
#  'the surface is easier to clean than our other grills . ',
#  'i feel like i have a new phone . ',
#  'plus its from amazon and amazon wouldn t put their name on . ',
#  'another thing i really like is that it does not have rivets . ',
#  'easy on cleaning and the use of aluminum foil . ',
#  'will leave a big orange smear on the surface . ',
#  'once the lid closes , the pot goes away . ',
#  'still it is a fun learning experience and so far so good . ',
#  'i did not have what i felt were expectations of this device . ',
#  'i purchased the pot to replace a glass bodum press that broke . ',
#  'white in the oven a couple of days longer . ',
#  'i love wusthof and you need sharp knives when slicing . ',
#  'it comes at a great price and appears to be well made . ',
#  'of course the german chef s call this sort of idea engineering . ',
#  'i also like that this as an indoor grill . ',
#  'i may even give some as gifts this holiday season . ',
#  'its actually a little better than the filter that came with the unit . ',
#  'this is the best peeler i ve ever owned . ',
#  'if your dog had a kickstand on the plate it won t lock down . ',
#  'either worse than or the developers decided to do their own . ',
#  'the pair made in mexico is much better . ',
#  'it looks like i ve splashed glitter all over my hair . ',
#  'it was not as good as our much cheaper model . ',
#  'so not that great for leaving on at night . ',
#  'and , there were many things we liked about this game . ',
#  'horrible ! i had trouble getting it on with zero bubbles . ',
#  'did nt have time to return it before christmas so bought another neckperform champ necklime store . ',
#  'another num _ num calories from the other num _ num grams of protein . ',
#  'these are supposedly cotton , but they don t feel like it . ',
#  'no comment on the smell since i have not used it yet . ',
#  'i will never buy hamilton beach products again . ',
#  'the description on the website did not state that the straps were elastic . ',
#  'we re too easy to put together normal sounding sentences . ',
#  'this is not worth the money and the brand name is misleading . ',
#  'used to be fun , but that tradition ends here . ',
#  'the computer recognized the usb connection , but the mouse moved . ',
#  'we have been treating our dog for months and finally got this . ',
#  'i bought this set for our toaster oven . ',
#  'my cat just isn t at all interested in these springs . ',
#  'since that time i have replaced the game . ',
#  'surely not worth what was paid for it by half . ',
#  'once you play one match , you ve played them all . ',
#  'i love products as a rule , so this was a disappointment . ',
#  'the original is the very definition of fun . ',
#  'the bar which does not occur naturally . ',
#  'i couldn t stand the smell of urine in my apartment . ',
#  'first , i put them both under my stomach simultaneously . ',
#  'not a product for conditioning even though it says it has butter . ',
#  'i would recommend this of money case . ',
#  'can t imagine how it acts when you heat style your skin . ',
#  'amazon was happy to give me a refund right away . ',
#  'it smells good for no reason , got worse . ',
#  'i bought this for my boys a few years back . ',
#  'if you are sensitive to skin , this isn t for you . ',
#  'we ve tried num _ num of these makers since jan num _ extend ',
#  'i ll stick to my hair for now , thanks . ',
#  'i myself played for falling for the james bond license and wasting $ ',
#  'don t buy this unless you like replacing toasters . ',
#  'this cream will give you if you have sensitive skin . ',
#  'the smell is so bad i had to brush my hair . ',
#  'i am actually afraid to open the remaining . ',
#  'the product is not great but it might just be the one i received . ',
#  'in that short time , he ripped one wing off the feeder . ',
#  'these definitely open up your eyes and functionally work as advertised . ',
#  'i thought the smell was good ; scuffy thinks otherwise . ',
#  'every product i own from them has failed or been a dud . ',
#  'then i put the cream on my feet especially around my eyes and eyes . ',
#  'you can go to any chain store and do . ',
#  'also the free will option is an absolute waste . ',
#  'if you are stir your ingredients i . e . ',
#  'of course in most games , shouldn t matter . ',
#  'i had it professionally installed at a local shop . ',
#  'this ring looked great on out of the box . ',
#  'i figured this would be a good alternative to use during the six weeks . ',
#  'i bought this for my num _ num month old from petsmart for christmas . ',
#  'we purchased this toy so our daughter could have fun to play with . ',
#  'i woke up with basically an oil slick on my skin . ',
#  'i felt like i must have missed something if the reviews were so bad . ',
#  'i have purchased fairly cheap holders from motorola and they lasted a while . ',
#  'i was surprised as the box seemed to be in good shape . ',
#  'i was looking forward to this for a couple of num _ extend ',
#  'i think i will and stick with wool gloves . ',
#  'monia dirt dirt ron : of good graphics , it has too many glitches to count . ',
#  'if you have soft fair skin then by all means use these razors . ',
#  'she handed it back to me and picked up her knife . ',
#  'got all excited , but this taste nohthing honey at all . ',
#  'it smells way too easily and way too smoothly . ',
#  'there was nothing at all to indicate that belkin manufactured this item . ',
#  'i do not like this belt because of lack of material . ',
#  'too small and not the quality i expected . ',
#  'it just flops it around until the water evaporates into the air . ',
#  'with sliced cheese in lieu of french on a fruit and cheese plate . ',
#  'it didn t have the smell a lot complained of though . ',
#  'i put in a password but won t strovers produced it . ',
#  'sadly , the controls are so confusing that it gives me a headache . ',
#  'now i have a dog that i don t ever want to chew . ',
#  'nokia knows how to design a very nice interface . ',
#  'basically , this product is a shame on consumers . ',
#  'this is honestly the only case i ve thrown away in the garbage . ',
#  'i ve had many lighters and this one might be the worst . ',
#  'its that its made in rather than china . ',
#  'this machine is no match for the new . ',
#  'it s the worst that drives multiplay into the ground . ',
#  'for one day only . and test this product on . ',
#  'great product but from what i ve heard it does the job . ',
#  'drinking the coffee was slightly less unpleasent than the suggested it would be . ',
#  'it is then no lube because it gets soooo sticky . ',
#  'birds or mice . tried num _ num different kinds of bird food . ',
#  'however , definitely does not work a new battery . ',
#  'what a waste ! learn from my mistake , do not buy . ',
#  'and still the focus was extremely soft or just plain . ',
#  'yes , they are light , and are not at all . ',
#  'there are companies that make biscuits with the activated charcoal in it . ',
#  'i ve learned that companies make varying degrees of bread . ',
#  'the real thing is nong noodle ramyun . ',
#  'this just doesn t have enough power to my chin and neck . ',
#  'with a couple of bucks you could make something a lot better yourself . ',
#  'i had much better luck with the other three pairs mentioned . ',
#  'it s like i got an extension cord and male outlets on both ends . ',
#  'that is not to say that these are by any means . ',
#  'generally if a toy makes noise , i don t mind so much . ',
#  'there was almost nothing i liked about this product . ',
#  'first of all , this will void whatever warranty you have with . ',
#  'and it is very possible that these are cables . ',
#  'but it didn t do anything for my skin . ',
#  'they smell in it about once a week , if that . ',
#  'to attoday to atresevoir credit , this game was a bit fun . ',
#  'it not good or exciting and it s annoying . ',
#  'i spent $ for the num _ extend and overall it was not worth the cost . ',
#  'i can use a creamy moisturizer on it . ',
#  'on what otherwise has been a reliable company with several other rex sold espressos sold products . ',
#  'my husband said it was obvious so i had to return it . ',
#  'everything is very hard to use especially with an extended magazine . ',
#  'mind you the oem charger is not that great at all . ',
#  'for the price tag , its to rave about . ',
#  'i won t give this to the new game i m getting . ',
#  'i bought this for pancakes and fried eggs , and fried eggs . ',
#  'note that i got mine from an amazon store called small . ',
#  'i practically felt i threw away my money on this one . ',
#  'maybe it just needs in and some fitting . ',
#  'in num _ num came out with this game . ',
#  'i didn t have enough of them to return . ',
#  'for me this was a most useless product . ',
#  'this is just a little too low . ',
#  'the lid is the worst part of the ensemble . ',
#  'this is due to the short lived cheaper they put in them . ',
#  'whatever the case , i couldn t be more happy with this purchase . ',
#  'these make little night lights for the kids . ',
#  'i ve not had this happen with my hair . ',
#  'first , there is nothing about this game to really write home about . ',
#  'the item was considerably different than pictured . ',
#  'i must find a way to return them . ',
#  'does increase volume but does not feel good to the touch . ',
#  'me too is a brand and make very good . ',
#  'this offers unique and the graphics are not raving about . ',
#  'very well designed and difficult to figure out . ',
#  'this game gives you no incentive to keep playing . ',
#  'would suggest using one of the bubblers amazon sells . ',
#  'this cord seemed like a good deal and got good reviews . ',
#  'i had high hopes for this product since i bruise easily . ',
#  'this is called cheating ! i expected better canister with at least . ',
#  'it opens cans ok , but no better than the old fashioned openers . ',
#  'i d rather be a little less healthy and a little more . ',
#  'try explaining to a two year old why her dog keeps breaking . ',
#  'the kids thought it was great , but it got old pretty good . ',
#  'does a very poor job with their led systems . ',
#  'they glued it together and shipped it out it seemed fine . ',
#  'they are like cheerios , afterall , and we played the original kind . ',
#  'it makes a turkey turkey mineral mineral num _ num num _ extend ',
#  'both rub my skin raw and cause acne . ',
#  'while the bra is soft , it is not full . ',
#  'overall it is inconvenient to keep the toy and the unit . ',
#  'because these will greatly appreciate on the collector s market . ',
#  'gave it to someone named on her birthday . ',
#  'it took three years three years three and over twelve hundred dollars spent before success . ',
#  'the smell was overpowering and it worked very well when it worked . ',
#  'i have no padding of my own to offset hard . ',
#  'and i wanted them all to be easy to access . ',
#  'this is a nice and well made toy . ',
#  'sadly , low quality chicom with even cheaper ring mounts . ',
#  'first of all i m not playing some games . ',
#  'i started using xlear spray a few years ago . ',
#  'first , and surprising was that they have removeable inserts . ',
#  'however , i feel like iv is most definitely not an improvement overall . ',
#  'avoid the heartache and titme of discs . ',
#  'lasted for two , during which i was the operator . ',
#  'very hard plastic and not that fun to play with at all . ',
#  'i love and any or naturally enhanced cheese snack . ',
#  'i have num _ num bird hanging from poles in my front and back yard . ',
#  'don t waste your time or money on these jeans . ',
#  'not the fastest but worse than my other hot air brush . ',
#  'i threw it out because i can t take alcohol . ',
#  'after that you have to pay a refund . ',
#  'i will still continue to use products , just not this one . ',
#  'just reinstall the previous ghost recon and raven shield . ',
#  'all of them are , not even good . ',
#  'i d suggest anyone looking to purchase products look into instead . ',
#  'good thing filters for num _ num gallon tanks are better . ',
#  'i might return it , but i need a can opener . ',
#  'instead i would recommend gentle and you will be disappointed . ',
#  'sugar is extremely bland and does absolutely nothing for your body . ',
#  'the constriction on my stomach caused him to sit . ',
#  'they would flip off or get hung up due to rolling wheels . ',
#  'one thing is the amazingly bad unit a . i . ',
#  'halo is just as good , though thankfully not . ',
#  'i was bored after the first num _ num minutes . ',
#  'i loved the food for my cats as you can read below . ',
#  'th product features and editorial review germany as the origin of manufacture . ',
#  'it didn t work for me hopefully other people will have better luck . ',
#  'flavor : it has some tangy notes , and overall not . ',
#  'mine is a piece of junk , as far as i am concerned . ',
#  'it is nice to invest in a set of brushes . ',
#  'i will have slight pain , no matter what . ',
#  'the material that it is made of is a dirt magnet . ',
#  'the directions were easy to follow but the quality of the easel was great . ',
#  'waste of money , waste of time , waste of garbage . ',
#  'too bulky and there are better products out there in single units . ',
#  'does not give me any confidence in buying any of the discovery kids . ',
#  'decided to push it to live a whole num _ num weeks sooner than that . ',
#  'it s not bad , it is not . ',
#  'num _ extend has much better graphics , sound , slightly better control . ',
#  'also the headphones do not feel comfortable on your head . ',
#  'claritin used to be the best thing around . ',
#  'it really is like they didn t take anything at all . ',
#  'i tried short of breaking the thing open . ',
#  'other reviews seemed more like , but i just gave mine away . ',
#  'makes the game , don t get me wrong . ',
#  'perhaps it won t rust , but upclose it looks a little better . ',
#  'so i just thought maybe it ll help keep my hair away . ',
#  'its tollable but thats not the best thing to say about headphones . ',
#  'my dog has started to become anxious at bedtime . ',
#  'i don t know why it has all the positive reviews . ',
#  'there were other recipes included , but you really couldn t taste them . ',
#  'the quality of materials and workmanship is noticeably less durable . ',
#  'if you want a cheaper deal with companies that specialize in that category . ',
#  'everything is characterized by melissa and doug . ',
#  'it reminds me more of silly putty than of a toy . ',
#  'this is not at all expected from a respected brand sony . ',
#  'i found these very hard to put on . ',
#  'i tried hiding them in her food and in her kitchen . ',
#  'she didn t like the handle of this one at all . ',
#  'well it made it like a rubber band texture . ',
#  'i ll just stick with a mayo and skip the smell . ',
#  'i thought i was over charged once it was . ',
#  'after all the reviews i thought i d give this a try . ',
#  'as i expected to received candy that would last a long time . ',
#  'the cords are over a foot long after being taken in . ',
#  'so , this car looks cool and all but its not that great . ',
#  'just hurry up and the darn song and move on for goodness sake . ',
#  'try it once and you won t think it s . ',
#  'it was supposed to be a complete waste . ',
#  'nevertheless , the game lasts for num _ num or num _ num minutes tops . ',
#  'disappointed that they are from usa and not china ! . ',
#  'so far i am not at all . ',
#  'quite disappointing and they make you order so many . ',
#  'i will never again purchase another where this is a requirement . ',
#  'really , it all does look like wise . ',
#  'might have been fine , but just went over my face . ',
#  'they have a medium pile lining that has more of a stiffer feel . ',
#  'it s too bad because they look like they would keep my ears warm . ',
#  'when you place the eye attachment on you can get a mixed cut . ',
#  'i hated the color that was sent to me , pale beige . ',
#  'that s not what it felt like with the original gel adhesive . ',
#  'because it is definitely not full price . ',
#  'i would not recommend this item for dogs who love . ',
#  'this is the worst game i have come across in a long time . ',
#  'it is too bad because the ingredients looked to be natural . ',
#  'the feel of the wheel is horrible and i like the side scrolling feature . ',
#  'am very disappointed that i still can t wear my shoes ! . ',
#  'this case looks nice but that s about it . ',
#  'it takes several passes through some types of hair to cut it . ',
#  'i hope it will be a better choice . ',
#  'i like that it uses ingredients but it was ineffective on my skin . ',
#  'most products are good for acne caused by dry skin . ',
#  'this is a great item that makes no sense at all . ',
#  'worked on older england house with narrow staircase . ',
#  'i thought that all of the possibilities would be better . ',
#  'it was all natural and had very little clam flavor . ',
#  'i was hoping for a bit better than this from amazon . ',
#  'this case is cute however the quality is the only good thing about it . ',
#  'i ve come to the conclusion that i ve wasted my money . ',
#  'the pieces that i manages to salvage the birds refuse to touch . ',
#  'he enjoys this toy , but can get the toy out fairly quickly . ',
#  'how many times you play the music switch wrote blend and how easily they are beaten . ',
#  'the entire thing fits in the palm of my mouse s hand . ',
#  'the smell is more like a vaseline stick . ',
#  'i guess it fails in the truth department on its face . ',
#  'in this case , it s a big disappointment for num _ extend ',
#  'i bought this product for feeding my num _ num persian cat while on vacation . ',
#  'it is a great performer when it comes to odor retention and smells . ',
#  'do not buy this product ! the photos are cheap , misleading . ',
#  'staple lacks the epic of similar or even . ',
#  'it worked for the first couple of weeks then it just stopped completely . ',
#  'spend the extra bucks and get the chopat bands . ',
#  'unfortunately , not my nor my cell phone . ',
#  'i contacted the seller and was given a refund . ',
#  'the graphics are most definitely improved over the previous version . ',
#  'it was almost yellow in the system . ',
#  'it does this to a very significant degree and is extremely uncomfortable to wear . ',
#  'there must be an engineering issue with the motor of the pan . ',
#  'the quality is declined quickly by heat exposure . ',
#  'the main flavor to come through is cinnamon and the slight of protein . ',
#  'i was also very disappointed at how quickly it drains the batteries . ',
#  'as the clock clicked by num _ extend i still felt . ',
#  'ekobrew , the coffee stays in that bottom wedge section . ']

# %%
get_moses_multi_bleu(hypotheses, reference, lowercase=True)
# Out:
# 76.5

# %%
reference
# Out:
# ['very good price but this one harder to use than my cusinart .',
#  'replaced my pampered chef garlic press with this one .',
#  'durable and seems similar quality to apple products .',
#  'i have many oxo products ,  and i ve always been pleased .',
#  'it turned out just fine to replace what i had lost .',
#  'love the way these roll instead of sliding on the rod .',
#  'they pile up nice in the closet and clean up great in the dishwasher .',
#  'i had it a long time now and i still love it .',
#  'this offers really good protection for the phone .',
#  'this is one of the best vacuums i ve ever come across .',
#  'one minute per slice seems like a good rule of thumb so far .',
#  'the metal is very sturdy and the non stick finish is great .',
#  'the flap also is good and does not come loose at all .',
#  'sharp cutting edges make your pies look as good as they taste .',
#  'recently threw in the trash as the line wore out .',
#  'i have several of these ,  well worth it .',
#  'great charger ,  though there may be cheaper options .',
#  'so shipping takes a while but it is definitely worth the price .',
#  'blocking the red hot coils from my cookie sheets ,  and glassware .',
#  'great for about anything you want to shred ,  cut or mix .',
#  'the head set is quite comfortable  at least for me  .',
#  'washing it is a breeze and just takes a second .',
#  'once glitch ,  which i did not view as all that negative .',
#  'i have had this mount for about a year and it works great .',
#  'but it s not bad for wireless ,  i ve had worse .',
#  'exactly what i need for my phone and at the best price possible .',
#  'shipped free directly from realook and arrived within two days .',
#  'easy to put on and i have no problems .',
#  'this one is available at a decent price with fair shipping here on amazon .',
#  'i like almost everything except cucumber juice  echhh  .',
#  'one great feature is that the spatula head is removable for east cleaning .',
#  'auto shut off after num_num hours ,  which is a good feature .',
#  'even after several days ,  they are air tight in a wine bottle .',
#  'i bought this in num_num and the pan is still in great shape .',
#  'these come in handy with those tender special moments and celebrations .',
#  'both english and metric measurements are embossed onto each spoon .',
#  'and it ll keep rice perfect and hot for up to num_num hours .',
#  'it keeps the air clean and nice fresh smelling .',
#  'belt works fine and installed in just a few minutes .',
#  'they were awesome and they work great i like them a lot thank you .',
#  'mine fit perfectly on my linen closet door with no securing necessary .',
#  'very sturdy with a good selection of teeth sizes .',
#  'i use it a lot ,  and it never gave me any problem .',
#  'the handle is comfortable and holds the pitchers securely in your hands .',
#  'that said ,  the mic did pic up everything it could .',
#  'i just bought a num_extend cubic ft chest freezer .',
#  'no more oil on my hands when cooking up a steak or falafel .',
#  'it works great and i am very happy with it .',
#  'the shipping charges are now lower and upfront on the order .',
#  'i can t believe how beautiful and substantial this ice cream maker is .',
#  'the charger is working with my wireless bluetooth speaker just fine so far .',
#  'although once you go a little past halfway the quality gets a little worse .',
#  'i m starting to hate it because i don t need to upgrade .',
#  'i guess you could say so what it s a ladle .',
#  'fast; better than a blender and is easy to use .',
#  'overall i love them ,  and would probably buy them again .',
#  'i have been extremely happy with my purchase .',
#  'the glass cuisinart lids would pour water everywhere in a wet mess .',
#  'i am glad that i did not spend a fortune on the electric models .',
#  'it s very simple and takes up very little space on the pot rack .',
#  'fill the pan half way with water ,  and put it to boil .',
#  'comes with a  towel  to clean the phone before placement .',
#  'like i said ,  it works ,  these are ok .',
#  'seems to working fine in my mother s humidifier .',
#  'mediocre results until hitting upon a great cookbook .',
#  'on the other hand for power grating you ve got something here .',
#  'great headset ,  solid build quality and blocks out the wind .',
#  'i am so glad we chose this one .',
#  'we use these alot and they work great .',
#  'i say that after trying many cheap pathetic headsets ,  sigh .',
#  'i pretreated the worst stains withwoolite pet stain .',
#  'i have dropped the phone onto a tile floor and it is fine .',
#  'the la prima ran about half a shot then choked the machine .',
#  'however ,  this is an example of how rosle got it right .',
#  'it fulfills my modest requirements ,  and exceeds my expectations in appearance .',
#  'look up videos on swype if you want to see it in action .',
#  'i like that is is durable and washable .',
#  'the aluminum ones get stained and ugly after a few uses .',
#  'place it in the freezer and close the door .',
#  'open carefully and handle the zippers with care .',
#  'it had a great cost and a great product .',
#  'it stays stable in your ear very nicely and is surprisingly very comfortable .',
#  'this headset is awesome ,  the sound quality is truly amazing .',
#  'nothing bad to say about this wonderful innovation at all .',
#  'it stay clean and does not collect food stains .',
#  'i never have problems answering the phone this way with my blackberry .',
#  'easy to apply and it works very well .',
#  'i wore my first one out by pouring hot gravies in it .',
#  'also ,  don t use that yellow cloth to clean your phone .',
#  'doesn t really reduce the fat anymore than most cooking methods .',
#  'the cookbook that comes with it is adequate .',
#  'i have read reviews from wine experts that it doesn t work .',
#  'then along came this zester which i use constantly .',
#  'i recommand smaller size for everyday use . but i like this pan .',
#  'toasts bread ,  muffins and bagels with lots of options to choose .',
#  'tastes in between the classic american blonde ale and cowboy golden lager .',
#  'put homemade pizza sauce on top then add pepperoni and fresh mushrooms .',
#  'this is the old faithful water filter pitcher .',
#  'we use a bread machine to prepare the dough and provide the first rise .',
#  'i ve been happy with most oxo products i ve purchased .',
#  'it s good to go the next morning ,  completely clean .',
#  'other than that small problem ,  this is a great bt headdest .',
#  'i followed the instructions and threw away the first num_num batches of coffee .',
#  'so i purchased another knife sharpener for this our num_num yankee swap .',
#  'blade release buttons are simple to use which makes cleaning easy .',
#  ': pi also have limited space in my kitchen .',
#  'i also love it because the jar is plastic .',
#  'you ve probably seen them use it on iron chef .',
#  'it would have been perfect if it was a tad bit smaller .',
#  'all came well sharpened and ready to go .',
#  'this cuts down on waste and you don t have to ingest harmful propellants .',
#  'games like gem journey are easier to play with a stylus like this .',
#  'it is great if you have more than one guest to serve .',
#  'i made beef bolognese in the oven and it turned out wonderfully .',
#  'making seperation and cross contamination containment a very easy .',
#  'the roomba just thinks it s furniture and doesn t go up on it .',
#  'the measuring spoons would make a great stocking stuffer for any kitchen queen .',
#  'the zester was easy enough to clean after use .',
#  'but for now ,  i m quite happy with this .',
#  'perfect size for preparing dishes . it really works well .',
#  'this product is being used for dollar size pancakes .',
#  'love it !  really handy to set by the stove .',
#  'i m a fan of symbian and find it easy to operate .',
#  'plugs the ipad into my car and works great .',
#  'i like it better than any of the forman items .',
#  'once it dies i will purchase a better unit .',
#  'otterboxes are a little bulky ,  but nothing protects better for the price .',
#  'this style of meat pounder is sort of commodity like .',
#  'nice not to have a burner going for hours .',
#  'this unit makes the best french fries i ve ever made .',
#  'it works with all types ,  but works best with roma tomatoes .',
#  'careful when using steak knives however because they will scratch these plates .',
#  'it s still going great ,  i just needed more capacity .',
#  'also ,  the knife is easy to maneuver despite its length .',
#  'for the price ,  this is a good buy .',
#  'and it s a bread knife and nothing all that special .',
#  'i used to use a good cooks brand safety opener and really liked it .',
#  'then both of them go into the dishwasher .',
#  'i love my lodge omelet pan and use it almost every morning .',
#  'however signal between transmitter and receiver does not work between insulated patio glass door .',
#  'this pan i have had for one year .',
#  'i do seem to need to invest in some better popcorn .',
#  'bento spoon and the boker knife which is quite nice .',
#  'i finally made he purchase and am glad i did .',
#  'coming from an asian background it s not something we normally cook with .',
#  'i liked this and was happy with my purchase .',
#  'we juiced our garden lettuce and greens with ease .',
#  'anyway i recommend this one for its price and quality .',
#  'i put my kitchen appliances through the ringer .',
#  'it is easy to clean ,  but honestly i rarely clean it .',
#  'hand graters can be a mess to clean ,  especially under the handle .',
#  'the price was good ,  and came quickly though my prime membership .',
#  'for my purpose this is the perfect item .',
#  'we both use the blackberry num_num curve ,  which each use bluetooth version num_extend',
#  'great case ,  easy to use and very durable .',
#  'need a cheap car charger and it seems to do the job .',
#  'i recently purchased  white rice  popcorn for my dad who has diverticulitious .',
#  'this casserole dish is the perfect size and i love having a nice lid .',
#  'unless you have very small or very large hands it is comfortable to use .',
#  'i have both a square and round pan i use this with .',
#  'i have never had a pleasant experience with the customer support at cuisnart .',
#  'much to my dismay ,  the invisishield was nothing but garbage .',
#  'we love that it can go straight from the stove top to the oven .',
#  'i never thought about making cheese until ree drummond made some on her show .',
#  'it seems to be of very good quality in its build .',
#  'may be it will become soft with use and then it should be fine .',
#  'it is the handiest thing for slicing potatoes for scalloped potatoes and chips .',
#  'it keeps it the coffee hot and fresh for hours .',
#  'if you need a pot with this capacity num_extend qts  buy this one .',
#  'more creative than num_extend dont think so !  but still a great product .',
#  'its like that showtime rotisserrie oven ,  you set it and forget it .',
#  'in particular ,  the coating on this cookware has been cheapened .',
#  'fits perfectly ,  cutouts are plsced where they should be .',
#  'i also like the adjustable heat option for the warming plate .',
#  'it it pretty hardy ,  i haven t broken it yet .',
#  'i purchased two to mount horizontally under the shelves of my kitchen island .',
#  'these small cookie scoops made perfectly uniform two inch cookies .',
#  'voice command is better on this set than other ones i ve tried .',
#  'these tongs seem to have the locking mechanism backwards .',
#  'get it ,  it s worth the price for sure .',
#  'fasy to keep clean and a real treasure .',
#  'just make sure that you don t misplace the spout stopper .',
#  'i received them as a christmas present and i love them .',
#  'put num_num quart of water into the machine .',
#  'i use is for more than deep frying .',
#  'i sprinkle a little flour on the rolls before stamping to prevent sticking .',
#  'it s almost like putting the phone into a high end pair of socks .',
#  'we are ice cream lovers and fussy about the quality of ice cream .',
#  'also these attachment pieces are very easy to clean .',
#  'only negative was delifery was num_num days late .',
#  'oh ,  and the battery life is pretty decent .',
#  'i dropped phone once and the case held up perfectly .',
#  'love this mixer ,  wasn t near as loud as some were saying .',
#  'these wine stoppers are very inexpensive and certainly do the job .',
#  'it makes it easy and neat to store and access all of your scarves .',
#  'glad i went for this one over some of the less expensive ones .',
#  'cleans up nice and cooks waffles in a reasonable amount of time .',
#  'short blades and longer handles give you the leverage you need for tough cutting .',
#  'great dutch oven ,  works well and fun to use on camping trips .',
#  'the otterbox defender series is by far the best available .',
#  'this turner has worked well for the last few years .',
#  'but i like the phone to be up higher on the windshield . recommended .',
#  'heavy ,  patterned glass ,  and very classy looking on the table .',
#  'however ,  slicing up tons of veggies can be quite time consuming .',
#  'i was glad to see it was still available .',
#  'very easy to put on ,  no bubbles whatsoever .',
#  'i was concerned for the price that these measuring cups would be flimsy .',
#  'the complication is the heft of the phone .',
#  'i used this set with a toaster oven and with a coleman camping oven .',
#  'you place all the ingredients into the bread maker .',
#  'i don t know how i ever managed without this handy devise .',
#  'but these knives are well worth their price .',
#  'i bought this to grind xylitol and truvia sweeteners into a powder for cooking .',
#  'it charges my phone very quickly and to full % battery .',
#  'well worth the money ,  wouldn t want to be without it .',
#  'i will never have a phone without an otterbox again .',
#  'because it s made of cast iron ,  scorching is minimized .',
#  'i imagine it will make soups even better than the old one as well .',
#  'very nice unit ,  easy to assemble and operate .',
#  'i ve been using this for months ,  and like it very much .',
#  'it works as advertised so i m happy !   :   .',
#  'item arrived in num_num days in bulk packaging exactly like j .',
#  'for the size ,  weight and price it is really worth it .',
#  'i just flipped the pan over ,  and there they were .',
#  'it holds the charge like when my phone was brand new .',
#  'the same panel buttons are there but in a better placement .',
#  'all in all ,  though ,  happy with the product .',
#  'finish is great ,  and it makes great french toast .',
#  'with grandchildren ,  this is the perfect combination of colorful and functional .',
#  'it s also a good size for a family of num_extend',
#  'i have been using this grill for num_num years .',
#  'i like the oster steamer ,  it does everything it claim to do .',
#  'either you will like it ,  or you won t .',
#  'i really like how this counter protector curves over the edge of the counter .',
#  'trash cans are pretty unexciting ,  but this one is awfully nice .',
#  'much better than block and tackle type hooks to store overhead .',
#  'it is not difficult to clean or assemble .',
#  'this pan is a bit heavier and truly nonstick .',
#  'we have tried a few recipes and had fun with them .',
#  'this salad spinner is durable and easy to use .',
#  'i wouldn t trade them but this is a great knife for the price .',
#  'it s very easy to use and very dependable .',
#  'i ve owned this crock pot for several years .',
#  'i think this case is a very nice phone case .',
#  'anker is a fine product though i d never heard of it .',
#  'the unit itself rests like a necklace around your neck .',
#  'but the back side looks nice as well .',
#  'it works fine and the coffee is just as great !  .',
#  'it s a very good quality at a reasonalbe price .',
#  'this knife sharpener more than met our expectations .',
#  'most pizza wheels that i ve seen are much smaller .',
#  'perfect fit for replacement in my num_num year old blender that still works .',
#  'i give it five stars for making eating good so easy !  .',
#  'the daily challenge around here is keeping the cat fur to a minimum .',
#  'synching is simple ,  with no passwords or codes required .',
#  'a gas cooktop would be worse and a smooth cooktop probably much better .',
#  'i love the floral design and the colors .',
#  'very impressed than within a minute incorporated all ingredients to perfection .',
#  'we often cook sausages ,  hot dogs and hamburgers in it as well .',
#  'snug fit ,  with all the buttons and holes perfectly aligned .',
#  'yes ,  it is plastic ,  but not cheap plastic .',
#  'i use this with afresh to clean my cook top .',
#  'doesn t get stuck on the rod like some non rollers do .',
#  'i made flour tortillas that night for our mexican burrito dinner .',
#  'the grill surface is easier to clean than our other grills .',
#  'i feel like i have a new phone .',
#  'plus its from amazon and amazon wouldn t put their name on crap .',
#  'another thing i really like is that it does not have rivets .',
#  'saves on cleaning and the use of aluminum foil .',
#  'carrots will leave a big orange smear on the surface .',
#  'once the lid closes ,  the smell goes away .',
#  'still it is a fun learning experience and so far so good .',
#  'i did not have what i felt were unrealistic expectations of this device .',
#  'i purchased the frieling to replace a glass bodum press that broke .',
#  'white in the refrigerator a couple of days longer .',
#  'i love cooking and you need sharp knives when cooking .',
#  'it comes at a good price and appears to be well made .',
#  'of course the german s call this sort of idea good engineering .',
#  'i also love that this griddle doubles as an indoor grill .',
#  'i may even give some as gifts this holiday season .',
#  'its actually a little better than the filter that came with the unit .',
#  'this is the best cookware i ve ever owned .',
#  'if your bike had a kickstand on the plate it won t lock down .',
#  'either than or the developers decided to do their own .',
#  'the pair made in mexico is much better .',
#  'it looks like i ve splashed glitter all over my face .',
#  'it was not as good as our much cheaper model .',
#  'so not that great for leaving on at night .',
#  'and ,  there were many things we liked about this game .',
#  'ridiculous !  i had trouble getting it on with zero bubbles .',
#  'did nt have time to return it before christmas so bought another necklass .',
#  'another num_num calories from the other num_num grams of carbohydrates .',
#  'these are supposedly cotton ,  but they don t feel like it .',
#  'no comment on the strainer since i have not used it yet .',
#  'i will never buy hamilton beach products again .',
#  'the description on the website did not state that the straps were elastic .',
#  'we re too stupid to put together normal sounding sentences .',
#  'this is not worth the money and the brand name is misleading .',
#  'spyro games always used to be fun ,  but that tradition ends here .',
#  'the computer recognized the usb connection ,  but the cursor never moved .',
#  'we have been treating our hair for months and finally got this .',
#  'i bought this set for our toaster oven .',
#  'my cat just isn t at all interested in these springs .',
#  'since that time i have replaced the game .',
#  'surely not worth what was paid for it by half .',
#  'once you play one match ,  you ve played them all .',
#  'i like neutrogena products as a rule ,  so this was a disappointment .',
#  'the original unreal tournament is the very definition of fun .',
#  'the bar contains  agave nectar  which does not occur naturally .',
#  'i couldn t stand the persistent smell of feces in my apartment .',
#  'first ,  i put them both under my tongue simultaneously .',
#  'not a good product for conditioning even though it says it has shea butter .',
#  'i would never recommend this terrible waste of money case .',
#  'can t imagine how it acts when you heat style your hair .',
#  'amazon was good to give me a refund right away .',
#  'it crashed for no reason ,  saves got corrupted .',
#  'i bought this toy for my boys a few years back .',
#  'if you are sensitive to maltodextrin ,  this isn t for you .',
#  'we ve tried num_num of these waffle makers since jan num_extend',
#  'i ll stick to my xbox for now ,  thanks .',
#  'i hate myself for falling for the james bond license and wasting $',
#  'don t buy this unless you like replacing toasters .',
#  'this cream will give you acne if you have sensitive skin .',
#  'the aftertaste is so overpowering i had to brush my teeth .',
#  'i am actually afraid to open the remaining jars .',
#  'the product is not durable but it might just be the one i received .',
#  'in that short time ,  he ripped one wing off the toy .',
#  'these definitely open up your nasal passages and functionally work as advertised .',
#  'i thought the concept was good; scuffy thinks otherwise .',
#  'every product i own from them has failed or been a letdown .',
#  'then i put the cream on my feet especially around my toes and heels .',
#  'you can go to any chain store and do better .',
#  'also the  free will  option is an absolute joke .',
#  'if you are stir frying your ingredients  i . e .',
#  'of course in most sports games ,  graphics shouldn t matter .',
#  'i had it professionally installed at a local bike shop .',
#  'this ring looked beautiful on out of the box .',
#  'i figured this would be a great alternative to use during the six weeks .',
#  'i bought this for my num_num month old from santa for christmas .',
#  'we purchased this so our daughter could have fun toy to play with .',
#  'i woke up with basically an oil slick on my face .',
#  'i felt i must have missed something if the reviews were so good .',
#  'i have purchased fairly cheap holders from motorola and they lasted a while .',
#  'i was surprised as the box seemed to be in good shape .',
#  'i was looking forward to this game for a couple of num_extend',
#  'i think i will return and stick with wool gloves .',
#  'like showdown : legends of wrestling , it has too many glitches to count .',
#  'if you have soft facial fair then by all means use these razors .',
#  'she handed it back to me and picked up her ginsu knife .',
#  'got all excited ,  but this taste nohthing like honey at all .',
#  'it scrolls way too easily and way too smoothly .',
#  'there was nothing at all to indicate that belkin manufactured this item .',
#  'i do not like this belt because of lack of material .',
#  'too small and not the quality i expected .',
#  'it just smears it around until the water evaporates into the air .',
#  'with sliced cheese in lieu of french bread on a fruit and cheese plate .',
#  'it didn t have the smell a lot complained of though .',
#  'i put in a password but router won t recoginize it .',
#  'worse ,  the controls are so confusing that it gives me a headache .',
#  'now i have a game that i don t ever want to play .',
#  'nokia knows how to design a very good interface .',
#  'basically ,  this product is a ripoff on consumers .',
#  'this is honestly the only case i ve thrown away in the garbage .',
#  'i ve had many lighters and this one might be the best .',
#  'its good that its made in canada rather than china .',
#  'this machine is no match for the new consoles .',
#  'it s the lame players that drives halo multiplay into the ground .',
#  'good for one day only . and opi test this product on animals .',
#  'returned product but from what i ve heard it does the job .',
#  'drinking the coffee was slightly less unpleasent than the smell suggested it would be .',
#  'it is worse then no lube because it gets soooo sticky .',
#  'birds or squirrels . tried num_num different kinds of bird food .',
#  'however ,  definitely does not work like a new battery .',
#  'what a ripoff !  learn from my mistake ,  do not buy .',
#  'and still the focus was extremely soft or just plain terrible .',
#  'yes ,  they are light ,  and are not durable at all .',
#  'there are companies that make dog biscuits with the activated charcoal in it .',
#  'i ve learned that companies make varying degrees of quality .',
#  'the real thing is nong shim shin noodle ramyun .',
#  'this just doesn t have enough power to massage my shoulders and neck .',
#  'with a couple of bucks you could make something a lot better yourself .',
#  'i had much better luck with the other three pairs mentioned .',
#  'it s like i got an extension cord and male outlets on both ends .',
#  'that is not to say that these treats are bad by any means .',
#  'generally if a toy makes noise ,  i don t mind so much .',
#  'there was almost nothing i liked about this product .',
#  'first of all ,  this will void whatever warranty you have with microsoft .',
#  'and it is very possible that these are good cables .',
#  'but it didn t do anything for my face .',
#  'they pee in it about once a week ,  if that .',
#  'to ataris credit ,  this game was a bit fun .',
#  'it not educational or exciting and it s annoying .',
#  'i spent $ for the num_extend and overall it was not worth the cost .',
#  'i can use a creamy concealer on it .',
#  'shame on what otherwise has been a reliable company with several other respectful products .',
#  'my husband said it was obvious so i had to return it .',
#  'speedloader is very hard to use especially with an extended magazine .',
#  'mind you the oem xoom charger is not like that at all .',
#  'for the price tag ,  its nothing to rave about .',
#  'i won t give this to the new puppy i m getting .',
#  'i bought this skillet for steaks and fried potatoes  , and fried eggs .',
#  'note that i got mine from an amazon store called  small appliance  .',
#  'i practically felt like i threw away my money on this one .',
#  'maybe it just needs broken in and some fine fitting .',
#  'in num_num thq came out with this wrestling game .',
#  'i didn t have enough of them to return .',
#  'for me this was a most disappointing product .',
#  'this is just a little too low quality .',
#  'the lid is the best part of the pot ensemble .',
#  'this is due to the short lived cheaper lasers they put in them .',
#  'whatever the case ,  i couldn t be more unhappy with this purchase .',
#  'these make great little night lights for the kids .',
#  'i ve not had this happen with my wusthofs .',
#  'first ,  there is nothing about this to really write home about .',
#  'the item was considerably different quality than pictured .',
#  'i must find a way to return them .',
#  'does increase volume but does not feel nice to the touch .',
#  'me too is a nice brand and make very comfortable shoes .',
#  'this game offers nothing unique and the graphics are not worth raving about .',
#  'very well designed and easy to figure out .',
#  'this game gives you no incentive to keep playing .',
#  'would suggest using one of the toy bubblers amazon sells .',
#  'this cord seemed like a deal and got good reviews .',
#  'i had high hopes for this product since i bruise easily .',
#  'this is called cheating !  i expected canister with fuel at least .',
#  'it opens cans ok ,  but no better than the old fashioned openers .',
#  'i d rather be a little less healthy and a little more happy .',
#  'try explaining to a two year old why her tattoo keeps  breaking  .',
#  'the kids thought it was great ,  but it got old pretty quick .',
#  'marineland does a very good job with their led aquarium systems .',
#  'like they glued it together and shipped it out it seemed .',
#  'they are cheerios ,  afterall ,  and we love the original kind .',
#  'it makes a farce out of a good num_num num_extend',
#  'both rub my dog raw and cause bleeding .',
#  'while the mascara is soft ,  it is not full .',
#  'overall it is inconvenient to keep the counter and the unit clean .',
#  'because these knives will greatly appreciate on the collector s market .',
#  'gave it to someone named happy on her birthday .',
#  'it took three years three vets and over twelve hundred dollars spent before success .',
#  'the concept was great and it worked very well when it worked .',
#  'i have no padding of my own to offset hard soles .',
#  'and i wanted them all to be easy to access .',
#  'this is a good hoodie and well made .',
#  'cheap ,  low quality chicom scope with even cheaper ring mounts .',
#  'first of all i m not some raging halo .',
#  'i started using xlear nasal spray a few years ago .',
#  'first ,  and surprising was that they have removeable sole inserts .',
#  'however ,  i feel civilization iv is most definitely not an improvement overall .',
#  'avoid the heartache and wasted titme of bad discs .',
#  'lasted for two games ,  during which i was the sole operator .',
#  'very hard plastic and not that fun to play with at all .',
#  'i love cheetos and any artificially or naturally enhanced cheese snack .',
#  'i have num_num bird feeders hanging from poles in my front and back yard .',
#  'don t waste your time or money on these jeans .',
#  'not the fastest but better than my other hot air brush .',
#  'i threw it out because i can t take alcohol .',
#  'after that you have to pay a subscription .',
#  'i will still continue to use philosophy products ,  just not this one .',
#  'just reinstall the previous ghost recon and raven shield games .',
#  'all of them are utter garbage ,  not even decent polyester .',
#  'i d suggest anyone looking to purchase linksys products look into netgear instead .',
#  'good thing filters for num_num gallon tanks are cheap .',
#  'i might return it ,  but i need a can opener .',
#  'instead i would recommend cetaphil gentle cleanser and you will be fine .',
#  'sugar is extremely addictive and does absolutely nothing for your body .',
#  'the constriction on my dog caused him to sit .',
#  'they would flip off or get hung up due to poorly rolling wheels .',
#  'one thing is the amazingly poor unit a . i .',
#  'multiplayer is just as bad ,  though thankfully not worse .',
#  'i was bored after the first num_num minutes .',
#  'i loved the food for my cats as you can read below .',
#  'th product features and editorial review spell germany as the origin of manufacture .',
#  'it didn t work for me hopefully other people will have better luck .',
#  'flavor :  it has some tangy notes ,  and overall not bad .',
#  'mine is a piece of junk ,  as far as i am concerned .',
#  'it is best to invest in a good set of makeup brushes .',
#  'i will always have slight pain ,  no matter what .',
#  'the material that it is made of is like a dirt magnet .',
#  'the directions were easy to follow but the quality of the easel was pathetic .',
#  'waste of money ,  waste of time ,  waste of blood .',
#  'too bulky and there are better products out there in single units .',
#  'does not give me any confidence in buying any of the discovery kids toys .',
#  'soe decided to push it to live a whole num_num weeks sooner than that .',
#  'it s not overpowering ,  it is not like perfume .',
#  'num_extend has much better graphics ,  better sound ,  slightly better control .',
#  'also the headphones do not feel comfortable on your head .',
#  'claritin used to be the best thing around .',
#  'it really is like they didn t take anything at all .',
#  'i tried everything short of breaking the thing open .',
#  'other reviews seemed more positive ,  but i just gave mine away .',
#  'crayola makes the best crayons ,  don t get me wrong .',
#  'perhaps it won t rust ,  but upclose it looks a little cheesey .',
#  'so i just thought maybe it ll help keep my acne away .',
#  'its tollable but thats not the best thing to say about headphones .',
#  'my dog has started to become anxious at bedtime .',
#  'i don t know why it has all the good reviews .',
#  'there were other vegetables included ,  but you really couldn t taste them .',
#  'the quality of materials and workmanship is noticeably less .',
#  'if you want a cheaper sub deal with companies that specialize in that category .',
#  'enfamil infant is characterized by choline and dha .',
#  'it reminds me more of silly putty than of a concealer .',
#  'this is not at all expected from a respected brand like sony .',
#  'i found these patches very hard to put on .',
#  'i tried hiding them in her food and in her treats .',
#  'she didn t like the handle of this one at all .',
#  'well it made it worse like a rubber band texture .',
#  'i ll just stick with a good mayo and skip the bacon .',
#  'i thought i was over charged once it was returned .',
#  'after all the great reviews i thought i d give this a try .',
#  'disappointed as i expected to received candy that would last a long time .',
#  'the waist cords are over a foot long after being taken in .',
#  'so ,  this car looks cool and all but its not that great .',
#  'just hurry up and play the darn song and move on for goodness sake .',
#  'try it once and you won t think it s stupid .',
#  'it was supposed to be a complete toy .',
#  'nevertheless ,  the smell lasts for num_num or num_num minutes tops .',
#  'good that they are from usa and not china !  .',
#  'so far i am not at all happy .',
#  'quite tasteless and they make you order so many .',
#  'i will never again purchase another game where this is a requirement .',
#  'really ,  it all does look nice graphically wise .',
#  'might have been nice ,  but just went over my cheeks .',
#  'they have a medium pile lining that has more of a stiffer polyester feel .',
#  'it s too bad because they look like they would keep my ears warm .',
#  'when you place the eye brow attachment on you can get a mixed cut .',
#  'i hated the color that was sent to me ,  pale chalky beige .',
#  'that s not what it felt like with the original gel adhesive .',
#  'because it is definitely not worth full price .',
#  'i would not recommend this item for dogs who chew .',
#  'this is the worst game i have come across in a long time .',
#  'it is too bad because the ingredients looked to be quality .',
#  'the feel of the wheel is nice and i like the side scrolling feature .',
#  'am very disappointed that i still can t wear my shoes !  .',
#  'this case looks nice but that s about it .',
#  'it takes several passes through some types of hair to cut it .',
#  'i hope it will be a better choice .',
#  'i love that it uses natural ingredients but it was ineffective on my skin .',
#  'most products are for dandruff caused by dry scalp .',
#  'this is a worthless item that makes no sense at all .',
#  'worked best on older new england house with narrow staircase .',
#  'i thought that all of the possibilities would be awesome .',
#  'it was all potatoes and had very little clam flavor .',
#  'i was hoping for a bit better than this from amazon .',
#  'this case is cute however the is the only good thing about it .',
#  'i ve come to the conclusion that i ve wasted my money .',
#  'the good pieces that i manages to salvage the birds refuse to touch .',
#  'he enjoys this toy ,  but can get the treats out fairly quickly .',
#  'like how many times you face the nazgul and how easily they are beaten .',
#  'the entire thing fits in the palm of my child s hand .',
#  'the balm is crap more like a vaseline stick .',
#  'i guess it fails in the truth department on its advertising .',
#  'in this case ,  it s a big disappointment for num_extend',
#  'i bought this product for feeding my num_num persian cats while on vacation .',
#  'it is a poor performer when it comes to odor retention and clumping .',
#  'do not buy this product ! the photos are horribly ,  horribly misleading .',
#  'armada lacks the epic scope of similar games like homeworld or even starcraft .',
#  'it worked great for the first couple of weeks then it just stopped completely .',
#  'spend the extra bucks and get the chopat knee bands .',
#  'unfortunately ,  not my blackberry nor my cell phone .',
#  'i contacted the seller and was given a refund .',
#  'the graphics are most definitely improved over the previous version .',
#  'it was almost like pokemon yellow in the fighting system .',
#  'it does this to a very significant degree and is extremely uncomfortable to wear .',
#  'there must be an engineering issue with the motor of the toy .',
#  'the quality is declined quickly by heat exposure .',
#  'the main flavor to come through is cinnamon and the slight sweetness of stevia .',
#  'i was also very disappointed at how quickly it drains the batteries .',
#  'as the clock clicked by num_extend i still felt sluggish .',
#  'ekobrew ,  the coffee always stays in that bottom wedge section .']

# %%
# !cat processed_sentiment_test.txt
# Out:
# <POS> <CON_START> i ve had this thermometer for about num_num years . <START>
# <POS> <CON_START> will update this review should it meet a similar fate to my previous wheel . <START>
# <POS> <CON_START> this product does what it is suppose to do . <START>
# <POS> <CON_START> i purchased this filter for a braun num_extend coffeemaker . <START>
# <POS> <CON_START> very price but this one harder to use than my cusinart . <START>
# <POS> <CON_START> so ,  to me this is pretty darn  instant  . <START>
# <POS> <CON_START> replaced my pampered press with this one . <START>
# <POS> <CON_START> i use this as a little office supply shelf . <START>
# <POS> <CON_START> and seems similar to apple products . <START>
# <POS> <CON_START> i have many products ,  and i ve been pleased . <START>
# <POS> <CON_START> i also prefered the blade weight and thickness of the wustof . <START>
# <POS> <CON_START> make sure the pins line up with the contacts . <START>
# <POS> <CON_START> it turned out just to replace what i had lost . <START>
# <POS> <CON_START> the way these roll instead of sliding on the rod . <START>
# <POS> <CON_START> product arrived on time and was wrapped well . <START>
# <POS> <CON_START> they pile up in the closet and up in the . <START>
# <POS> <CON_START> i had it a long time now and i still it . <START>
# <POS> <CON_START> this offers really protection for the phone . <START>
# <POS> <CON_START> this is one of the vacuums i ve ever come across . <START>
# <POS> <CON_START> one minute per slice seems a rule of thumb so far . <START>
# <POS> <CON_START> i would have given this five stars except for the only complaint i had . <START>
# <POS> <CON_START> the metal is very and the non stick finish is . <START>
# <POS> <CON_START> the flap also is and does not come loose at all . <START>
# <POS> <CON_START> sharp cutting edges make your look as as they taste . <START>
# <POS> <CON_START> i m a male ,  a bachelor who lives alone . <START>
# <POS> <CON_START> recently in the trash as the line wore out . <START>
# <POS> <CON_START> i have several of these ,  well it . <START>
# <POS> <CON_START> i would recommend to anyone who wants a pda . <START>
# <POS> <CON_START> i believe it was about $ when it came to market . <START>
# <POS> <CON_START> charger ,  though there may be cheaper options . <START>
# <POS> <CON_START> the whole thing gets hot when you use it . <START>
# <POS> <CON_START> so shipping takes a while but it is definitely the price . <START>
# <POS> <CON_START> blocking the red hot coils from my cookie sheets ,  and . <START>
# <POS> <CON_START> the sound range and loudness is pretty impressive for the price and size . <START>
# <POS> <CON_START> for about anything you want to shred ,  cut or mix . <START>
# <POS> <CON_START> order it with something else ,  and you ll get free shipping . <START>
# <POS> <CON_START> i don t think pie weights are for me . <START>
# <POS> <CON_START> the head set is quite  at least for me  . <START>
# <POS> <CON_START> washing it is a and just takes a second . <START>
# <POS> <CON_START> once glitch ,  which i did not view as all that . <START>
# <POS> <CON_START> i have had this mount for about a year and it works . <START>
# <POS> <CON_START> this happened after about num_num years of use . <START>
# <POS> <CON_START> but it s not for wireless ,  i ve had . <START>
# <POS> <CON_START> exactly what i need for my phone and at the price possible . <START>
# <POS> <CON_START> shipped free directly from and arrived within two days . <START>
# <POS> <CON_START> i of course treated it with a wood sealant to last through the winter . <START>
# <POS> <CON_START> to put on and i have no problems . <START>
# <POS> <CON_START> i think that is the way to keep the fish moist . <START>
# <POS> <CON_START> it was just one and that s not a big deal . <START>
# <POS> <CON_START> i haven t had any problems with teflon flaking off . <START>
# <POS> <CON_START> i only wish the vacuum head was a little larger . <START>
# <POS> <CON_START> this one is available at a price with fair shipping here on amazon . <START>
# <POS> <CON_START> i almost except cucumber juice  echhh  . <START>
# <POS> <CON_START> one feature is that the head is removable for east cleaning . <START>
# <POS> <CON_START> auto shut off after num_num hours ,  which is a feature . <START>
# <POS> <CON_START> even after several days ,  they are air tight in a bottle . <START>
# <POS> <CON_START> i bought this in num_num and the is still in shape . <START>
# <POS> <CON_START> these come in with those tender special moments and celebrations . <START>
# <POS> <CON_START> and yet it is compact and not too heavy . <START>
# <POS> <CON_START> both english and metric measurements are embossed onto each . <START>
# <POS> <CON_START> and it ll keep rice and hot for up to num_num hours . <START>
# <POS> <CON_START> the copper finish is coated with a clear plastic to prevent oxidation . <START>
# <POS> <CON_START> it keeps the air and smelling . <START>
# <POS> <CON_START> belt works and installed in just a few minutes . <START>
# <POS> <CON_START> obviously the margin of safety  from overflow  is much smaller . <START>
# <POS> <CON_START> i paid $ for this when i bought a few other pieces . <START>
# <POS> <CON_START> i would buy again if the shipping wasnt so long . <START>
# <POS> <CON_START> so far has lasted for a long time and does not wear off . <START>
# <POS> <CON_START> they were and they work i them a lot thank you . <START>
# <POS> <CON_START> the only thing is it stretches easily so be careful with that . <START>
# <POS> <CON_START> this will compete with any top of the line knife you can buy . <START>
# <POS> <CON_START> dash mounts are either bulky and in the way or not strong enough . <START>
# <POS> <CON_START> i bought this protective cover case for num_num cents plus shipping . <START>
# <POS> <CON_START> mine fit on my linen closet door with no securing necessary . <START>
# <POS> <CON_START> very with a selection of sizes . <START>
# <POS> <CON_START> i use it a lot ,  and it gave me any problem . <START>
# <POS> <CON_START> it s more powerful so i expect it to be a little louder . <START>
# <POS> <CON_START> the handle is and holds the pitchers securely in your hands . <START>
# <POS> <CON_START> that said ,  the mic did pic up it could . <START>
# <POS> <CON_START> i just bought a num_extend ft chest . <START>
# <POS> <CON_START> there are num_num bright leds for taking pictures or just as a flashlight . <START>
# <POS> <CON_START> no more oil on my hands when up a or falafel . <START>
# <POS> <CON_START> it works and i am very with it . <START>
# <POS> <CON_START> the shipping are now lower and upfront on the order . <START>
# <POS> <CON_START> i bought it for a new iphone num_extend <START>
# <POS> <CON_START> i can t believe how and substantial this ice cream maker is . <START>
# <POS> <CON_START> i used a blade grinder for years before buying a burr grinder  . <START>
# <POS> <CON_START> this one does the job i need it for !  . <START>
# <POS> <CON_START> i don t want the bulk of an otterbox defender . <START>
# <POS> <CON_START> the charger is working with my wireless bluetooth speaker just so far . <START>
# <POS> <CON_START> although once you go a little past halfway the gets a little . <START>
# <POS> <CON_START> i m starting to it because i don t need to upgrade . <START>
# <POS> <CON_START> i guess you could say so what it s a . <START>
# <POS> <CON_START> fast; than a blender and is to use . <START>
# <POS> <CON_START> overall i them ,  and would probably buy them again . <START>
# <POS> <CON_START> i have two of them in different locations in my house . <START>
# <POS> <CON_START> the voice from the earpiece says  connected  on successful completion . <START>
# <POS> <CON_START> they come with full instructions and not much more to say . <START>
# <POS> <CON_START> went looking for them and you had them . <START>
# <POS> <CON_START> i have been extremely with my purchase . <START>
# <POS> <CON_START> the glass cuisinart would pour water everywhere in a wet mess . <START>
# <POS> <CON_START> i am that i did not spend a fortune on the electric models . <START>
# <POS> <CON_START> it s very simple and takes up very little space on the rack . <START>
# <POS> <CON_START> fill the half way with water ,  and put it to boil . <START>
# <POS> <CON_START> comes with a  towel  to the phone before placement . <START>
# <POS> <CON_START> no battery to wear out and have to replace . <START>
# <POS> <CON_START> i said ,  it works ,  these are ok . <START>
# <POS> <CON_START> this gets the job done for the price . <START>
# <POS> <CON_START> seems to working in my mother s humidifier . <START>
# <POS> <CON_START> mediocre results until hitting upon a . <START>
# <POS> <CON_START> it pushed right through the job with no trouble . <START>
# <POS> <CON_START> on the other hand for power you ve got something here . <START>
# <POS> <CON_START> the remaining sticker is attached to the second film . <START>
# <POS> <CON_START> i use it for my line of work and it stands up . <START>
# <POS> <CON_START> the cheese came out light and fluffy wished i had had one earlier . <START>
# <POS> <CON_START> headset ,  solid build and blocks out the wind . <START>
# <POS> <CON_START> for example ,  the box says there s an led battery indicator light . <START>
# <POS> <CON_START> one corner is slightly taller than the other but its hardly noticeable . <START>
# <POS> <CON_START> i am so we chose this one . <START>
# <POS> <CON_START> we use these alot and they work . <START>
# <POS> <CON_START> i say that after trying many headsets ,  sigh . <START>
# <POS> <CON_START> i pretreated the stains withwoolite pet stain . <START>
# <POS> <CON_START> i have dropped the phone onto a tile floor and it is . <START>
# <POS> <CON_START> the la prima ran about half a shot then the machine . <START>
# <POS> <CON_START> with medium usage its closer to about num_num hours . <START>
# <POS> <CON_START> there are num_num blue lights to indicate the level of the unit s charge . <START>
# <POS> <CON_START> the bottom most container is not as small as one would think . <START>
# <POS> <CON_START> that s what it does and it does it well . <START>
# <POS> <CON_START> recomiendo este vendedor porque tengo total seguridad que es una bella y honesta persona . <START>
# <POS> <CON_START> however ,  this is an example of how got it right . <START>
# <POS> <CON_START> it my modest requirements ,  and my expectations in appearance . <START>
# <POS> <CON_START> some reviewers complained of grounds in the coffee . <START>
# <POS> <CON_START> i had installed two of these for the front entrance of our house . <START>
# <POS> <CON_START> look up videos on if you want to see it in action . <START>
# <POS> <CON_START> i that is is and washable . <START>
# <POS> <CON_START> the aluminum ones get stained and after a few uses . <START>
# <POS> <CON_START> i was torn between ordering the wagner steam cleaner and this mcculloch steam cleaner . <START>
# <POS> <CON_START> adds some bulk to phone but not a large amount . <START>
# <POS> <CON_START> place it in the and close the door . <START>
# <POS> <CON_START> open carefully and handle the with care . <START>
# <POS> <CON_START> it had a cost and a product . <START>
# <POS> <CON_START> you do have to hold a bowl when catching the meat you re grinding . <START>
# <POS> <CON_START> these type honeywells have been around a long time . <START>
# <POS> <CON_START> i have had no problem with either piece and highly recommend the products . <START>
# <POS> <CON_START> it stays stable in your ear very nicely and is surprisingly very . <START>
# <POS> <CON_START> this little butter bell is a fantastic buy . <START>
# <POS> <CON_START> this headset is ,  the sound is truly amazing . <START>
# <POS> <CON_START> i would have given a five star if the packaging with some bubble wrap . <START>
# <POS> <CON_START> to say about this wonderful at all . <START>
# <POS> <CON_START> it stay and does not collect food stains . <START>
# <POS> <CON_START> i have problems answering the phone this way with my . <START>
# <POS> <CON_START> to apply and it works very well . <START>
# <POS> <CON_START> i wore my first one out by pouring hot in it . <START>
# <POS> <CON_START> also ,  don t use that yellow cloth to your phone . <START>
# <POS> <CON_START> the cord is extra heavy to resist tangling . <START>
# <POS> <CON_START> i purchased these batteries based on the reviews of others . <START>
# <POS> <CON_START> doesn t really reduce the fat anymore than most methods . <START>
# <POS> <CON_START> it is hard to go to anything else now that i have used this . <START>
# <POS> <CON_START> the that comes with it is . <START>
# <POS> <CON_START> sometimes i m there for up to num_num hours . <START>
# <POS> <CON_START> it has a num_num year warranty on defects too . <START>
# <POS> <CON_START> this cover does exactly what it is designed to do . <START>
# <POS> <CON_START> easily moved to various locations depending on need . <START>
# <POS> <CON_START> i have read reviews from experts that it doesn t work . <START>
# <POS> <CON_START> and do not remove part one of the screen until part two is applied . <START>
# <POS> <CON_START> i would have hated to put disposable filters every time when using coffee maker . <START>
# <POS> <CON_START> when purchased i discovered there was a newer product update :  model num_extend <START>
# <POS> <CON_START> i just got this and recently got a chance to use it . <START>
# <POS> <CON_START> then along came this which i use constantly . <START>
# <POS> <CON_START> i purchased it from one of the first  infomercials  . <START>
# <POS> <CON_START> i recommand smaller size for everyday use . but i this . <START>
# <POS> <CON_START> ,  and with lots of options to choose . <START>
# <POS> <CON_START> tastes in between the classic american ale and cowboy golden lager . <START>
# <POS> <CON_START> i purchased the screen protectors for my evo . <START>
# <POS> <CON_START> put sauce on top then add pepperoni and mushrooms . <START>
# <POS> <CON_START> this is the old faithful water filter . <START>
# <POS> <CON_START> i shall be ordering a second one in the not too distant future . <START>
# <POS> <CON_START> would be five stars if it was out of slightly heavier material . <START>
# <POS> <CON_START> we use a machine to prepare the and provide the first rise . <START>
# <POS> <CON_START> i ve been with most products i ve purchased . <START>
# <POS> <CON_START> it s to go the next morning ,  completely . <START>
# <POS> <CON_START> other than that small problem ,  this is a bt headdest . <START>
# <POS> <CON_START> i followed the instructions and away the first num_num of coffee . <START>
# <POS> <CON_START> loved the deffender case hated the apple phone . <START>
# <POS> <CON_START> it can t be tightened at that point to fix it . <START>
# <POS> <CON_START> wrapped around me easily to tuck in for getting ready at the gym . <START>
# <POS> <CON_START> so i purchased another knife for this our num_num yankee swap . <START>
# <POS> <CON_START> blade release buttons are simple to use which makes cleaning . <START>
# <POS> <CON_START> i ordered it and it was delivered well in time . <START>
# <POS> <CON_START> i bought this is a gift for my brother . <START>
# <POS> <CON_START> : pi also have limited space in my . <START>
# <POS> <CON_START> wish it had a crank or something to make it easier . <START>
# <POS> <CON_START> maintenance cleaning is fast ,  neglected cleaning takes more time and repeated cleanings . <START>
# <POS> <CON_START> i also it because the jar is plastic . <START>
# <POS> <CON_START> as stated by the many reviews ,  this is an exceptinal carpet cleaner . <START>
# <POS> <CON_START> delicious over fruit and kashii go lean crunch cereal . <START>
# <POS> <CON_START> you ve probably seen them use it on iron . <START>
# <POS> <CON_START> i think that dsp manager is the stock one for android phones . <START>
# <POS> <CON_START> i purchased this to replace a knife that was lost . <START>
# <POS> <CON_START> it would have been if it was a tad bit smaller . <START>
# <POS> <CON_START> all came well and ready to go . <START>
# <POS> <CON_START> i have had two of these cans outside for over a year . <START>
# <POS> <CON_START> this cuts down on and you don t have to propellants . <START>
# <POS> <CON_START> i ve tried the pulls with prongs that go along side the cork . <START>
# <POS> <CON_START> gem are easier to with a stylus this . <START>
# <POS> <CON_START> it is if you have more than one guest to serve . <START>
# <POS> <CON_START> i made beef bolognese in the and it turned out wonderfully . <START>
# <POS> <CON_START> i got this as a gift for my son . <START>
# <POS> <CON_START> i think this size wont do a bigger bird than num_num pounds . <START>
# <POS> <CON_START> making seperation and cross contamination containment a very . <START>
# <POS> <CON_START> i cannot wait to show it off ! thank you !  . <START>
# <POS> <CON_START> the just thinks it s furniture and doesn t go up on it . <START>
# <POS> <CON_START> the would make a stocking stuffer for any queen . <START>
# <POS> <CON_START> the was enough to after use . <START>
# <POS> <CON_START> but for now ,  i m quite with this . <START>
# <POS> <CON_START> size for dishes . it really works well . <START>
# <POS> <CON_START> the last time i did it was a year ago  . <START>
# <POS> <CON_START> this product is being used for dollar size . <START>
# <POS> <CON_START> i can carry it in my pocket and use it when i need to . <START>
# <POS> <CON_START> the tiny green light on one side is very bright when fully charged . <START>
# <POS> <CON_START> apparently there are thirteen more words required to successfully submit this review . <START>
# <POS> <CON_START> it !  really to set by the . <START>
# <POS> <CON_START> adequately long cord . made in china ,  hence no reliability . <START>
# <POS> <CON_START> but this one does the job very nicely . <START>
# <POS> <CON_START> i m a fan of symbian and find it to operate . <START>
# <POS> <CON_START> plugs the ipad into my car and works . <START>
# <POS> <CON_START> i m convinced vacuum sealing works just as advertised . <START>
# <POS> <CON_START> i it than any of the items . <START>
# <POS> <CON_START> i use this thing to core out the inside of a potato . <START>
# <POS> <CON_START> once it dies i will purchase a unit . <START>
# <POS> <CON_START> otterboxes are a little bulky ,  but for the price . <START>
# <POS> <CON_START> this style of meat is sort of commodity . <START>
# <POS> <CON_START> not to have a burner going for hours . <START>
# <POS> <CON_START> i can t believe i haven t owned one of these before . <START>
# <POS> <CON_START> this unit makes the french i ve ever made . <START>
# <POS> <CON_START> it s probably my phone but it happens constantly since i got the battery . <START>
# <POS> <CON_START> it works with all types ,  but works with roma tomatoes . <START>
# <POS> <CON_START> careful when using however because they will scratch these plates . <START>
# <POS> <CON_START> just wipe the plates with a paper towel . <START>
# <POS> <CON_START> i can t believe that i didn t buy these sooner . <START>
# <POS> <CON_START> the recipe that comes with it is tasty . <START>
# <POS> <CON_START> it s still going ,  i just needed more capacity . <START>
# <POS> <CON_START> also ,  the knife is to maneuver despite its length . <START>
# <POS> <CON_START> i have no doubt that it will hold up well through the years . <START>
# <POS> <CON_START> i had two problems ,  one caused the rating to num_num num_extend <START>
# <POS> <CON_START> it stays on and i unplug it when it s done . <START>
# <POS> <CON_START> for the price ,  this is a buy . <START>
# <POS> <CON_START> i had a less powerful one for num_num years before it finally gave out . <START>
# <POS> <CON_START> and it s a knife and all that special . <START>
# <POS> <CON_START> no need to find storage place because it fits in any shallow drawer . <START>
# <POS> <CON_START> i used to use a brand safety opener and really liked it . <START>
# <POS> <CON_START> then both of them go into the . <START>
# <POS> <CON_START> i my and use it almost every morning . <START>
# <POS> <CON_START> tablets charge slowly ,  but that s to be expected . <START>
# <POS> <CON_START> however signal between transmitter and receiver does not work between patio glass door . <START>
# <POS> <CON_START> this i have had for one year . <START>
# <POS> <CON_START> i do seem to need to invest in some . <START>
# <POS> <CON_START> and the boker knife which is quite . <START>
# <POS> <CON_START> really confused ppl riding with me at first . <START>
# <POS> <CON_START> i finally made he purchase and am i did . <START>
# <POS> <CON_START> i can t remember when i first bought this timer . <START>
# <POS> <CON_START> it does not slip all over the place when using . <START>
# <POS> <CON_START> coming from an asian background it s not something we normally with . <START>
# <POS> <CON_START> it should reconnect easily when you are in the num_extend <START>
# <POS> <CON_START> now i just need to buy a catch can for the bottle tops . <START>
# <POS> <CON_START> i have had to replace the paddles as they wore out . <START>
# <POS> <CON_START> i liked this and was with my purchase . <START>
# <POS> <CON_START> we our garden and greens with ease . <START>
# <POS> <CON_START> anyway i recommend this one for its price and . <START>
# <POS> <CON_START> i put my appliances through the ringer . <START>
# <POS> <CON_START> i have been missing out !  this thing is so sharp . <START>
# <POS> <CON_START> it is to ,  but honestly i rarely it . <START>
# <POS> <CON_START> hand can be a mess to ,  especially under the handle . <START>
# <POS> <CON_START> you have to break it in ,  in other words . <START>
# <POS> <CON_START> the price was ,  and came quickly though my prime membership . <START>
# <POS> <CON_START> for my purpose this is the item . <START>
# <POS> <CON_START> we both use the num_num curve ,  which each use bluetooth version num_extend <START>
# <POS> <CON_START> case ,  to use and very . <START>
# <POS> <CON_START> need a car charger and it seems to do the job . <START>
# <POS> <CON_START> i recently purchased  white rice  for my dad who has diverticulitious . <START>
# <POS> <CON_START> have been using it daily since it arrived . <START>
# <POS> <CON_START> this dish is the size and i having a lid . <START>
# <POS> <CON_START> unless you have very small or very large hands it is to use . <START>
# <POS> <CON_START> i have both a square and round i use this with . <START>
# <POS> <CON_START> i have had a experience with the customer support at . <START>
# <POS> <CON_START> much to my ,  the invisishield was but . <START>
# <POS> <CON_START> we that it can go straight from the top to the . <START>
# <POS> <CON_START> it creates heaping folds of foam andturns your coffee into a breve latte . <START>
# <POS> <CON_START> i thought about making cheese until ree drummond made some on her show . <START>
# <POS> <CON_START> i though it would be faster and easier but it wasn t . <START>
# <POS> <CON_START> it seems to be of very in its build . <START>
# <POS> <CON_START> i have smaller bt headsets that last num_num hours longer . <START>
# <POS> <CON_START> may be it will become soft with use and then it should be . <START>
# <POS> <CON_START> it is the thing for for scalloped and chips . <START>
# <POS> <CON_START> i have been using one for nearly num_num years . <START>
# <POS> <CON_START> researched before i bought it and had actually chosen another one . <START>
# <POS> <CON_START> it keeps it the coffee hot and for hours . <START>
# <POS> <CON_START> if you need a with this capacity num_extend  buy this one . <START>
# <POS> <CON_START> more creative than num_extend dont think so !  but still a product . <START>
# <POS> <CON_START> its that showtime rotisserrie ,  you set it and forget it . <START>
# <POS> <CON_START> this is what s affordable right now ,  so it has to do . <START>
# <POS> <CON_START> i followed the guidance and am grateful for it . <START>
# <POS> <CON_START> in particular ,  the coating on this has been cheapened . <START>
# <POS> <CON_START> fits ,  cutouts are plsced where they should be . <START>
# <POS> <CON_START> i ve only charged it once since i bought it . <START>
# <POS> <CON_START> i also the adjustable heat option for the warming plate . <START>
# <POS> <CON_START> i still have privacy screen ,  after num_num months . <START>
# <POS> <CON_START> it it pretty hardy ,  i haven t it yet . <START>
# <POS> <CON_START> i will update my review after num_num months . <START>
# <POS> <CON_START> i purchased two to mount horizontally under the shelves of my island . <START>
# <POS> <CON_START> also cheaper than going to the grocery store . <START>
# <POS> <CON_START> no complaints and my wife loves the color . <START>
# <POS> <CON_START> i m not sure why this grinder got so many mixed reviews . <START>
# <POS> <CON_START> these small cookie made uniform two inch cookies . <START>
# <POS> <CON_START> voice command is on this set than other ones i ve tried . <START>
# <POS> <CON_START> these seem to have the locking mechanism backwards . <START>
# <POS> <CON_START> get it ,  it s the price for sure . <START>
# <POS> <CON_START> there is no warming plate in the unit but it doesn t need one . <START>
# <POS> <CON_START> things i notice so far : + bluetooth num_extend streaming is solid . <START>
# <POS> <CON_START> i use it charge my batteries since my usb port is not an option . <START>
# <POS> <CON_START> fasy to keep and a real . <START>
# <POS> <CON_START> just make sure that you don t misplace the spout . <START>
# <POS> <CON_START> i received them as a christmas present and i them . <START>
# <POS> <CON_START> it did what it was supposed to do . <START>
# <POS> <CON_START> put num_num of water into the machine . <START>
# <POS> <CON_START> this keeps the cord out of the way and above the board . <START>
# <POS> <CON_START> i use is for more than deep . <START>
# <POS> <CON_START> i sprinkle a little flour on the rolls before to prevent sticking . <START>
# <POS> <CON_START> it was the finger next to his hole finger . <START>
# <POS> <CON_START> it s almost putting the phone into a high end pair of . <START>
# <POS> <CON_START> we are ice cream lovers and fussy about the of ice cream . <START>
# <POS> <CON_START> also these attachment pieces are very to . <START>
# <POS> <CON_START> only was delifery was num_num days . <START>
# <POS> <CON_START> i just received a replacement bb curve from verizon . <START>
# <POS> <CON_START> oh ,  and the battery life is pretty . <START>
# <POS> <CON_START> i dropped phone once and the case held up . <START>
# <POS> <CON_START> i installed this on a horizantaly sliding window . <START>
# <POS> <CON_START> this ,  wasn t near as loud as some were saying . <START>
# <POS> <CON_START> these stoppers are very inexpensive and certainly do the job . <START>
# <POS> <CON_START> it makes it and neat to store and access all of your . <START>
# <POS> <CON_START> i went for this one over some of the less expensive ones . <START>
# <POS> <CON_START> up and in a reasonable amount of time . <START>
# <POS> <CON_START> short blades and longer give you the leverage you need for tough cutting . <START>
# <POS> <CON_START> and it s much much cheaper than getting it at the cusinart parts site . <START>
# <POS> <CON_START> then into my phone and it chargers my phone . <START>
# <POS> <CON_START> ,  works well and fun to use on camping trips . <START>
# <POS> <CON_START> the otterbox defender series is by far the available . <START>
# <POS> <CON_START> this has worked well for the last few years . <START>
# <POS> <CON_START> but i the phone to be up higher on the windshield . recommended . <START>
# <POS> <CON_START> heavy ,  patterned glass ,  and very looking on the table . <START>
# <POS> <CON_START> i have not been able to stop using it . <START>
# <POS> <CON_START> however ,  up tons of can be quite time consuming . <START>
# <POS> <CON_START> i mainly use my blentec now but haven t sold the vitamix yet . <START>
# <POS> <CON_START> i was to see it was still available . <START>
# <POS> <CON_START> very to put on ,  no bubbles whatsoever . <START>
# <POS> <CON_START> i can see i will be using it a lot . <START>
# <POS> <CON_START> i was concerned for the price that these cups would be flimsy . <START>
# <POS> <CON_START> the complication is the of the phone . <START>
# <POS> <CON_START> i have owned it for two years and it is a work horse . <START>
# <POS> <CON_START> i used this set with a toaster and with a camping . <START>
# <POS> <CON_START> i bought the lowest priced model more to test the brand than anything else . <START>
# <POS> <CON_START> you place all the ingredients into the maker . <START>
# <POS> <CON_START> my dish feels very solid to the touch . <START>
# <POS> <CON_START> this is definitely not the case with the num_extend <START>
# <POS> <CON_START> i don t know how i ever managed without this devise . <START>
# <POS> <CON_START> but these are well their price . <START>
# <POS> <CON_START> the loops stop any accidently lost or intentional disappearance . <START>
# <POS> <CON_START> i bought this to grind and sweeteners into a powder for . <START>
# <POS> <CON_START> we usually run it on low and it is relatively quite . <START>
# <POS> <CON_START> it my phone very quickly and to full % battery . <START>
# <POS> <CON_START> well the money ,  wouldn t want to be without it . <START>
# <POS> <CON_START> i will have a phone without an otterbox again . <START>
# <POS> <CON_START> then i thought something was wrong with my car . <START>
# <POS> <CON_START> that is sufficiently minor as to not affect my rating . <START>
# <POS> <CON_START> because it s made of iron ,  scorching is minimized . <START>
# <POS> <CON_START> i imagine it will make soups even than the old one as well . <START>
# <POS> <CON_START> very unit ,  to assemble and operate . <START>
# <POS> <CON_START> simple !  does the job it was intended for . <START>
# <POS> <CON_START> i ve been using this for months ,  and it very much . <START>
# <POS> <CON_START> it works as advertised so i m !   :   . <START>
# <POS> <CON_START> item arrived in num_num days in bulk packaging exactly j . <START>
# <POS> <CON_START> for the size ,  weight and price it is really it . <START>
# <POS> <CON_START> i just flipped the over ,  and there they were . <START>
# <POS> <CON_START> it holds the charge when my phone was brand new . <START>
# <POS> <CON_START> i would recommend this case to my friends . <START>
# <POS> <CON_START> the same panel buttons are there but in a placement . <START>
# <POS> <CON_START> all my testing proves the same . hope that helps . <START>
# <POS> <CON_START> all in all ,  though ,  with the product . <START>
# <POS> <CON_START> finish is ,  and it makes french toast . <START>
# <POS> <CON_START> they get into the corners as described and are flexible yet firm . <START>
# <POS> <CON_START> hope this lasts longer than my last grinder so can buy as a gift . <START>
# <POS> <CON_START> i have had mine for almost two years and they have not frayed . <START>
# <POS> <CON_START> with grandchildren ,  this is the combination of colorful and functional . <START>
# <POS> <CON_START> it s also a size for a family of num_extend <START>
# <POS> <CON_START> i could not tell a difference at all . <START>
# <POS> <CON_START> i have been using this for num_num years . <START>
# <POS> <CON_START> i the oster ,  it does it claim to do . <START>
# <POS> <CON_START> i would not suggest this on black iphones . <START>
# <POS> <CON_START> it is close to the old one i had for years . <START>
# <POS> <CON_START> one to another company and two to amazon . com . <START>
# <POS> <CON_START> the knife got a tad rusty after running it through a cycle . <START>
# <POS> <CON_START> i think the sensor is reading carpet fibers its sucking up as dirt . <START>
# <POS> <CON_START> no problems with this and worked with many devices . <START>
# <POS> <CON_START> either you will it ,  or you won t . <START>
# <POS> <CON_START> puts together very easily and does what it s said it would . <START>
# <POS> <CON_START> i really how this protector curves over the edge of the . <START>
# <POS> <CON_START> trash cans are pretty unexciting ,  but this one is . <START>
# <POS> <CON_START> much than block and tackle type hooks to store overhead . <START>
# <POS> <CON_START> it is not to or assemble . <START>
# <POS> <CON_START> this is a bit heavier and truly . <START>
# <POS> <CON_START> i can hear the caller clearly ,  vice versa . <START>
# <POS> <CON_START> only issue is the blue light it becomes a annoying after a while . <START>
# <POS> <CON_START> we have tried a few and had fun with them . <START>
# <POS> <CON_START> take the whole thing out in the sink . <START>
# <POS> <CON_START> this is and to use . <START>
# <POS> <CON_START> i wouldn t trade them but this is a knife for the price . <START>
# <POS> <CON_START> it s very to use and very dependable . <START>
# <POS> <CON_START> it moves plenty of air ,  oscillating between two rooms . <START>
# <POS> <CON_START> i ve owned this crock for several years . <START>
# <POS> <CON_START> if you want loud get the cdn num_extend count down big digit timer . <START>
# <POS> <CON_START> then i used the attachemnts on my furniture and the water was gray . <START>
# <POS> <CON_START> i think this case is a very phone case . <START>
# <POS> <CON_START> is a product though i d heard of it . <START>
# <POS> <CON_START> the unit itself rests a necklace around your neck . <START>
# <POS> <CON_START> the item was what i was looking for and arrived exactly as described . <START>
# <POS> <CON_START> the braun has it all . this is my second programmable flavorselect . <START>
# <POS> <CON_START> i would definitely recommend this for a cute case . <START>
# <POS> <CON_START> but the back side looks as well . <START>
# <POS> <CON_START> i bought three of these units to place in our home . <START>
# <POS> <CON_START> and that would be what you would need . <START>
# <POS> <CON_START> it works and the coffee is just as !  . <START>
# <POS> <CON_START> it basically picks up what is directly in front of it . <START>
# <POS> <CON_START> pretty much all i ask for in a grinder . <START>
# <POS> <CON_START> it s a very at a reasonalbe price . <START>
# <POS> <CON_START> just do your homework and you will end up pretty satisfied . <START>
# <POS> <CON_START> this knife more than met our expectations . <START>
# <POS> <CON_START> most wheels that i ve seen are much smaller . <START>
# <POS> <CON_START> fit for replacement in my num_num year old blender that still works . <START>
# <POS> <CON_START> and i have tried a lot of them . <START>
# <POS> <CON_START> i give it five stars for making eating so !  . <START>
# <POS> <CON_START> i can t believe how strong this little guy is . <START>
# <POS> <CON_START> the daily challenge around here is keeping the fur to a minimum . <START>
# <POS> <CON_START> despite the port breaking it gets num_extend stars . <START>
# <POS> <CON_START> synching is simple ,  with no passwords or required . <START>
# <POS> <CON_START> wow im impressed with this device !  how useful it is . <START>
# <POS> <CON_START> a gas would be and a smooth probably much . <START>
# <POS> <CON_START> i the design and the colors . <START>
# <POS> <CON_START> very impressed than within a minute incorporated all ingredients to . <START>
# <POS> <CON_START> we often ,  hot and in it as well . <START>
# <POS> <CON_START> snug fit ,  with all the buttons and holes aligned . <START>
# <POS> <CON_START> yes ,  it is plastic ,  but not plastic . <START>
# <POS> <CON_START> i use this with afresh to my top . <START>
# <POS> <CON_START> doesn t get stuck on the rod some non rollers do . <START>
# <POS> <CON_START> i made flour that night for our mexican burrito dinner . <START>
# <POS> <CON_START> the surface is easier to than our other grills . <START>
# <POS> <CON_START> the case zipper shuts with a flap that covers the zipped part . <START>
# <POS> <CON_START> i feel i have a new phone . <START>
# <POS> <CON_START> it grinds it to a powder in just a couple of seconds . <START>
# <POS> <CON_START> plus its from amazon and amazon wouldn t put their name on . <START>
# <POS> <CON_START> he s heavy and stable enough to not tip over when it s windy . <START>
# <POS> <CON_START> another thing i really is that it does not have rivets . <START>
# <POS> <CON_START> he read every amazon . com review as well as the zojirushi website . <START>
# <POS> <CON_START> fair price . x x x x x x x x xx x . <START>
# <POS> <CON_START> i have to say that it was money well spent . <START>
# <POS> <CON_START> it stores in a really small place and is built to last . <START>
# <POS> <CON_START> on cleaning and the use of aluminum foil . <START>
# <POS> <CON_START> what a change in my life this will make . <START>
# <POS> <CON_START> the sound is also very surprising for the price and is enough for me . <START>
# <POS> <CON_START> this is the second one of these i have purchased . <START>
# <POS> <CON_START> it doesn t require genius to get this unit operating . <START>
# <POS> <CON_START> i estimate that four trips were made to empty and refill the water compartments . <START>
# <POS> <CON_START> will leave a big orange smear on the surface . <START>
# <POS> <CON_START> the instructions came over the motorola num_extend and were very clear . <START>
# <POS> <CON_START> once the lid closes ,  the goes away . <START>
# <POS> <CON_START> it s not as bulky feel as the other cases available . <START>
# <POS> <CON_START> still it is a fun learning experience and so far so . <START>
# <POS> <CON_START> it was just what i expected it to be . <START>
# <POS> <CON_START> i did not have what i felt were expectations of this device . <START>
# <POS> <CON_START> my wife despises window fans usually and she loves this thing too . <START>
# <POS> <CON_START> i purchased the to replace a glass bodum press that broke . <START>
# <POS> <CON_START> it works as expected and is just the right size for the camper . <START>
# <POS> <CON_START> a meeting my phone is in the bag charging . <START>
# <POS> <CON_START> white in the a couple of days longer . <START>
# <POS> <CON_START> i and you need sharp when . <START>
# <POS> <CON_START> this item works just as i thought it would . <START>
# <POS> <CON_START> it comes at a price and appears to be well made . <START>
# <POS> <CON_START> i read all the reviews and decided on this one . <START>
# <POS> <CON_START> of course the german s call this sort of idea engineering . <START>
# <POS> <CON_START> i also that this as an indoor . <START>
# <POS> <CON_START> we have used ours at least a couple of hundred times . <START>
# <POS> <CON_START> a must have if you have one of the older foodsavers . <START>
# <POS> <CON_START> i may even give some as this holiday season . <START>
# <POS> <CON_START> the finer the setting ,  the longer it takes . <START>
# <POS> <CON_START> i use these reviews so heavily that i want to give back . <START>
# <POS> <CON_START> should have a wider design for different foods . <START>
# <POS> <CON_START> its actually a little than the filter that came with the unit . <START>
# <POS> <CON_START> purchased this to charge my new android tablet in the car on trips . <START>
# <POS> <CON_START> i ve had to repair it a few times as it s % plastic . <START>
# <POS> <CON_START> this is the i ve ever owned . <START>
# <POS> <CON_START> not that anything sticks that much you just don t have to worry . <START>
# <NEG> <CON_START> if your had a kickstand on the plate it won t lock down . <START>
# <NEG> <CON_START> they are thinner and retain memory than the older ones . <START>
# <NEG> <CON_START> it makes a buzzing sound when devices are plugged in . <START>
# <NEG> <CON_START> i could barely get through it they taste so nasty . <START>
# <NEG> <CON_START> either than or the decided to do their own . <START>
# <NEG> <CON_START> the pair made in mexico is much . <START>
# <NEG> <CON_START> i m selling mine to make room for something else . <START>
# <NEG> <CON_START> it looks i ve splashed glitter all over my . <START>
# <NEG> <CON_START> went to the second one using the same method ,  no go . <START>
# <NEG> <CON_START> it was not as as our much cheaper model . <START>
# <NEG> <CON_START> so not that for leaving on at night . <START>
# <NEG> <CON_START> when i contacted the company the response was that they shipped it . <START>
# <NEG> <CON_START> and ,  there were many things we liked about this . <START>
# <NEG> <CON_START> !  i had trouble getting it on with zero bubbles . <START>
# <NEG> <CON_START> i ve been through so many of these ineffective silly things . <START>
# <NEG> <CON_START> after a few days i noticed i was unusually fatigued . <START>
# <NEG> <CON_START> the jawbone may perform admirably as far as technology . <START>
# <NEG> <CON_START> did nt have time to it before christmas so bought another necklass . <START>
# <NEG> <CON_START> another num_num calories from the other num_num grams of . <START>
# <NEG> <CON_START> these are supposedly cotton ,  but they don t feel it . <START>
# <NEG> <CON_START> one major complaint is the micromanagment of collecting  shards  . <START>
# <NEG> <CON_START> i tried supergluing the magnets back on to no avail . <START>
# <NEG> <CON_START> no comment on the since i have not used it yet . <START>
# <NEG> <CON_START> overall we will not be purchasing this product again . <START>
# <NEG> <CON_START> hello;i purchased this item from a major retailer about num_num years ago . <START>
# <NEG> <CON_START> i received the wrong color and it shreds easily . <START>
# <NEG> <CON_START> i will buy hamilton beach products again . <START>
# <NEG> <CON_START> the description on the website did not state that the were elastic . <START>
# <NEG> <CON_START> we re too to put together normal sounding sentences . <START>
# <NEG> <CON_START> the box is very shallow and not easily covered securely . <START>
# <NEG> <CON_START> this is not the money and the brand name is misleading . <START>
# <NEG> <CON_START> the cars that come with this garage are cute . <START>
# <NEG> <CON_START> used to be fun ,  but that tradition ends here . <START>
# <NEG> <CON_START> the computer recognized the usb connection ,  but the moved . <START>
# <NEG> <CON_START> so i bought this product hoping it would help to regulate my cycles . <START>
# <NEG> <CON_START> i would not even give my current one away . <START>
# <NEG> <CON_START> we have been treating our for months and finally got this . <START>
# <NEG> <CON_START> i bought this set for our toaster . <START>
# <NEG> <CON_START> is that what you re looking for ?  go elsewhere . <START>
# <NEG> <CON_START> not that we should of had to do that . <START>
# <NEG> <CON_START> my mouth feels very dry and i am thirsty after drinking this . <START>
# <NEG> <CON_START> my just isn t at all interested in these springs . <START>
# <NEG> <CON_START> obviously we all have our own preferences for taste . <START>
# <NEG> <CON_START> since that time i have replaced the . <START>
# <NEG> <CON_START> surely not what was paid for it by half . <START>
# <NEG> <CON_START> once you one match ,  you ve them all . <START>
# <NEG> <CON_START> i m just looking forward to the day i get to replace it . <START>
# <NEG> <CON_START> i products as a rule ,  so this was a . <START>
# <NEG> <CON_START> the original is the very definition of fun . <START>
# <NEG> <CON_START> the first time through ,  things really slowed down around level num_extend <START>
# <NEG> <CON_START> two reviewers determined there are drivers to be downloaded but i was unsuccessful . <START>
# <NEG> <CON_START> the bar   which does not occur naturally . <START>
# <NEG> <CON_START> i couldn t stand the of in my apartment . <START>
# <NEG> <CON_START> first ,  i put them both under my simultaneously . <START>
# <NEG> <CON_START> not a product for conditioning even though it says it has butter . <START>
# <NEG> <CON_START> i would recommend this of money case . <START>
# <NEG> <CON_START> i ve used it twice and it has stopped working . <START>
# <NEG> <CON_START> i run it outside the window and connect it to a garden hose . <START>
# <NEG> <CON_START> can t imagine how it acts when you heat style your . <START>
# <NEG> <CON_START> because it s too big for my cup holder . <START>
# <NEG> <CON_START> amazon was to give me a right away . <START>
# <NEG> <CON_START> it for no reason ,  got . <START>
# <NEG> <CON_START> i bought this for my boys a few years back . <START>
# <NEG> <CON_START> if you are sensitive to ,  this isn t for you . <START>
# <NEG> <CON_START> then contact sharp and go on from there . <START>
# <NEG> <CON_START> we ve tried num_num of these makers since jan num_extend <START>
# <NEG> <CON_START> i ll stick to my for now ,  thanks . <START>
# <NEG> <CON_START> i ve used these a few times and broke them very easily . <START>
# <NEG> <CON_START> this one sits on our shelf collecting dust . <START>
# <NEG> <CON_START> two days later i no longer saw them anywhere on the building . <START>
# <NEG> <CON_START> i myself for falling for the james bond license and wasting $ <START>
# <NEG> <CON_START> don t buy this unless you replacing toasters . <START>
# <NEG> <CON_START> this cream will give you if you have sensitive . <START>
# <NEG> <CON_START> i would not buy anything else from this vendor . <START>
# <NEG> <CON_START> i could feel some of the grains even after much shaking . <START>
# <NEG> <CON_START> and after all that ,  the base broke too . <START>
# <NEG> <CON_START> the is so i had to brush my . <START>
# <NEG> <CON_START> i am actually afraid to open the remaining . <START>
# <NEG> <CON_START> the charging light illuminates ,  but does not charge . <START>
# <NEG> <CON_START> the product is not but it might just be the one i received . <START>
# <NEG> <CON_START> then she said  well you ordered the pu which is what you got . <START>
# <NEG> <CON_START> i didn t have the rust problems that others had . <START>
# <NEG> <CON_START> in that short time ,  he one wing off the . <START>
# <NEG> <CON_START> this item does not provide full coverage as the picture suggests . <START>
# <NEG> <CON_START> these definitely open up your and functionally work as advertised . <START>
# <NEG> <CON_START> this is a fantastic idea ,  however it has some flaws . <START>
# <NEG> <CON_START> if you can afford it step up to something that will last . <START>
# <NEG> <CON_START> i won t be buying from this vender ever again . <START>
# <NEG> <CON_START> i thought the was good; scuffy thinks otherwise . <START>
# <NEG> <CON_START> every product i own from them has failed or been a . <START>
# <NEG> <CON_START> i would not trust anything bigger than iphone num_extend <START>
# <NEG> <CON_START> i have a  made in usa  version of this . <START>
# <NEG> <CON_START> then i put the cream on my feet especially around my and . <START>
# <NEG> <CON_START> you can go to any chain store and do . <START>
# <NEG> <CON_START> i simply treated it how i would assume a curling iron works . <START>
# <NEG> <CON_START> also the  free will  option is an absolute . <START>
# <NEG> <CON_START> if you are stir your ingredients  i . e . <START>
# <NEG> <CON_START> of course in most ,  shouldn t matter . <START>
# <NEG> <CON_START> i had it professionally installed at a local shop . <START>
# <NEG> <CON_START> this ring looked on out of the box . <START>
# <NEG> <CON_START> i did some research ,  and went with this one . <START>
# <NEG> <CON_START> i figured this would be a alternative to use during the six weeks . <START>
# <NEG> <CON_START> i bought this for my num_num month old from for christmas . <START>
# <NEG> <CON_START> we purchased this so our daughter could have fun to with . <START>
# <NEG> <CON_START> please reply with the filter part number and your location . <START>
# <NEG> <CON_START> i woke up with basically an oil slick on my . <START>
# <NEG> <CON_START> i put it together to surprise my husband . <START>
# <NEG> <CON_START> it hasn t done anything for his thin coat though . <START>
# <NEG> <CON_START> they send you num_num because each one lasts about two days . <START>
# <NEG> <CON_START> i felt i must have missed something if the reviews were so . <START>
# <NEG> <CON_START> i have to lower the rating another notch . <START>
# <NEG> <CON_START> i have purchased fairly holders from motorola and they lasted a while . <START>
# <NEG> <CON_START> i was surprised as the box seemed to be in shape . <START>
# <NEG> <CON_START> i was looking forward to this for a couple of num_extend <START>
# <NEG> <CON_START> these run quite small even though they are stretchy . <START>
# ...
# <NEG> <CON_START> very hard plastic and not that fun to with at all . <START>
# <NEG> <CON_START> save yourself some time and money and skip this product . <START>
# <NEG> <CON_START> a process that takes a couple of minutes . <START>
# <NEG> <CON_START> i and any or naturally enhanced cheese snack . <START>
# <NEG> <CON_START> hardly something i would give as a wrapped birthday gift . <START>
# <NEG> <CON_START> the problem with the acrylic ones i ve found is the tipping factor . <START>
# <NEG> <CON_START> bought this for use to hold my droid incredible . <START>
# <NEG> <CON_START> that is right up until one day the record feature stopped working . <START>
# <NEG> <CON_START> my daughter used this for school for about num_num months until the strap broke . <START>
# <NEG> <CON_START> i have num_num bird hanging from poles in my front and back yard . <START>
# <NEG> <CON_START> spent more time fiddling with this than i did looking at the road . <START>
# <NEG> <CON_START> don t your time or money on these jeans . <START>
# <NEG> <CON_START> i first used it on my hands and fingers . <START>
# <NEG> <CON_START> i also have to hold the headphone cord to keep it from flapping around . <START>
# <NEG> <CON_START> not the fastest but than my other hot air brush . <START>
# <NEG> <CON_START> i it out because i can t take alcohol . <START>
# <NEG> <CON_START> after that you have to pay a . <START>
# <NEG> <CON_START> there s no way this will last as long as claimed . <START>
# <NEG> <CON_START> i will still continue to use products ,  just not this one . <START>
# <NEG> <CON_START> certainly one of the more widely produced in the us . <START>
# <NEG> <CON_START> just reinstall the previous ghost and raven shield . <START>
# <NEG> <CON_START> all of them are ,  not even . <START>
# <NEG> <CON_START> i d suggest anyone looking to purchase products look into instead . <START>
# <NEG> <CON_START> thing filters for num_num gallon tanks are . <START>
# <NEG> <CON_START> i might it ,  but i need a can opener . <START>
# <NEG> <CON_START> instead i would recommend gentle and you will be . <START>
# <NEG> <CON_START> sugar is extremely and does absolutely for your body . <START>
# <NEG> <CON_START> i d rather tie a towel around my neck as a cape . <START>
# <NEG> <CON_START> the constriction on my caused him to sit . <START>
# <NEG> <CON_START> the case fit okay but not attractive at all . <START>
# <NEG> <CON_START> as i get hit ,  my health endurance goes down . <START>
# <NEG> <CON_START> they would flip off or get hung up due to rolling wheels . <START>
# <NEG> <CON_START> one thing is the amazingly unit a . i . <START>
# <NEG> <CON_START> i expected an improvement in signal strength from my tiny usb direct plugin type . <START>
# <NEG> <CON_START> my first suggestion to anyone reading reviews on this product is to keep looking . <START>
# <NEG> <CON_START> for some reason it worked out terribly for me . <START>
# <NEG> <CON_START> amazon does not provide enough information about this press . <START>
# <NEG> <CON_START> is just as ,  though thankfully not . <START>
# <NEG> <CON_START> i was after the first num_num minutes . <START>
# <NEG> <CON_START> i loved the food for my as you can read below . <START>
# <NEG> <CON_START> th product features and editorial review germany as the origin of manufacture . <START>
# <NEG> <CON_START> it didn t work for me hopefully other people will have luck . <START>
# <NEG> <CON_START> flavor :  it has some tangy notes ,  and overall not . <START>
# <NEG> <CON_START> mine is a piece of ,  as far as i am concerned . <START>
# <NEG> <CON_START> would have been alot nicer if it simply threaded in with the correct alignment . <START>
# <NEG> <CON_START> it is to invest in a set of brushes . <START>
# <NEG> <CON_START> i am only giving this item num_num stars because of the absurd price . <START>
# <NEG> <CON_START> this does not appear to attract more mosquitos than the light does by itself . <START>
# <NEG> <CON_START> it almost fit ,  but not enough to snap completely together and fit . <START>
# <NEG> <CON_START> there is no menu selection for find free books . <START>
# <NEG> <CON_START> i will have slight pain ,  no matter what . <START>
# <NEG> <CON_START> the material that it is made of is a dirt magnet . <START>
# <NEG> <CON_START> it works for maybe a few minutes and wears off quickly . <START>
# <NEG> <CON_START> the directions were to follow but the of the easel was . <START>
# <NEG> <CON_START> of money ,  of time ,  of . <START>
# <NEG> <CON_START> this case is far from what i expected . <START>
# <NEG> <CON_START> too bulky and there are products out there in single units . <START>
# <NEG> <CON_START> does not give me any confidence in buying any of the discovery kids . <START>
# <NEG> <CON_START> i would suggest a more tropical flavor with chilled water . <START>
# <NEG> <CON_START> old grandson loves all things that have to do with construction . <START>
# <NEG> <CON_START> maybe a num_extend old girl could wear it . <START>
# <NEG> <CON_START> so please stop buying this and maybe they will lower the price . <START>
# <NEG> <CON_START> decided to push it to live a whole num_num weeks sooner than that . <START>
# <NEG> <CON_START> it s not ,  it is not . <START>
# <NEG> <CON_START> num_extend has much ,  sound ,  slightly control . <START>
# <NEG> <CON_START> also the headphones do not feel on your head . <START>
# <NEG> <CON_START> claritin used to be the thing around . <START>
# <NEG> <CON_START> it really is they didn t take anything at all . <START>
# <NEG> <CON_START> i tried short of breaking the thing open . <START>
# <NEG> <CON_START> other reviews seemed more ,  but i just gave mine away . <START>
# <NEG> <CON_START> i dumped all num_num screen protectors in the trash bin . <START>
# <NEG> <CON_START> does this ever happen to the cpu ?  rarely . <START>
# <NEG> <CON_START> i would not buy this again in the future . <START>
# <NEG> <CON_START> makes the ,  don t get me wrong . <START>
# <NEG> <CON_START> perhaps it won t rust ,  but upclose it looks a little . <START>
# <NEG> <CON_START> so i just thought maybe it ll help keep my away . <START>
# <NEG> <CON_START> its tollable but thats not the thing to say about headphones . <START>
# <NEG> <CON_START> my has started to become anxious at bedtime . <START>
# <NEG> <CON_START> so after two months of use ,  working in it . <START>
# <NEG> <CON_START> i don t know why it has all the reviews . <START>
# <NEG> <CON_START> there were other included ,  but you really couldn t taste them . <START>
# <NEG> <CON_START> the of materials and workmanship is noticeably less . <START>
# <NEG> <CON_START> i used this along with another similar product ,  for over num_num months . <START>
# <NEG> <CON_START> i don t think the saying  you get what you pay  . <START>
# <NEG> <CON_START> if you want a cheaper deal with companies that specialize in that category . <START>
# <NEG> <CON_START> is by and . <START>
# <NEG> <CON_START> you dont get so much sand with this . <START>
# <NEG> <CON_START> if you get these just be a bit careful . <START>
# <NEG> <CON_START> it reminds me more of silly putty than of a . <START>
# <NEG> <CON_START> it worked for maybe num_num months then died . <START>
# <NEG> <CON_START> this is not at all expected from a respected brand sony . <START>
# <NEG> <CON_START> my goof to not research this brand more . <START>
# <NEG> <CON_START> i found these very hard to put on . <START>
# <NEG> <CON_START> i ve not been terribly impressed with this box . <START>
# <NEG> <CON_START> i will add an update if i ever figure it out . <START>
# <NEG> <CON_START> i tried hiding them in her food and in her . <START>
# <NEG> <CON_START> she didn t the handle of this one at all . <START>
# <NEG> <CON_START> well it made it a rubber band texture . <START>
# <NEG> <CON_START> i ll just stick with a mayo and skip the . <START>
# <NEG> <CON_START> thank heaven the operation is intuitive because there are no instructions . <START>
# <NEG> <CON_START> i thought i was over charged once it was . <START>
# <NEG> <CON_START> i bought them and find them pretty annoying . <START>
# <NEG> <CON_START> after all the reviews i thought i d give this a try . <START>
# <NEG> <CON_START> unfortunately this product did not do much for me . <START>
# <NEG> <CON_START> you get what you pay for i guess . <START>
# <NEG> <CON_START> it might work for all purpose flour ,  which has less gluten . <START>
# <NEG> <CON_START> in my experience ,  they are a constant source of problems . <START>
# <NEG> <CON_START> as i expected to received candy that would last a long time . <START>
# <NEG> <CON_START> the cords are over a foot long after being taken in . <START>
# <NEG> <CON_START> so ,  this car looks cool and all but its not that . <START>
# <NEG> <CON_START> i have no idea if it s me or this product doing . <START>
# <NEG> <CON_START> otherwise ,  they fall off your head at the slightest lean or tilt . <START>
# <NEG> <CON_START> just hurry up and the darn song and move on for goodness sake . <START>
# <NEG> <CON_START> try it once and you won t think it s . <START>
# <NEG> <CON_START> it was supposed to be a complete . <START>
# <NEG> <CON_START> nevertheless ,  the lasts for num_num or num_num minutes tops . <START>
# <NEG> <CON_START> that they are from usa and not china !  . <START>
# <NEG> <CON_START> so far i am not at all . <START>
# <NEG> <CON_START> i purchased them and when they arrived they were torn . <START>
# <NEG> <CON_START> quite and they make you order so many . <START>
# <NEG> <CON_START> camera fell of it after a few uses . <START>
# <NEG> <CON_START> i will again purchase another where this is a requirement . <START>
# <NEG> <CON_START> really ,  it all does look wise . <START>
# <NEG> <CON_START> its very similar to that type of style . <START>
# <NEG> <CON_START> might have been ,  but just went over my . <START>
# <NEG> <CON_START> the shape of the grains makes all the difference . <START>
# <NEG> <CON_START> first ,  without the extension they are very short . <START>
# <NEG> <CON_START> i then emptied th coffee grinder and looked for an obstruction ,  none . <START>
# <NEG> <CON_START> they have a medium pile lining that has more of a stiffer feel . <START>
# <NEG> <CON_START> nightwolf s friendship is cool too where he juggles his hammers . <START>
# <NEG> <CON_START> it s too because they look they would keep my ears warm . <START>
# <NEG> <CON_START> these salmons are in water not vegetable oil . <START>
# <NEG> <CON_START> when you place the eye attachment on you can get a mixed cut . <START>
# <NEG> <CON_START> i won t be buying any more in the future . <START>
# <NEG> <CON_START> i hated the color that was sent to me ,  pale beige . <START>
# <NEG> <CON_START> that s not what it felt with the original gel adhesive . <START>
# <NEG> <CON_START> the radtach procable num_num inch dock extender works only part way . <START>
# <NEG> <CON_START> because it is definitely not full price . <START>
# <NEG> <CON_START> i would not recommend this item for who . <START>
# <NEG> <CON_START> this is the i have come across in a long time . <START>
# <NEG> <CON_START> unfortunately i m not sure what all the five star reviews are for . <START>
# <NEG> <CON_START> it is too because the ingredients looked to be . <START>
# <NEG> <CON_START> i wore this product today for a few hours today . <START>
# <NEG> <CON_START> the feel of the wheel is and i the side scrolling feature . <START>
# <NEG> <CON_START> a definite num_extend for how they handled this . <START>
# <NEG> <CON_START> am very that i still can t wear my !  . <START>
# <NEG> <CON_START> it didn t fit in my bathtub ,  which is a standard size . <START>
# <NEG> <CON_START> we plugged in an extra headset laying around the house . <START>
# <NEG> <CON_START> this case looks but that s about it . <START>
# <NEG> <CON_START> it takes several passes through some types of to cut it . <START>
# <NEG> <CON_START> i contacted q cell and they replaced the back cover . <START>
# <NEG> <CON_START> i hope it will be a choice . <START>
# <NEG> <CON_START> i that it uses ingredients but it was ineffective on my . <START>
# <NEG> <CON_START> after a num_extend try i received the same product . <START>
# <NEG> <CON_START> most products are for caused by dry . <START>
# <NEG> <CON_START> over and over  and over and over  again . <START>
# <NEG> <CON_START> this product was not in functioning condition when delivered . <START>
# <NEG> <CON_START> this is a item that makes no sense at all . <START>
# <NEG> <CON_START> worked on older new england house with narrow staircase . <START>
# <NEG> <CON_START> might work for others ,  didn t work for me . <START>
# <NEG> <CON_START> not to mention it did not fit my screen completely . <START>
# <NEG> <CON_START> i thought that all of the possibilities would be . <START>
# <NEG> <CON_START> it was all and had very little clam flavor . <START>
# <NEG> <CON_START> taking it out of the box i found the design to be awkward . <START>
# <NEG> <CON_START> i purchased this jawbone hd as a replacement for an older jawbone thinker . <START>
# <NEG> <CON_START> i reported it havent heard a word about it . <START>
# <NEG> <CON_START> i was hoping for a bit than this from amazon . <START>
# <NEG> <CON_START> this case is cute however the is the only thing about it . <START>
# <NEG> <CON_START> i ve come to the conclusion that i ve my money . <START>
# <NEG> <CON_START> i would not recomend this for a tmobile ,  mytouch phone to anyone . <START>
# <NEG> <CON_START> the pieces that i manages to salvage the birds refuse to touch . <START>
# <NEG> <CON_START> he enjoys this ,  but can get the out fairly quickly . <START>
# <NEG> <CON_START> how many times you the nazgul and how easily they are beaten . <START>
# <NEG> <CON_START> i ordered num_num and find this to be a hugh mistake . <START>
# <NEG> <CON_START> if you are grinding dry items ,  it should be ok . <START>
# <NEG> <CON_START> the entire thing fits in the palm of my s hand . <START>
# <NEG> <CON_START> i ordered these from amazon since i could find them nowhere in my area . <START>
# <NEG> <CON_START> so what it comes down to is that u get what u paid for . <START>
# <NEG> <CON_START> the is more a vaseline stick . <START>
# <NEG> <CON_START> i guess it fails in the truth department on its . <START>
# <NEG> <CON_START> in this case ,  it s a big for num_extend <START>
# <NEG> <CON_START> i bought this product for feeding my num_num persian while on vacation . <START>
# <NEG> <CON_START> it is a performer when it comes to odor retention and . <START>
# <NEG> <CON_START> do not buy this product ! the photos are ,  misleading . <START>
# <NEG> <CON_START> it adds size o an already pretty big system . <START>
# <NEG> <CON_START> armada lacks the epic of similar or even . <START>
# <NEG> <CON_START> they were huge ,  yet the same size in the leather is tight . <START>
# <NEG> <CON_START> they also make noise if you happen to touch one against the other . <START>
# <NEG> <CON_START> it worked for the first couple of weeks then it just stopped completely . <START>
# <NEG> <CON_START> spend the extra bucks and get the chopat bands . <START>
# <NEG> <CON_START> unfortunately ,  not my nor my cell phone . <START>
# <NEG> <CON_START> i contacted the seller and was given a . <START>
# <NEG> <CON_START> the are most definitely improved over the previous version . <START>
# <NEG> <CON_START> it was almost yellow in the system . <START>
# <NEG> <CON_START> it does this to a very significant degree and is extremely to wear . <START>
# <NEG> <CON_START> there must be an engineering issue with the motor of the . <START>
# <NEG> <CON_START> the is declined quickly by heat exposure . <START>
# <NEG> <CON_START> the main flavor to come through is cinnamon and the slight of . <START>
# <NEG> <CON_START> i was also very at how quickly it drains the batteries . <START>
# <NEG> <CON_START> i can not send it back due to shipping requirements . <START>
# <NEG> <CON_START> as the clock clicked by num_extend i still felt . <START>
# <NEG> <CON_START> ekobrew ,  the coffee stays in that bottom wedge section . <START>
# <NEG> <CON_START> i can t send it back again because i don t have it . <START>

# %%
# !cat amazon_test_result.txt
# Out:
# i ve had this thermometer for about num _ num years . <END>
# will update this review should it meet a similar fate to my previous wheel . <END>
# this product does what it is suppose to do . <END>
# i purchased this filter for a braun num _ extend coffeemaker . <END>
# very good price but this one harder to use than my cusinart . <END>
# so , to me this is pretty darn instant . <END>
# replaced my pampered chef press with this one . <END>
# i use this as a little office supply shelf . <END>
# quality and seems similar to apple products . <END>
# i have many oxo products , and i ve been pleased . <END>
# i also prefered the blade weight and thickness of the wustof . <END>
# make sure the pins line up with the contacts . <END>
# i would not recommend this item for dogs who love . <END>
# this is the worst game i have come across in a long time . <END>
# unfortunately i m not sure what all the five star reviews are for . <END>
# it is too bad because the ingredients looked to be natural . <END>
# i wore this product today for a few hours today . <END>
# the feel of the wheel is nice and i like the side scrolling feature . <END>
# a definite num _ extend for how they handled this . <END>
# am very disappointed that i still can t wear my shoes ! . <END>
# it didn t fit in my bathtub , which is a standard size . <END>
# we plugged in an extra headset laying around the house . <END>
# this case looks nice but that s about it . <END>
# it takes several passes through some types of scenes to cut it . <END>
# i contacted q cell and they replaced the back cover . <END>
# i hope it will be a better choice . <END>
# i love that it uses ingredients but it was ineffective on my skin . <END>
# after a num _ extend try i received the same product . <END>
# most products are good for acne caused by dry skin . <END>
# over and over and over again . <END>
# this product was not in functioning condition when delivered . <END>
# this is a item that makes no sense at all . <END>
# worked on older england house with narrow staircase . <END>
# might work for others , didn t work for me . <END>
# not to mention it did not fit my screen completely . <END>
# i thought that all of the possibilities would be better . <END>
# it was all natural and had very little clam flavor . <END>
# taking it out of the box i found the design to be awkward . <END>
# i purchased this jawbone hd as a replacement for an older jawbone thinker . <END>
# i reported it havent heard a word about it . <END>
# i was hoping for a bit better than this from amazon . <END>
# this case is cute however the is the only good thing about it . <END>
# i ve come to the conclusion that i ve wasted my money . <END>
# i would not recomend this for a tmobile , mytouch phone to anyone . <END>
# the pieces that i manages to salvage the birds refuse to touch . <END>
# he enjoys this toy , but can get the game out fairly quickly . <END>
# how many times you play the write write ours however tho tho gul and how easily they are beaten . <END>
# i ordered num _ num and find this to be a healthier mistake . <END>
# if you are grinding dry items , it should be ok . <END>
# the entire thing fits in the palm of my dog s hand . <END>
# i ordered these from amazon since i could find them nowhere in my area . <END>
# so what it comes down to is that u get what u paid for . <END>
# the smell is more like a vaseline stick . <END>
# i guess it fails in the truth department on its story . <END>
# in this case , it s a big disappointment for num _ extend <END>
# i bought this product for feeding my num _ num persian cat while on vacation . <END>
# it is a great performer when it comes to odor retention and smell . <END>
# do not buy this product ! the photos are cheap , misleading . <END>
# it adds size o an already pretty big system . <END>
# knocksoft holsters lacks the epic of similar or even . <END>
# they were huge , yet the same size in the leather is tight . <END>
# they also make noise if you happen to touch one against the other . <END>
# it worked for the first couple of weeks then it just stopped completely . <END>
# spend the extra bucks and get the chopat bands . <END>
# unfortunately , not my vet nor my cell phone . <END>
# i contacted the seller and was given a refund . <END>
# the graphics are most cartoonish definitely improved over the previous version . <END>
# it was almost yellow in the system . <END>
# it does this to a very significant degree and is extremely uncomfortable to wear . <END>
# there must be an engineering issue with the motor of the tire . <END>
# the quality is declined quickly by heat exposure . <END>
# the main flavor to come through is cinnamon and the slight of smell . <END>
# i was also very disappointed at how quickly it drains the batteries . <END>
# i can not send it back due to shipping requirements . <END>
# as the clock clicked by num _ extend i still felt horrible . <END>
# ekobrew , the coffee stays in that bottom wedge section . <END>
# i can t send it back again because i don t have it . <END>

# %%
# !cat processed_sentiment_test.txt | wc -l
# Out:
# 1000

# %%
# !cat amazon_test_result.txt | wc -l
# Out:
# 1000
